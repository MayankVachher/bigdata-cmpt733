# %%
from pylab import rcParams

# %matplotlib inline
rcParams['figure.figsize'] = (8,6)

# %%
from pyspark.sql import SparkSession, Row, functions, Column
from pyspark.sql.types import *

from pyspark.ml import Pipeline, Estimator
from pyspark.ml.feature import SQLTransformer, VectorAssembler
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import TrainValidationSplit, ParamGridBuilder
from pyspark.ml.regression import (LinearRegression,
                                   GBTRegressor,
                                   RandomForestRegressor,
                                   DecisionTreeRegressor)

import sys
from weather_tools_mv import *

# %%
schema = StructType([
    StructField('station', StringType(), False),
    StructField('date', DateType(), False),
    # StructField('dayofyear', IntegerType(), False),
    StructField('latitude', FloatType(), False),
    StructField('longitude', FloatType(), False),
    StructField('elevation', FloatType(), False),
    StructField('tmax', FloatType(), False),
])

def get_data(inputloc, tablename='data'):
    data = spark.read.csv(inputloc, schema=schema)
    data.createOrReplaceTempView(tablename)
    return data

# %% [markdown]
# # Part 2a

# %%
# Part 2a

input_loc = 'tmax-2'

data = get_data(input_loc)

# years = list(map(lambda x: str(x), range(2000, 2018)))

years = ['2000', '2001', '2002', '2003']

reduced_data = dict()

def resolved_max(df):
    df_max = df.groupBy('station').agg({'date': 'max'}).select(functions.col('station'),
                                                              functions.col('max(date)').alias('d_max'))
    
    d_max = df.join(df_max, 'station').where(functions.col('d_max') == functions.col('date'))
    
    fin_ret = d_max.select(functions.col('latitude'),
                            functions.col('longitude'),
                            functions.col('tmax'),
                            functions.col('station'))
    
    return list(map(lambda row: row.asDict(), fin_ret.collect()))

for i in range(0, len(years) - 1):
    lower = years[i]
    upper = years[i+1]
    zone = data.filter(functions.col('date') < upper).filter(functions.col('date') >= lower)
    reduced_data[lower+"_"+upper] = resolved_max(zone)

reduced_data['2000_2001']
# Out:
# [{'latitude': 38.62779998779297,
#   'longitude': -92.55449676513672,
#   'station': 'USC00231189',
#   'tmax': 27.799999237060547},
#  {'latitude': 76.7699966430664,
#   'longitude': -18.670000076293945,
#   'station': 'GL000004320',
#   'tmax': 9.5},
#  {'latitude': 4.019999980926514,
#   'longitude': 9.720000267028809,
#   'station': 'CM000004910',
#   'tmax': 30.5},
#  {'latitude': 35.74250030517578,
#   'longitude': -78.83689880371094,
#   'station': 'USC00310212',
#   'tmax': 19.399999618530273},
#  {'latitude': 62.93669891357422,
#   'longitude': 22.490800857543945,
#   'station': 'FIE00144322',
#   'tmax': 19.799999237060547},
#  {'latitude': -35.90039825439453,
#   'longitude': 150.14370727539062,
#   'station': 'ASN00069148',
#   'tmax': 17.0},
#  {'latitude': 39.47079849243164,
#   'longitude': -87.40809631347656,
#   'station': 'USC00128723',
#   'tmax': 29.399999618530273},
#  {'latitude': 47.5088996887207,
#   'longitude': -99.12110137939453,
#   'station': 'USC00321362',
#   'tmax': 28.299999237060547},
#  {'latitude': 43.354400634765625,
#   'longitude': -71.73639678955078,
#   'station': 'USC00277833',
#   'tmax': 25.600000381469727},
#  {'latitude': 42.774200439453125,
#   'longitude': -77.6082992553711,
#   'station': 'USC00303773',
#   'tmax': 26.700000762939453},
#  {'latitude': 53.0463981628418,
#   'longitude': 8.799200057983398,
#   'station': 'GM000001474',
#   'tmax': 21.0},
#  {'latitude': 56.279998779296875,
#   'longitude': 90.5,
#   'station': 'RSM00029467',
#   'tmax': 16.100000381469727},
#  {'latitude': 54.91669845581055,
#   'longitude': -115.1500015258789,
#   'station': 'CA003062020',
#   'tmax': 20.0},
#  {'latitude': 64.7300033569336,
#   'longitude': 13.960000038146973,
#   'station': 'SWE00140390',
#   'tmax': 21.0},
#  {'latitude': 43.81999969482422,
#   'longitude': -114.26000213623047,
#   'station': 'USS0014F03S',
#   'tmax': 27.100000381469727},
#  {'latitude': 43.36360168457031,
#   'longitude': -117.11419677734375,
#   'station': 'USC00357277',
#   'tmax': 32.79999923706055},
#  {'latitude': 64.98310089111328,
#   'longitude': 34.81639862060547,
#   'station': 'RSM00022520',
#   'tmax': 14.699999809265137},
#  {'latitude': 61.30440139770508,
#   'longitude': 28.181900024414062,
#   'station': 'FIE00143265',
#   'tmax': 15.600000381469727},
#  {'latitude': 66.38999938964844,
#   'longitude': 21.6200008392334,
#   'station': 'SWE00140718',
#   'tmax': 22.5},
#  {'latitude': 39.457801818847656,
#   'longitude': -95.75499725341797,
#   'station': 'USC00143759',
#   'tmax': 32.79999923706055},
#  {'latitude': 35.970001220703125,
#   'longitude': -92.74579620361328,
#   'station': 'USR0000ASIL',
#   'tmax': 32.79999923706055},
#  {'latitude': 48.79999923706055,
#   'longitude': 29.399999618530273,
#   'station': 'UPM00033577',
#   'tmax': 25.5},
#  {'latitude': -12.123900413513184,
#   'longitude': 134.90780639648438,
#   'station': 'ASN00014402',
#   'tmax': 27.0},
#  {'latitude': 32.30670166015625,
#   'longitude': -95.2968978881836,
#   'station': 'USC00419207',
#   'tmax': 35.0},
#  {'latitude': -24.291400909423828,
#   'longitude': 131.54879760742188,
#   'station': 'ASN00015652',
#   'tmax': 15.800000190734863},
#  {'latitude': 42.89139938354492,
#   'longitude': -73.24690246582031,
#   'station': 'USW00054781',
#   'tmax': 21.700000762939453},
#  {'latitude': 45.650001525878906,
#   'longitude': -73.7332992553711,
#   'station': 'CA007020392',
#   'tmax': 23.5},
#  {'latitude': 50.54999923706055,
#   'longitude': -105.38330078125,
#   'station': 'CA004010984',
#   'tmax': 28.0},
#  {'latitude': 46.47999954223633,
#   'longitude': 30.6299991607666,
#   'station': 'UPM00033837',
#   'tmax': 28.5},
#  {'latitude': 44.43560028076172,
#   'longitude': -121.94280242919922,
#   'station': 'USC00357554',
#   'tmax': 23.299999237060547},
#  {'latitude': 40.12670135498047,
#   'longitude': -82.94419860839844,
#   'station': 'USC00338951',
#   'tmax': 30.600000381469727},
#  {'latitude': 38.16419982910156,
#   'longitude': -86.80940246582031,
#   'station': 'USC00127724',
#   'tmax': 30.600000381469727},
#  {'latitude': 55.016700744628906,
#   'longitude': 73.38310241699219,
#   'station': 'RSM00028698',
#   'tmax': 31.600000381469727},
#  {'latitude': 31.553600311279297,
#   'longitude': -99.8499984741211,
#   'station': 'USC00416747',
#   'tmax': 37.20000076293945},
#  {'latitude': 37.32780075073242,
#   'longitude': -95.50420379638672,
#   'station': 'USW00003998',
#   'tmax': 30.600000381469727},
#  {'latitude': 45.45249938964844,
#   'longitude': -99.33580017089844,
#   'station': 'USC00397277',
#   'tmax': 28.299999237060547},
#  {'latitude': 35.60309982299805,
#   'longitude': -83.7780990600586,
#   'station': 'USC00409065',
#   'tmax': 25.600000381469727},
#  {'latitude': 46.50669860839844,
#   'longitude': -99.76920318603516,
#   'station': 'USC00326255',
#   'tmax': 28.899999618530273},
#  {'latitude': 22.253999710083008,
#   'longitude': -100.93099975585938,
#   'station': 'MXM00076539',
#   'tmax': 27.0},
#  {'latitude': 44.94139862060547,
#   'longitude': -107.70890045166016,
#   'station': 'USR0000WBOY',
#   'tmax': 26.700000762939453},
#  {'latitude': 37.1088981628418,
#   'longitude': -92.57890319824219,
#   'station': 'USC00235227',
#   'tmax': 28.899999618530273},
#  {'latitude': 41.150001525878906,
#   'longitude': -105.16670227050781,
#   'station': 'USC00484442',
#   'tmax': 30.0},
#  {'latitude': 34.82419967651367,
#   'longitude': -106.0344009399414,
#   'station': 'USC00293060',
#   'tmax': 32.79999923706055},
#  {'latitude': 14.171699523925781,
#   'longitude': 145.2427978515625,
#   'station': 'CQC00914801',
#   'tmax': 30.0},
#  {'latitude': 37.61280059814453,
#   'longitude': -114.52639770507812,
#   'station': 'USC00261358',
#   'tmax': 37.20000076293945},
#  {'latitude': 36.91939926147461,
#   'longitude': -104.43250274658203,
#   'station': 'USC00297279',
#   'tmax': 30.600000381469727},
#  {'latitude': 41.06560134887695,
#   'longitude': -92.78669738769531,
#   'station': 'USC00130112',
#   'tmax': 28.299999237060547},
#  {'latitude': 32.73360061645508,
#   'longitude': -117.18309783935547,
#   'station': 'USW00023188',
#   'tmax': 23.299999237060547},
#  {'latitude': 41.15169906616211,
#   'longitude': -104.65750122070312,
#   'station': 'USC00480270',
#   'tmax': 33.29999923706055},
#  {'latitude': 37.4536018371582,
#   'longitude': -103.3218994140625,
#   'station': 'USC00054538',
#   'tmax': 33.900001525878906},
#  {'latitude': 35.18080139160156,
#   'longitude': -97.43779754638672,
#   'station': 'USC00346386',
#   'tmax': 31.700000762939453},
#  {'latitude': 67.93329620361328,
#   'longitude': -162.3000030517578,
#   'station': 'USR0000AKEL',
#   'tmax': 14.399999618530273},
#  {'latitude': 35.54999923706055,
#   'longitude': 133.23300170898438,
#   'station': 'JA000047742',
#   'tmax': 34.099998474121094},
#  {'latitude': 44.96609878540039,
#   'longitude': -121.49079895019531,
#   'station': 'USR0000OHEH',
#   'tmax': 32.79999923706055},
#  {'latitude': 34.53580093383789,
#   'longitude': -119.7833023071289,
#   'station': 'USR0000CLOP',
#   'tmax': 36.70000076293945},
#  {'latitude': 47.117000579833984,
#   'longitude': 81.61699676513672,
#   'station': 'KZ000036639',
#   'tmax': 34.5},
#  {'latitude': 31.541400909423828,
#   'longitude': -102.91220092773438,
#   'station': 'USC00415999',
#   'tmax': 40.0},
#  {'latitude': 26.5580997467041,
#   'longitude': -99.13719940185547,
#   'station': 'USC00413060',
#   'tmax': 41.099998474121094},
#  {'latitude': 38.313899993896484,
#   'longitude': -81.71859741210938,
#   'station': 'USC00461579',
#   'tmax': 30.600000381469727},
#  {'latitude': 45.96670150756836,
#   'longitude': -66.6500015258789,
#   'station': 'CA008101507',
#   'tmax': 22.5},
#  {'latitude': 49.06669998168945,
#   'longitude': 54.683101654052734,
#   'station': 'KZ000035416',
#   'tmax': 37.599998474121094},
#  {'latitude': 39.4286003112793,
#   'longitude': -105.07029724121094,
#   'station': 'USC00057249',
#   'tmax': 30.600000381469727},
#  {'latitude': 49.13330078125,
#   'longitude': -113.25,
#   'station': 'CA003031320',
#   'tmax': 31.5},
#  {'latitude': 41.81719970703125,
#   'longitude': -110.53279876708984,
#   'station': 'USC00485105',
#   'tmax': 30.0},
#  {'latitude': 41.20970153808594,
#   'longitude': -101.67060089111328,
#   'station': 'USC00254455',
#   'tmax': 31.100000381469727},
#  {'latitude': 43.6088981628418,
#   'longitude': -84.20110321044922,
#   'station': 'USC00205434',
#   'tmax': 25.600000381469727},
#  {'latitude': 41.94419860839844,
#   'longitude': -71.9030990600586,
#   'station': 'USC00069388',
#   'tmax': 23.299999237060547},
#  {'latitude': 47.687198638916016,
#   'longitude': -122.25530242919922,
#   'station': 'USW00094290',
#   'tmax': 26.700000762939453},
#  {'latitude': 46.680301666259766,
#   'longitude': -92.9542007446289,
#   'station': 'USC00219173',
#   'tmax': 28.899999618530273},
#  {'latitude': 38.13169860839844,
#   'longitude': -108.2863998413086,
#   'station': 'USC00056012',
#   'tmax': 34.400001525878906},
#  {'latitude': 47.766700744628906,
#   'longitude': -53.21670150756836,
#   'station': 'CA008404100',
#   'tmax': 20.0},
#  {'latitude': 32.47249984741211,
#   'longitude': -94.71720123291016,
#   'station': 'USC00415341',
#   'tmax': 36.099998474121094},
#  {'latitude': 57.0,
#   'longitude': -92.30000305175781,
#   'station': 'CA005063350',
#   'tmax': 34.0},
#  {'latitude': 43.27220153808594,
#   'longitude': -78.16639709472656,
#   'station': 'USC00300055',
#   'tmax': 27.799999237060547},
#  {'latitude': 35.639400482177734,
#   'longitude': -84.66500091552734,
#   'station': 'USC00402388',
#   'tmax': 34.400001525878906},
#  {'latitude': 33.367000579833984,
#   'longitude': 129.5500030517578,
#   'station': 'JA000047805',
#   'tmax': 31.200000762939453},
#  {'latitude': 59.02000045776367,
#   'longitude': 121.7699966430664,
#   'station': 'RSM00030089',
#   'tmax': 29.0},
#  {'latitude': 53.25,
#   'longitude': -131.8166961669922,
#   'station': 'CA001057050',
#   'tmax': 16.299999237060547},
#  {'latitude': 34.36220169067383,
#   'longitude': -98.9760971069336,
#   'station': 'USW00003981',
#   'tmax': 31.700000762939453},
#  {'latitude': 43.93330001831055,
#   'longitude': -60.016700744628906,
#   'station': 'CA008204700',
#   'tmax': 18.799999237060547},
#  {'latitude': 38.506900787353516,
#   'longitude': -121.49500274658203,
#   'station': 'USW00023232',
#   'tmax': 36.70000076293945},
#  {'latitude': 65.87969970703125,
#   'longitude': 20.1299991607666,
#   'station': 'SWE00140634',
#   'tmax': 26.5},
#  {'latitude': 40.15190124511719,
#   'longitude': -122.25360107421875,
#   'station': 'USW00024216',
#   'tmax': 39.400001525878906},
#  {'latitude': -23.37529945373535,
#   'longitude': 150.4774932861328,
#   'station': 'ASN00039083',
#   'tmax': 21.700000762939453},
#  {'latitude': 40.86000061035156,
#   'longitude': -110.80000305175781,
#   'station': 'USS0010J35S',
#   'tmax': 28.600000381469727},
#  {'latitude': 44.38999938964844,
#   'longitude': -103.70059967041016,
#   'station': 'USC00392209',
#   'tmax': 30.0},
#  {'latitude': 48.997798919677734,
#   'longitude': -107.83309936523438,
#   'station': 'USC00246672',
#   'tmax': 35.0},
#  {'latitude': 57.849998474121094,
#   'longitude': 114.23310089111328,
#   'station': 'RSM00030253',
#   'tmax': 24.700000762939453},
#  {'latitude': 64.30000305175781,
#   'longitude': -96.08329772949219,
#   'station': 'CA002300500',
#   'tmax': 18.600000381469727},
#  {'latitude': 44.88309860229492,
#   'longitude': -85.67530059814453,
#   'station': 'USC00206012',
#   'tmax': 27.200000762939453},
#  {'latitude': 3.549999952316284,
#   'longitude': -76.38300323486328,
#   'station': 'CO000080259',
#   'tmax': 29.0},
#  {'latitude': 19.117000579833984,
#   'longitude': 72.8499984741211,
#   'station': 'IN012070800',
#   'tmax': 31.700000762939453},
#  {'latitude': 34.752201080322266,
#   'longitude': -112.11139678955078,
#   'station': 'USC00024453',
#   'tmax': 36.70000076293945},
#  {'latitude': 39.642799377441406,
#   'longitude': -79.91639709472656,
#   'station': 'USW00013736',
#   'tmax': 24.399999618530273},
#  {'latitude': 4.701000213623047,
#   'longitude': -74.1500015258789,
#   'station': 'CO000080222',
#   'tmax': 17.600000381469727},
#  {'latitude': 48.321998596191406,
#   'longitude': 4.017000198364258,
#   'station': 'FRM00007168',
#   'tmax': 24.600000381469727},
#  {'latitude': 43.630001068115234,
#   'longitude': -107.18000030517578,
#   'station': 'USS0007F02S',
#   'tmax': 26.799999237060547},
#  {'latitude': 36.32109832763672,
#   'longitude': -87.2217025756836,
#   'station': 'USC00401663',
#   'tmax': 27.799999237060547},
#  {'latitude': 58.45000076293945,
#   'longitude': -3.0829999446868896,
#   'station': 'UK000070765',
#   'tmax': 14.5},
#  {'latitude': 31.71190071105957,
#   'longitude': -110.068603515625,
#   'station': 'USC00028619',
#   'tmax': 33.900001525878906},
#  {'latitude': 48.08000183105469,
#   'longitude': -116.00140380859375,
#   'station': 'USC00244084',
#   'tmax': 33.29999923706055},
#  {'latitude': 38.5099983215332,
#   'longitude': -112.0199966430664,
#   'station': 'USS0012L04S',
#   'tmax': 27.100000381469727},
#  {'latitude': 39.50389862060547,
#   'longitude': -98.31500244140625,
#   'station': 'USC00143100',
#   'tmax': 31.100000381469727},
#  {'latitude': 47.42190170288086,
#   'longitude': 10.986700057983398,
#   'station': 'GM000004155',
#   'tmax': -0.20000000298023224},
#  {'latitude': 49.66669845581055,
#   'longitude': -107.0,
#   'station': 'CA004023800',
#   'tmax': 35.5},
#  {'latitude': 48.160301208496094,
#   'longitude': -90.88420104980469,
#   'station': 'USC00213417',
#   'tmax': 26.700000762939453},
#  {'latitude': 50.70000076293945,
#   'longitude': -120.44999694824219,
#   'station': 'CA001163780',
#   'tmax': 33.400001525878906},
#  {'latitude': 42.30609893798828,
#   'longitude': -113.368896484375,
#   'station': 'USC00105567',
#   'tmax': 40.0},
#  {'latitude': 1.5329999923706055,
#   'longitude': 124.91699981689453,
#   'station': 'ID000097014',
#   'tmax': 31.799999237060547},
#  {'latitude': 43.1432991027832,
#   'longitude': -70.94999694824219,
#   'station': 'USC00272174',
#   'tmax': 21.100000381469727},
#  {'latitude': 16.933000564575195,
#   'longitude': 54.016998291015625,
#   'station': 'MUM00041312',
#   'tmax': 27.100000381469727},
#  {'latitude': -3.3499999046325684,
#   'longitude': 128.88299560546875,
#   'station': 'IDM00097722',
#   'tmax': 28.299999237060547},
#  {'latitude': 29.299999237060547,
#   'longitude': -94.80000305175781,
#   'station': 'USW00012944',
#   'tmax': 30.600000381469727},
#  {'latitude': 39.560001373291016,
#   'longitude': -115.83999633789062,
#   'station': 'USS0015K03S',
#   'tmax': 32.099998474121094},
#  {'latitude': 52.1702995300293,
#   'longitude': 4.429200172424316,
#   'station': 'NLE00101982',
#   'tmax': 20.5},
#  {'latitude': 43.782798767089844,
#   'longitude': -113.00330352783203,
#   'station': 'USC00104384',
#   'tmax': 37.20000076293945},
#  {'latitude': -16.25,
#   'longitude': -62.099998474121094,
#   'station': 'BLM00085196',
#   'tmax': 28.5},
#  {'latitude': 30.25,
#   'longitude': 56.96699905395508,
#   'station': 'IR000040841',
#   'tmax': 33.0},
#  {'latitude': 42.86669921875,
#   'longitude': -80.55000305175781,
#   'station': 'CA006131983',
#   'tmax': 27.100000381469727},
#  {'latitude': 49.79999923706055,
#   'longitude': -112.11669921875,
#   'station': 'CA003036360',
#   'tmax': 31.0},
#  {'latitude': 47.27000045776367,
#   'longitude': -113.76000213623047,
#   'station': 'USS0013B07S',
#   'tmax': 27.0},
#  {'latitude': 37.98780059814453,
#   'longitude': -89.19309997558594,
#   'station': 'USC00112483',
#   'tmax': 27.799999237060547},
#  {'latitude': 39.26029968261719,
#   'longitude': -108.4072036743164,
#   'station': 'USR0000CPNR',
#   'tmax': 32.79999923706055},
#  {'latitude': 34.02190017700195,
#   'longitude': -109.45189666748047,
#   'station': 'USC00023683',
#   'tmax': 24.399999618530273},
#  {'latitude': 65.3458023071289,
#   'longitude': -155.93609619140625,
#   'station': 'USR0000ACOT',
#   'tmax': 14.399999618530273},
#  {'latitude': 33.072200775146484,
#   'longitude': -111.76609802246094,
#   'station': 'USC00027370',
#   'tmax': 43.900001525878906},
#  {'latitude': 34.58829879760742,
#   'longitude': -118.09390258789062,
#   'station': 'USC00046624',
#   'tmax': 41.70000076293945},
#  {'latitude': 46.483299255371094,
#   'longitude': -84.5167007446289,
#   'station': 'CA006057592',
#   'tmax': 26.299999237060547},
#  {'latitude': 44.789398193359375,
#   'longitude': -122.81500244140625,
#   'station': 'USC00358095',
#   'tmax': 32.20000076293945},
#  {'latitude': 41.517799377441406,
#   'longitude': -115.3927993774414,
#   'station': 'USR0000NSTA',
#   'tmax': 36.70000076293945},
#  {'latitude': 35.733001708984375,
#   'longitude': 140.85000610351562,
#   'station': 'JA000047648',
#   'tmax': 28.899999618530273},
#  {'latitude': -34.67499923706055,
#   'longitude': 150.85189819335938,
#   'station': 'ASN00068038',
#   'tmax': 17.299999237060547},
#  {'latitude': 42.69580078125,
#   'longitude': -73.1707992553711,
#   'station': 'USW00054768',
#   'tmax': 20.0},
#  {'latitude': 59.849998474121094,
#   'longitude': 81.94999694824219,
#   'station': 'RSM00029023',
#   'tmax': 25.399999618530273},
#  {'latitude': 53.0,
#   'longitude': -122.94999694824219,
#   'station': 'CA001086550',
#   'tmax': 25.0},
#  {'latitude': 40.34579849243164,
#   'longitude': -94.83419799804688,
#   'station': 'USC00235340',
#   'tmax': 27.200000762939453},
#  {'latitude': 42.709999084472656,
#   'longitude': -118.62999725341797,
#   'station': 'USS0018G02S',
#   'tmax': 28.0},
#  {'latitude': 39.29309844970703,
#   'longitude': -118.01969909667969,
#   'station': 'USC00265132',
#   'tmax': 37.79999923706055},
#  {'latitude': 37.14670181274414,
#   'longitude': -94.502197265625,
#   'station': 'USW00013987',
#   'tmax': 28.899999618530273},
#  {'latitude': -33.955101013183594,
#   'longitude': 137.69529724121094,
#   'station': 'ASN00022006',
#   'tmax': 18.299999237060547},
#  {'latitude': 8.050000190734863,
#   'longitude': -2.7829999923706055,
#   'station': 'IVM00065545',
#   'tmax': 29.0},
#  {'latitude': 41.95000076293945,
#   'longitude': 101.06700134277344,
#   'station': 'CHM00052267',
#   'tmax': 31.600000381469727},
#  {'latitude': 60.16669845581055,
#   'longitude': 24.950000762939453,
#   'station': 'FI000000304',
#   'tmax': 20.5},
#  {'latitude': 43.92470169067383,
#   'longitude': -119.59439849853516,
#   'station': 'USR0000OALL',
#   'tmax': 33.900001525878906},
#  {'latitude': 33.4119987487793,
#   'longitude': 36.51599884033203,
#   'station': 'SYM00040080',
#   'tmax': 45.79999923706055},
#  {'latitude': 35.994998931884766,
#   'longitude': -106.97029876708984,
#   'station': 'USC00292241',
#   'tmax': 30.0},
#  {'latitude': 35.599998474121094,
#   'longitude': 0.30000001192092896,
#   'station': 'AGM00060506',
#   'tmax': 37.20000076293945},
#  {'latitude': 45.400001525878906,
#   'longitude': 29.600000381469727,
#   'station': 'UPM00033898',
#   'tmax': 28.899999618530273},
#  {'latitude': 42.32780075073242,
#   'longitude': -7.860300064086914,
#   'station': 'SPE00120368',
#   'tmax': 36.599998474121094},
#  {'latitude': 33.373600006103516,
#   'longitude': -93.90689849853516,
#   'station': 'USC00032746',
#   'tmax': 33.29999923706055},
#  {'latitude': 51.79999923706055,
#   'longitude': 87.5999984741211,
#   'station': 'RSM00036064',
#   'tmax': 25.700000762939453},
#  {'latitude': 3.632999897003174,
#   'longitude': -54.03300094604492,
#   'station': 'FGM00081415',
#   'tmax': 32.20000076293945},
#  {'latitude': 43.03499984741211,
#   'longitude': -106.98829650878906,
#   'station': 'USC00487376',
#   'tmax': 37.20000076293945},
#  {'latitude': 33.53110122680664,
#   'longitude': -84.35440063476562,
#   'station': 'USC00094700',
#   'tmax': 33.900001525878906},
#  {'latitude': 38.21030044555664,
#   'longitude': -122.28469848632812,
#   'station': 'USW00093227',
#   'tmax': 33.29999923706055},
#  {'latitude': 32.349998474121094,
#   'longitude': -94.6500015258789,
#   'station': 'USW00003951',
#   'tmax': 35.0},
#  {'latitude': 40.78329849243164,
#   'longitude': -91.12529754638672,
#   'station': 'USW00014931',
#   'tmax': 30.0},
#  {'latitude': 33.45000076293945,
#   'longitude': 135.75,
#   'station': 'JA000047778',
#   'tmax': 29.899999618530273},
#  {'latitude': 19.49169921875,
#   'longitude': -155.9116973876953,
#   'station': 'USC00513977',
#   'tmax': 24.399999618530273},
#  {'latitude': 43.83829879760742,
#   'longitude': -115.83190155029297,
#   'station': 'USC00104442',
#   'tmax': 38.29999923706055},
#  {'latitude': 64.16999816894531,
#   'longitude': 17.31999969482422,
#   'station': 'SWE00140264',
#   'tmax': 18.799999237060547},
#  {'latitude': -33.72999954223633,
#   'longitude': -65.38700103759766,
#   'station': 'ARM00087448',
#   'tmax': 24.100000381469727},
#  {'latitude': 62.54560089111328,
#   'longitude': 29.67169952392578,
#   'station': 'FIE00144951',
#   'tmax': 20.700000762939453},
#  {'latitude': 40.79169845581055,
#   'longitude': -85.82579803466797,
#   'station': 'USC00129138',
#   'tmax': 27.200000762939453},
#  {'latitude': 41.2682991027832,
#   'longitude': -120.2947006225586,
#   'station': 'USC00044374',
#   'tmax': 35.0},
#  {'latitude': 41.752498626708984,
#   'longitude': -81.29560089111328,
#   'station': 'USC00336389',
#   'tmax': 27.200000762939453},
#  {'latitude': 45.54999923706055,
#   'longitude': -75.55000305175781,
#   'station': 'CA007030170',
#   'tmax': 25.0},
#  {'latitude': 38.82469940185547,
#   'longitude': -106.12750244140625,
#   'station': 'USC00051071',
#   'tmax': 31.100000381469727},
#  {'latitude': 35.61109924316406,
#   'longitude': -93.33329772949219,
#   'station': 'USR0000ADVK',
#   'tmax': 29.399999618530273},
#  {'latitude': -18.533000946044922,
#   'longitude': 25.632999420166016,
#   'station': 'BCM00068030',
#   'tmax': 25.899999618530273},
#  {'latitude': 43.450801849365234,
#   'longitude': -118.22440338134766,
#   'station': 'USC00357208',
#   'tmax': 37.79999923706055},
#  {'latitude': 60.1781005859375,
#   'longitude': 19.98940086364746,
#   'station': 'FIE00141855',
#   'tmax': 19.200000762939453},
#  {'latitude': -12.022000312805176,
#   'longitude': -77.11399841308594,
#   'station': 'PEM00084628',
#   'tmax': 19.0},
#  {'latitude': 43.45000076293945,
#   'longitude': -80.38330078125,
#   'station': 'CA006149387',
#   'tmax': 24.5},
#  {'latitude': 24.95800018310547,
#   'longitude': 46.69900131225586,
#   'station': 'SAM00040437',
#   'tmax': 46.0},
#  {'latitude': 44.900001525878906,
#   'longitude': 110.11699676513672,
#   'station': 'MGM00044354',
#   'tmax': 32.0},
#  {'latitude': 34.093299865722656,
#   'longitude': -110.93329620361328,
#   'station': 'USR0000APLE',
#   'tmax': 36.099998474121094},
#  {'latitude': 43.595001220703125,
#   'longitude': -118.9563980102539,
#   'station': 'USW00094185',
#   'tmax': 35.0},
#  {'latitude': 38.97999954223633,
#   'longitude': 56.279998779296875,
#   'station': 'TX000038763',
#   'tmax': 42.70000076293945},
#  {'latitude': 37.77170181274414,
#   'longitude': -107.10970306396484,
#   'station': 'USC00053951',
#   'tmax': 26.700000762939453},
#  {'latitude': 24.344999313354492,
#   'longitude': 124.18699645996094,
#   'station': 'JAM00047918',
#   'tmax': 28.899999618530273},
#  {'latitude': 42.381099700927734,
#   'longitude': -122.87220001220703,
#   'station': 'USW00024225',
#   'tmax': 35.599998474121094},
#  {'latitude': 53.43330001831055,
#   'longitude': -116.5167007446289,
#   'station': 'CA003065765',
#   'tmax': 19.799999237060547},
#  {'latitude': 43.10060119628906,
#   'longitude': -118.49810028076172,
#   'station': 'USR0000ORID',
#   'tmax': 32.20000076293945},
#  {'latitude': 66.8125,
#   'longitude': -141.6199951171875,
#   'station': 'USR0000ASAL',
#   'tmax': 20.600000381469727},
#  {'latitude': 42.71310043334961,
#   'longitude': -106.34609985351562,
#   'station': 'USR0000WCAS',
#   'tmax': 31.100000381469727},
#  {'latitude': 30.294700622558594,
#   'longitude': -89.38310241699219,
#   'station': 'USC00229426',
#   'tmax': 31.100000381469727},
#  {'latitude': 45.61669921875,
#   'longitude': -61.900001525878906,
#   'station': 'CA008205193',
#   'tmax': 24.899999618530273},
#  {'latitude': 34.618900299072266,
#   'longitude': -89.19110107421875,
#   'station': 'USC00224001',
#   'tmax': 31.100000381469727},
#  {'latitude': 19.283300399780273,
#   'longitude': 166.64999389648438,
#   'station': 'WQW00041606',
#   'tmax': 30.600000381469727},
#  {'latitude': 28.06220054626465,
#   'longitude': -81.75420379638672,
#   'station': 'USW00012876',
#   'tmax': 32.79999923706055},
#  {'latitude': 69.38330078125,
#   'longitude': -81.80000305175781,
#   'station': 'CA002402540',
#   'tmax': 16.0},
#  {'latitude': -20.677799224853516,
#   'longitude': 139.4875030517578,
#   'station': 'ASN00029127',
#   'tmax': 27.600000381469727},
#  {'latitude': 47.75170135498047,
#   'longitude': -90.32830047607422,
#   'station': 'USC00213282',
#   'tmax': 25.0},
#  {'latitude': 45.3036003112793,
#   'longitude': -97.0625,
#   'station': 'USC00398116',
#   'tmax': 27.200000762939453},
#  {'latitude': 38.30830001831055,
#   'longitude': -113.38469696044922,
#   'station': 'USR0000BRIM',
#   'tmax': 37.79999923706055},
#  {'latitude': 65.54309844970703,
#   'longitude': 22.119199752807617,
#   'station': 'SWE00140554',
#   'tmax': 19.799999237060547},
#  {'latitude': 36.569698333740234,
#   'longitude': -104.58670043945312,
#   'station': 'USC00295490',
#   'tmax': 33.900001525878906},
#  {'latitude': 63.45000076293945,
#   'longitude': 48.900001525878906,
#   'station': 'RSM00022695',
#   'tmax': 16.799999237060547},
#  {'latitude': 57.400001525878906,
#   'longitude': 21.533000946044922,
#   'station': 'LG000026314',
#   'tmax': 19.200000762939453},
#  {'latitude': 46.03329849243164,
#   'longitude': -73.11669921875,
#   'station': 'CA007028200',
#   'tmax': 28.0},
#  {'latitude': 43.349998474121094,
#   'longitude': -80.4666976928711,
#   'station': 'CA006147188',
#   'tmax': 25.0},
#  {'latitude': 55.75,
#   'longitude': -120.18329620361328,
#   'station': 'CA001182285',
#   'tmax': 15.100000381469727},
#  {'latitude': 38.88669967651367,
#   'longitude': -102.72329711914062,
#   'station': 'USC00054606',
#   'tmax': 35.0},
#  {'latitude': 57.119998931884766,
#   'longitude': 14.6899995803833,
#   'station': 'SWE00137984',
#   'tmax': 17.799999237060547},
#  {'latitude': 33.715599060058594,
#   'longitude': -117.19000244140625,
#   'station': 'USC00048655',
#   'tmax': 40.0},
#  {'latitude': 44.020599365234375,
#   'longitude': -88.55809783935547,
#   'station': 'USC00476330',
#   'tmax': 28.299999237060547},
#  {'latitude': 40.583900451660156,
#   'longitude': -90.96859741210938,
#   'station': 'USC00114823',
#   'tmax': 31.100000381469727},
#  {'latitude': 42.41939926147461,
#   'longitude': -94.9760971069336,
#   'station': 'USC00137312',
#   'tmax': 28.899999618530273},
#  {'latitude': 42.29999923706055,
#   'longitude': 118.83300018310547,
#   'station': 'CHM00054218',
#   'tmax': 28.899999618530273},
#  {'latitude': 40.54999923706055,
#   'longitude': -123.16500091552734,
#   'station': 'USR0000CHAY',
#   'tmax': 42.20000076293945},
#  {'latitude': 44.423301696777344,
#   'longitude': -118.95939636230469,
#   'station': 'USC00354291',
#   'tmax': 36.099998474121094},
#  {'latitude': 43.67250061035156,
#   'longitude': -92.07469940185547,
#   'station': 'USC00216654',
#   'tmax': 31.100000381469727},
#  {'latitude': 33.62670135498047,
#   'longitude': -100.33689880371094,
#   'station': 'USC00413828',
#   'tmax': 36.70000076293945},
#  {'latitude': 51.54999923706055,
#   'longitude': 23.533000946044922,
#   'station': 'PLM00012497',
#   'tmax': 25.200000762939453},
#  {'latitude': 44.74079895019531,
#   'longitude': -85.5824966430664,
#   'station': 'USW00014850',
#   'tmax': 25.0},
#  {'latitude': 19.31999969482422,
#   'longitude': -98.2300033569336,
#   'station': 'MX000029030',
#   'tmax': 27.0},
#  {'latitude': 42.35580062866211,
#   'longitude': -3.632499933242798,
#   'station': 'SPE00119909',
#   'tmax': 26.399999618530273},
#  {'latitude': 34.20830154418945,
#   'longitude': -112.33329772949219,
#   'station': 'USR0000ACRO',
#   'tmax': 32.79999923706055},
#  {'latitude': 60.19580078125,
#   'longitude': -154.32000732421875,
#   'station': 'USR0000APAL',
#   'tmax': 21.100000381469727},
#  {'latitude': 37.514198303222656,
#   'longitude': -91.19390106201172,
#   'station': 'USC00231101',
#   'tmax': 30.0},
#  {'latitude': -19.741899490356445,
#   'longitude': 120.84359741210938,
#   'station': 'ASN00004019',
#   'tmax': 31.200000762939453},
#  {'latitude': -26.850000381469727,
#   'longitude': -58.31700134277344,
#   'station': 'PAM00086255',
#   'tmax': 26.600000381469727},
#  {'latitude': 53.849998474121094,
#   'longitude': 25.316999435424805,
#   'station': 'BOM00026832',
#   'tmax': 23.399999618530273},
#  {'latitude': -31.650800704956055,
#   'longitude': 116.65859985351562,
#   'station': 'ASN00010111',
#   'tmax': 13.399999618530273},
#  {'latitude': 33.37810134887695,
#   'longitude': -116.83999633789062,
#   'station': 'USC00046657',
#   'tmax': 31.100000381469727},
#  {'latitude': 30.36359977722168,
#   'longitude': -95.08390045166016,
#   'station': 'USC00411810',
#   'tmax': 35.599998474121094},
#  {'latitude': 55.29999923706055,
#   'longitude': 89.81700134277344,
#   'station': 'RSM00029653',
#   'tmax': 21.299999237060547},
#  {'latitude': -24.39299964904785,
#   'longitude': -65.0979995727539,
#   'station': 'ARM00087046',
#   'tmax': 25.399999618530273},
#  {'latitude': 21.933000564575195,
#   'longitude': -99.98300170898438,
#   'station': 'MXM00076581',
#   'tmax': 33.20000076293945},
#  {'latitude': 43.64970016479492,
#   'longitude': -70.30030059814453,
#   'station': 'USW00014764',
#   'tmax': 30.600000381469727},
#  {'latitude': 28.90690040588379,
#   'longitude': -97.87560272216797,
#   'station': 'USC00414696',
#   'tmax': 38.29999923706055},
#  {'latitude': 51.06669998168945,
#   'longitude': -93.80000305175781,
#   'station': 'CA006016975',
#   'tmax': 25.200000762939453},
#  {'latitude': 48.299400329589844,
#   'longitude': 69.69940185546875,
#   'station': 'KZ000035576',
#   'tmax': 32.70000076293945},
#  {'latitude': 61.16669845581055,
#   'longitude': -45.41669845581055,
#   'station': 'GLE00147281',
#   'tmax': 15.5},
#  {'latitude': 28.48940086364746,
#   'longitude': -99.87329864501953,
#   'station': 'USC00411486',
#   'tmax': 38.900001525878906},
#  {'latitude': 45.495601654052734,
#   'longitude': -110.55889892578125,
#   'station': 'USC00245080',
#   'tmax': 30.0},
#  {'latitude': 34.75579833984375,
#   'longitude': -94.98310089111328,
#   'station': 'USR0000OKIA',
#   'tmax': 36.70000076293945},
#  {'latitude': 56.0,
#   'longitude': -116.5999984741211,
#   'station': 'CA003073F4M',
#   'tmax': 21.0},
#  {'latitude': 44.264400482177734,
#   'longitude': -105.49189758300781,
#   'station': 'USC00483855',
#   'tmax': 32.20000076293945},
#  {'latitude': 44.2489013671875,
#   'longitude': -73.98500061035156,
#   'station': 'USC00304555',
#   'tmax': 25.600000381469727},
#  {'latitude': 37.777801513671875,
#   'longitude': -3.807499885559082,
#   'station': 'SPE00120170',
#   'tmax': 33.0},
#  {'latitude': 31.600299835205078,
#   'longitude': -97.21690368652344,
#   'station': 'USC00419417',
#   'tmax': 38.900001525878906},
#  {'latitude': 48.69279861450195,
#   'longitude': -116.310302734375,
#   'station': 'USC00101079',
#   'tmax': 35.0},
#  {'latitude': 53.099998474121094,
#   'longitude': 157.6999969482422,
#   'station': 'RSM00032539',
#   'tmax': 21.5},
#  {'latitude': 32.61140060424805,
#   'longitude': -114.63500213623047,
#   'station': 'USC00029652',
#   'tmax': 41.70000076293945},
#  {'latitude': 39.7327995300293,
#   'longitude': -84.63529968261719,
#   'station': 'USC00332485',
#   'tmax': 28.899999618530273},
#  {'latitude': 53.71670150756836,
#   'longitude': -118.56670379638672,
#   'station': 'CA003060045',
#   'tmax': 10.0},
#  {'latitude': 65.08000183105469,
#   'longitude': -145.8699951171875,
#   'station': 'USS0045Q02S',
#   'tmax': 25.200000762939453},
#  {'latitude': 38.3567008972168,
#   'longitude': -87.5905990600586,
#   'station': 'USC00127125',
#   'tmax': 28.899999618530273},
#  {'latitude': 57.0,
#   'longitude': 82.06999969482422,
#   'station': 'RSM00029328',
#   'tmax': 24.399999618530273},
#  {'latitude': -27.031400680541992,
#   'longitude': 153.46609497070312,
#   'station': 'ASN00040043',
#   'tmax': 18.399999618530273},
#  {'latitude': 31.933000564575195,
#   'longitude': 118.9000015258789,
#   'station': 'CHM00058238',
#   'tmax': 30.100000381469727},
#  {'latitude': 40.09920120239258,
#   'longitude': -83.7822036743164,
#   'station': 'USC00338552',
#   'tmax': 25.0},
#  {'latitude': 29.700000762939453,
#   'longitude': -94.11669921875,
#   'station': 'USR0000TMCF',
#   'tmax': 31.700000762939453},
#  {'latitude': 44.650001525878906,
#   'longitude': -66.83329772949219,
#   'station': 'CA00810M937',
#   'tmax': 17.0},
#  {'latitude': 52.20000076293945,
#   'longitude': 57.400001525878906,
#   'station': 'RSM00035026',
#   'tmax': 34.70000076293945},
#  {'latitude': 17.530000686645508,
#   'longitude': -14.680000305175781,
#   'station': 'MR000001461',
#   'tmax': 36.0},
#  {'latitude': 40.7327995300293,
#   'longitude': -73.61830139160156,
#   'station': 'USC00305377',
#   'tmax': 26.700000762939453},
#  {'latitude': 43.97079849243164,
#   'longitude': -74.2219009399414,
#   'station': 'USC00305714',
#   'tmax': 26.100000381469727},
#  {'latitude': 39.905601501464844,
#   'longitude': -80.75499725341797,
#   'station': 'USC00466248',
#   'tmax': 28.899999618530273},
#  {'latitude': 46.06560134887695,
#   'longitude': 14.516900062561035,
#   'station': 'SIM00014015',
#   'tmax': 24.0},
#  {'latitude': 33.17720031738281,
#   'longitude': -90.49189758300781,
#   'station': 'USC00220660',
#   'tmax': 36.70000076293945},
#  {'latitude': 47.3036003112793,
#   'longitude': -115.0907974243164,
#   'station': 'USC00247318',
#   'tmax': 32.20000076293945},
#  {'latitude': 48.99919891357422,
#   'longitude': -108.38939666748047,
#   'station': 'USC00248415',
#   'tmax': 30.600000381469727},
#  {'latitude': 36.14139938354492,
#   'longitude': -114.72750091552734,
#   'station': 'USC00261371',
#   'tmax': 45.0},
#  {'latitude': 44.58060073852539,
#   'longitude': -101.7406005859375,
#   'station': 'USC00395547',
#   'tmax': 37.79999923706055},
#  {'latitude': 18.12809944152832,
#   'longitude': -66.26419830322266,
#   'station': 'RQC00660158',
#   'tmax': 26.100000381469727},
#  {'latitude': 44.61000061035156,
#   'longitude': -116.9800033569336,
#   'station': 'USS0016E10S',
#   'tmax': 27.100000381469727},
#  {'latitude': 61.709999084472656,
#   'longitude': 16.18000030517578,
#   'station': 'SWE00139674',
#   'tmax': 22.0},
#  {'latitude': 46.18000030517578,
#   'longitude': -113.8499984741211,
#   'station': 'USS0013C39S',
#   'tmax': 26.5},
#  {'latitude': 33.0161018371582,
#   'longitude': -83.94170379638672,
#   'station': 'USC00093506',
#   'tmax': 32.20000076293945},
#  {'latitude': 33.19860076904297,
#   'longitude': -101.37439727783203,
#   'station': 'USC00417206',
#   'tmax': 37.20000076293945},
#  {'latitude': -41.72560119628906,
#   'longitude': 147.07940673828125,
#   'station': 'ASN00091306',
#   'tmax': 16.0},
#  {'latitude': 38.39500045776367,
#   'longitude': -93.77110290527344,
#   'station': 'USC00231711',
#   'tmax': 32.79999923706055},
#  {'latitude': 52.73310089111328,
#   'longitude': 41.46670150756836,
#   'station': 'RSM00027947',
#   'tmax': 26.600000381469727},
#  {'latitude': 58.08330154418945,
#   'longitude': -104.4832992553711,
#   'station': 'CA004061570',
#   'tmax': 26.0},
#  {'latitude': 47.38639831542969,
#   'longitude': -92.83889770507812,
#   'station': 'USW00094931',
#   'tmax': 26.100000381469727},
#  {'latitude': 22.75,
#   'longitude': 90.36699676513672,
#   'station': 'BGM00041950',
#   'tmax': 34.0},
#  {'latitude': 43.51110076904297,
#   'longitude': -102.49690246582031,
#   'station': 'USR0000SWHR',
#   'tmax': 38.900001525878906},
#  {'latitude': 37.685001373291016,
#   'longitude': -92.693603515625,
#   'station': 'USC00234825',
#   'tmax': 31.700000762939453},
#  {'latitude': 40.43109893798828,
#   'longitude': -111.75,
#   'station': 'USR0000PLGV',
#   'tmax': 33.900001525878906},
#  {'latitude': 39.935298919677734,
#   'longitude': -77.63939666748047,
#   'station': 'USC00361354',
#   'tmax': 25.600000381469727},
#  {'latitude': 39.881099700927734,
#   'longitude': -110.26580047607422,
#   'station': 'USR0000FIVE',
#   'tmax': 26.700000762939453},
#  {'latitude': -28.88360023498535,
#   'longitude': 121.3302993774414,
#   'station': 'ASN00012046',
#   'tmax': 18.100000381469727},
#  {'latitude': 34.68080139160156,
#   'longitude': -99.8135986328125,
#   'station': 'USC00344249',
#   'tmax': 40.599998474121094},
#  {'latitude': 35.63750076293945,
#   'longitude': -83.09559631347656,
#   'station': 'USC00311564',
#   'tmax': 27.200000762939453},
#  {'latitude': 41.91389846801758,
#   'longitude': -83.39420318603516,
#   'station': 'USC00205558',
#   'tmax': 22.799999237060547},
#  {'latitude': 44.11669921875,
#   'longitude': -81.0,
#   'station': 'CA006113329',
#   'tmax': 22.0},
#  {'latitude': 45.04999923706055,
#   'longitude': -76.7833023071289,
#   'station': 'CA006105762',
#   'tmax': 23.5},
#  {'latitude': 58.349998474121094,
#   'longitude': 43.382999420166016,
#   'station': 'RSM00027252',
#   'tmax': 19.799999237060547},
#  {'latitude': 48.03559875488281,
#   'longitude': -98.00969696044922,
#   'station': 'USC00327027',
#   'tmax': 26.100000381469727},
#  {'latitude': 45.5525016784668,
#   'longitude': -115.46060180664062,
#   'station': 'USC00102575',
#   'tmax': 26.700000762939453},
#  {'latitude': 45.37670135498047,
#   'longitude': -114.27749633789062,
#   'station': 'USC00108395',
#   'tmax': 33.29999923706055},
#  {'latitude': 41.45109939575195,
#   'longitude': -90.14859771728516,
#   'station': 'USC00113384',
#   'tmax': 25.0},
#  {'latitude': 44.72999954223633,
#   'longitude': -109.91000366210938,
#   'station': 'USS0009E07S',
#   'tmax': 15.600000381469727},
#  {'latitude': 35.41109848022461,
#   'longitude': -80.58329772949219,
#   'station': 'USC00311975',
#   'tmax': 29.399999618530273},
#  {'latitude': 39.18360137939453,
#   'longitude': -120.88469696044922,
#   'station': 'USR0000CSEC',
#   'tmax': 34.400001525878906},
#  {'latitude': 42.31669998168945,
#   'longitude': -74.03309631347656,
#   'station': 'USC00301095',
#   'tmax': 25.0},
#  {'latitude': 41.224700927734375,
#   'longitude': -80.23500061035156,
#   'station': 'USC00365651',
#   'tmax': 24.399999618530273},
#  {'latitude': -1.3170000314712524,
#   'longitude': 36.91699981689453,
#   'station': 'KE000063740',
#   'tmax': 23.600000381469727},
#  {'latitude': -16.418100357055664,
#   'longitude': 126.10250091552734,
#   'station': 'ASN00001018',
#   'tmax': 29.299999237060547},
#  {'latitude': 29.316699981689453,
#   'longitude': -100.41439819335938,
#   'station': 'USC00411007',
#   'tmax': 31.700000762939453},
#  {'latitude': 50.93330001831055,
#   'longitude': -120.80000305175781,
#   'station': 'CA001166658',
#   'tmax': 28.0},
#  {'latitude': 30.747800827026367,
#   'longitude': -99.23059844970703,
#   'station': 'USC00415650',
#   'tmax': 36.70000076293945},
#  {'latitude': 57.79999923706055,
#   'longitude': 35.900001525878906,
#   'station': 'RSM00027208',
#   'tmax': 19.899999618530273},
#  {'latitude': 55.16699981689453,
#   'longitude': 34.400001525878906,
#   'station': 'RSM00026695',
#   'tmax': 21.100000381469727},
#  {'latitude': 19.75,
#   'longitude': -14.380000114440918,
#   'station': 'MR000001437',
#   'tmax': 37.900001525878906},
#  {'latitude': 39.72330093383789,
#   'longitude': -91.37190246582031,
#   'station': 'USC00233601',
#   'tmax': 26.700000762939453},
#  {'latitude': 56.43330001831055,
#   'longitude': -118.0167007446289,
#   'station': 'CA003077480',
#   'tmax': 27.0},
#  {'latitude': 12.352999687194824,
#   'longitude': -1.5119999647140503,
#   'station': 'UVM00065503',
#   'tmax': 32.79999923706055},
#  {'latitude': 40.22999954223633,
#   'longitude': -106.5999984741211,
#   'station': 'USS0006J18S',
#   'tmax': 22.5},
#  {'latitude': 46.5,
#   'longitude': -65.2667007446289,
#   'station': 'CA008102151',
#   'tmax': 25.0},
#  {'latitude': 46.56669998168945,
#   'longitude': -121.63059997558594,
#   'station': 'USR0000WHAG',
#   'tmax': 27.799999237060547},
#  {'latitude': 43.91669845581055,
#   'longitude': -79.83329772949219,
#   'station': 'CA006150103',
#   'tmax': 25.0},
#  {'latitude': 49.21670150756836,
#   'longitude': -119.81670379638672,
#   'station': 'CA001124112',
#   'tmax': 35.5},
#  {'latitude': 39.48720169067383,
#   'longitude': -75.22000122070312,
#   'station': 'USC00287936',
#   'tmax': 28.899999618530273},
#  {'latitude': 60.243900299072266,
#   'longitude': 24.052499771118164,
#   'station': 'FIE00142106',
#   'tmax': 21.0},
#  {'latitude': 35.184200286865234,
#   'longitude': -105.05690002441406,
#   'station': 'USC00292510',
#   'tmax': 35.0},
#  {'latitude': 63.516700744628906,
#   'longitude': -116.0,
#   'station': 'CA002203700',
#   'tmax': 29.299999237060547},
#  {'latitude': 46.90999984741211,
#   'longitude': -121.4800033569336,
#   'station': 'USS0021C17S',
#   'tmax': 20.799999237060547},
#  {'latitude': 30.0,
#   'longitude': 100.26699829101562,
#   'station': 'CHM00056257',
#   'tmax': 14.399999618530273},
#  {'latitude': 23.18400001525879,
#   'longitude': 89.16100311279297,
#   'station': 'BGM00041936',
#   'tmax': 37.0},
#  {'latitude': 38.958099365234375,
#   'longitude': -89.09529876708984,
#   'station': 'USC00118781',
#   'tmax': 28.299999237060547},
#  {'latitude': 60.59560012817383,
#   'longitude': 24.806400299072266,
#   'station': 'FIE00142751',
#   'tmax': 21.799999237060547},
#  {'latitude': 66.2667007446289,
#   'longitude': -146.51669311523438,
#   'station': 'USR0000ABEV',
#   'tmax': 17.799999237060547},
#  {'latitude': 34.34469985961914,
#   'longitude': -108.49220275878906,
#   'station': 'USC00297180',
#   'tmax': 31.100000381469727},
#  {'latitude': -31.54199981689453,
#   'longitude': 159.07899475097656,
#   'station': 'ASM00094995',
#   'tmax': 18.299999237060547},
#  {'latitude': 38.80080032348633,
#   'longitude': -81.3582992553711,
#   'station': 'USC00468384',
#   'tmax': 26.700000762939453},
#  {'latitude': -32.78860092163086,
#   'longitude': 151.33770751953125,
#   'station': 'ASN00061260',
#   'tmax': 17.700000762939453},
#  {'latitude': 40.6171989440918,
#   'longitude': -109.2427978515625,
#   'station': 'USR0000DIAM',
#   'tmax': 25.600000381469727},
#  {'latitude': 34.62689971923828,
#   'longitude': -79.0250015258789,
#   'station': 'USC00315177',
#   'tmax': 28.299999237060547},
#  {'latitude': 64.85690307617188,
#   'longitude': -147.86109924316406,
#   'station': 'USC00509641',
#   'tmax': 15.600000381469727},
#  {'latitude': 43.561100006103516,
#   'longitude': -120.24859619140625,
#   'station': 'USR0000OBRO',
#   'tmax': 32.20000076293945},
#  {'latitude': 36.54999923706055,
#   'longitude': 139.86700439453125,
#   'station': 'JA000047615',
#   'tmax': 32.79999923706055},
#  {'latitude': 45.590599060058594,
#   'longitude': -123.4760971069336,
#   'station': 'USR0000OSFK',
#   'tmax': 26.100000381469727},
#  {'latitude': 47.12919998168945,
#   'longitude': -115.875,
#   'station': 'USR0000IFIS',
#   'tmax': 30.0},
#  {'latitude': 40.81330108642578,
#   'longitude': -113.19999694824219,
#   'station': 'USC00424748',
#   'tmax': 34.400001525878906},
#  {'latitude': 51.33330154418945,
#   'longitude': -56.68330001831055,
#   'station': 'CA008401583',
#   'tmax': 20.0},
#  {'latitude': 42.96699905395508,
#   'longitude': 54.117000579833984,
#   'station': 'KZ000038232',
#   'tmax': 38.099998474121094},
#  {'latitude': 57.09299850463867,
#   'longitude': 9.848999977111816,
#   'station': 'DAM00006030',
#   'tmax': 17.5},
#  {'latitude': 45.11000061035156,
#   'longitude': -119.5,
#   'station': 'USS0019D03S',
#   'tmax': 27.5},
#  {'latitude': 48.40359878540039,
#   'longitude': -115.53919982910156,
#   'station': 'USC00245015',
#   'tmax': 35.599998474121094},
#  {'latitude': 41.01639938354492,
#   'longitude': -93.2791976928711,
#   'station': 'USC00131394',
#   'tmax': 30.600000381469727},
#  {'latitude': 45.599998474121094,
#   'longitude': 84.8499984741211,
#   'station': 'CHM00051243',
#   'tmax': 36.29999923706055},
#  {'latitude': 56.849998474121094,
#   'longitude': 13.880000114440918,
#   'station': 'SWE00137890',
#   'tmax': 18.700000762939453},
#  {'latitude': 40.01359939575195,
#   'longitude': -101.94080352783203,
#   'station': 'USC00253515',
#   'tmax': 34.400001525878906},
#  {'latitude': 48.766700744628906,
#   'longitude': -123.2833023071289,
#   'station': 'CA001015638',
#   'tmax': 21.5},
#  {'latitude': 42.33330154418945,
#   'longitude': -82.93329620361328,
#   'station': 'CA006139520',
#   'tmax': 30.0},
#  {'latitude': 35.60419845581055,
#   'longitude': -91.27439880371094,
#   'station': 'USC00035186',
#   'tmax': 34.400001525878906},
#  {'latitude': 37.529998779296875,
#   'longitude': -110.72029876708984,
#   'station': 'USC00421020',
#   'tmax': 38.900001525878906},
#  {'latitude': 34.978599548339844,
#   'longitude': -85.80079650878906,
#   'station': 'USC00011099',
#   'tmax': 33.29999923706055},
#  {'latitude': 56.96670150756836,
#   'longitude': -119.55000305175781,
#   'station': 'CA003072093',
#   'tmax': 20.0},
#  {'latitude': 50.21670150756836,
#   'longitude': -5.316699981689453,
#   'station': 'UK000003808',
#   'tmax': 21.100000381469727},
#  {'latitude': 33.52579879760742,
#   'longitude': -89.97309875488281,
#   'station': 'USR0000MRDG',
#   'tmax': 38.29999923706055},
#  {'latitude': 35.381099700927734,
#   'longitude': -120.1875,
#   'station': 'USR0000CLAP',
#   'tmax': 38.29999923706055},
#  {'latitude': 38.18470001220703,
#   'longitude': -84.9032974243164,
#   'station': 'USW00053841',
#   'tmax': 32.20000076293945},
#  {'latitude': 49.38330078125,
#   'longitude': -126.55000305175781,
#   'station': 'CA001032730',
#   'tmax': 17.5},
#  {'latitude': 35.23529815673828,
#   'longitude': -92.36190032958984,
#   'station': 'USC00032962',
#   'tmax': 37.79999923706055},
#  {'latitude': 35.43220138549805,
#   'longitude': -84.58329772949219,
#   'station': 'USC00400284',
#   'tmax': 32.20000076293945},
#  {'latitude': 43.357200622558594,
#   'longitude': -121.05169677734375,
#   'station': 'USC00353029',
#   'tmax': 33.900001525878906},
#  {'latitude': 26.0718994140625,
#   'longitude': -80.15360260009766,
#   'station': 'USW00012849',
#   'tmax': 31.100000381469727},
#  {'latitude': 43.766700744628906,
#   'longitude': -99.31829833984375,
#   'station': 'USW00094943',
#   'tmax': 31.700000762939453},
#  {'latitude': 31.09440040588379,
#   'longitude': -86.54859924316406,
#   'station': 'USR0000AOPE',
#   'tmax': 35.599998474121094},
#  {'latitude': 35.099998474121094,
#   'longitude': 129.0330047607422,
#   'station': 'KSM00047159',
#   'tmax': 30.5},
#  {'latitude': 53.45000076293945,
#   'longitude': -115.86669921875,
#   'station': 'CA003061360',
#   'tmax': 19.0},
#  {'latitude': 46.72809982299805,
#   'longitude': -116.95580291748047,
#   'station': 'USC00106152',
#   'tmax': 32.20000076293945},
#  {'latitude': 47.16939926147461,
#   'longitude': -122.00360107421875,
#   'station': 'USC00450945',
#   'tmax': 28.899999618530273},
#  {'latitude': 45.95000076293945,
#   'longitude': -73.58329772949219,
#   'station': 'CA007017380',
#   'tmax': 25.0},
#  {'latitude': 61.36669921875,
#   'longitude': -139.0500030517578,
#   'station': 'CA002100182',
#   'tmax': 14.5},
#  {'latitude': 32.014198303222656,
#   'longitude': -85.74639892578125,
#   'station': 'USC00018438',
#   'tmax': 35.0},
#  {'latitude': 52.380001068115234,
#   'longitude': 140.47000122070312,
#   'station': 'RSM00031439',
#   'tmax': 23.299999237060547},
#  {'latitude': 20.132999420166016,
#   'longitude': 92.87300109863281,
#   'station': 'BMM00048062',
#   'tmax': 30.0},
#  {'latitude': 57.84000015258789,
#   'longitude': 14.430000305175781,
#   'station': 'SWE00138258',
#   'tmax': 16.299999237060547},
#  {'latitude': 20.66699981689453,
#   'longitude': 58.900001525878906,
#   'station': 'MU000041288',
#   'tmax': 31.299999237060547},
#  {'latitude': 35.07059860229492,
#   'longitude': -108.83889770507812,
#   'station': 'USW00093044',
#   'tmax': 35.0},
#  {'latitude': 39.729400634765625,
#   'longitude': -105.00830078125,
#   'station': 'USC00052223',
#   'tmax': 35.0},
#  {'latitude': 56.25,
#   'longitude': -96.0999984741211,
#   'station': 'CA005062751',
#   'tmax': 24.5},
#  {'latitude': 35.21500015258789,
#   'longitude': -100.25029754638672,
#   'station': 'USC00418236',
#   'tmax': 36.099998474121094},
#  {'latitude': 41.57469940185547,
#   'longitude': -90.40059661865234,
#   'station': 'USC00134705',
#   'tmax': 33.29999923706055},
#  {'latitude': 37.35419845581055,
#   'longitude': -84.33689880371094,
#   'station': 'USC00155648',
#   'tmax': 31.700000762939453},
#  {'latitude': 31.962200164794922,
#   'longitude': -95.27359771728516,
#   'station': 'USC00414525',
#   'tmax': 37.79999923706055},
#  {'latitude': 37.409400939941406,
#   'longitude': -119.76809692382812,
#   'station': 'USR0000CMET',
#   'tmax': 36.099998474121094},
#  {'latitude': 42.62329864501953,
#   'longitude': -106.35669708251953,
#   'station': 'USC00480552',
#   'tmax': 30.0},
#  {'latitude': 21.950000762939453,
#   'longitude': 108.61699676513672,
#   'station': 'CHM00059632',
#   'tmax': 30.700000762939453},
#  {'latitude': 68.55000305175781,
#   'longitude': 55.5,
#   'station': 'RSM00023114',
#   'tmax': 13.699999809265137},
#  {'latitude': 40.43830108642578,
#   'longitude': -109.30690002441406,
#   'station': 'USC00422173',
#   'tmax': 35.599998474121094},
#  {'latitude': 58.20000076293945,
#   'longitude': -118.2166976928711,
#   'station': 'CA0030705LQ',
#   'tmax': 16.0},
#  {'latitude': -31.95560073852539,
#   'longitude': 115.79280090332031,
#   'station': 'ASN00009151',
#   'tmax': 17.5},
#  {'latitude': 55.33330154418945,
#   'longitude': -110.19999694824219,
#   'station': 'CA003067590',
#   'tmax': 17.0},
#  {'latitude': 46.485801696777344,
#   'longitude': -90.43720245361328,
#   'station': 'USC00473332',
#   'tmax': 25.600000381469727},
#  {'latitude': 20.7007999420166,
#   'longitude': -156.35609436035156,
#   'station': 'USC00515004',
#   'tmax': 23.899999618530273},
#  {'latitude': 46.29859924316406,
# ...
#   'longitude': -110.08999633789062,
#   'station': 'USS0010D24S',
#   'tmax': 17.600000381469727},
#  {'latitude': 40.632999420166016,
#   'longitude': 87.69999694824219,
#   'station': 'CHM00051765',
#   'tmax': 33.400001525878906},
#  {'latitude': -31.570999145507812,
#   'longitude': -68.41799926757812,
#   'station': 'ARM00087311',
#   'tmax': 13.600000381469727},
#  {'latitude': 37.9994010925293,
#   'longitude': -121.31780242919922,
#   'station': 'USC00048560',
#   'tmax': 31.700000762939453},
#  {'latitude': -50.33300018310547,
#   'longitude': -72.30000305175781,
#   'station': 'ARM00087903',
#   'tmax': 4.800000190734863},
#  {'latitude': 41.27000045776367,
#   'longitude': 69.26940155029297,
#   'station': 'UZM00038457',
#   'tmax': 34.599998474121094},
#  {'latitude': 54.46670150756836,
#   'longitude': -116.41670227050781,
#   'station': 'CA003062150',
#   'tmax': 17.5},
#  {'latitude': 36.10749816894531,
#   'longitude': -85.50330352783203,
#   'station': 'USC00402009',
#   'tmax': 26.700000762939453},
#  {'latitude': 43.12110137939453,
#   'longitude': -117.03919982910156,
#   'station': 'USC00357736',
#   'tmax': 27.200000762939453},
#  {'latitude': 32.7047004699707,
#   'longitude': -108.72810363769531,
#   'station': 'USC00297340',
#   'tmax': 35.599998474121094},
#  {'latitude': 63.435298919677734,
#   'longitude': 21.068099975585938,
#   'station': 'FIE00144222',
#   'tmax': 18.5},
#  {'latitude': 46.13999938964844,
#   'longitude': -114.51000213623047,
#   'station': 'USS0014C12S',
#   'tmax': 18.700000762939453},
#  {'latitude': 41.71390151977539,
#   'longitude': -113.86940002441406,
#   'station': 'USC00423486',
#   'tmax': 27.799999237060547},
#  {'latitude': 33.02859878540039,
#   'longitude': -84.73500061035156,
#   'station': 'USC00093915',
#   'tmax': 35.599998474121094},
#  {'latitude': 53.849998474121094,
#   'longitude': -115.9666976928711,
#   'station': 'CA003065885',
#   'tmax': 21.0},
#  {'latitude': 50.28310012817383,
#   'longitude': 57.150001525878906,
#   'station': 'KZ000035229',
#   'tmax': 24.600000381469727},
#  {'latitude': 10.25,
#   'longitude': -67.6500015258789,
#   'station': 'VE000080413',
#   'tmax': 29.600000381469727},
#  {'latitude': 50.266700744628906,
#   'longitude': -107.7332992553711,
#   'station': 'CA004028060',
#   'tmax': 28.0},
#  {'latitude': 40.44029998779297,
#   'longitude': -114.81109619140625,
#   'station': 'USR0000NSPM',
#   'tmax': 31.700000762939453},
#  {'latitude': 43.0,
#   'longitude': -82.30000305175781,
#   'station': 'CA006127514',
#   'tmax': 25.700000762939453},
#  {'latitude': 37.96670150756836,
#   'longitude': 58.333099365234375,
#   'station': 'TX000038880',
#   'tmax': 38.099998474121094},
#  {'latitude': 28.61639976501465,
#   'longitude': -82.36579895019531,
#   'station': 'USC00081046',
#   'tmax': 33.29999923706055},
#  {'latitude': 45.08000183105469,
#   'longitude': -117.55000305175781,
#   'station': 'USS0017D07S',
#   'tmax': 25.600000381469727},
#  {'latitude': 6.793000221252441,
#   'longitude': -6.4730000495910645,
#   'station': 'IVM00065560',
#   'tmax': 29.899999618530273},
#  {'latitude': -36.16469955444336,
#   'longitude': 144.7642059326172,
#   'station': 'ASN00080015',
#   'tmax': 14.5},
#  {'latitude': 41.15999984741211,
#   'longitude': -106.93000030517578,
#   'station': 'USS0006H09S',
#   'tmax': 21.200000762939453},
#  {'latitude': 45.88330078125,
#   'longitude': -72.4832992553711,
#   'station': 'CA007022160',
#   'tmax': 23.0},
#  {'latitude': 62.534400939941406,
#   'longitude': 24.220600128173828,
#   'station': 'FIE00144482',
#   'tmax': 16.0},
#  {'latitude': -40.99720001220703,
#   'longitude': 145.7292022705078,
#   'station': 'ASN00091107',
#   'tmax': 11.800000190734863},
#  {'latitude': 51.0,
#   'longitude': -105.5167007446289,
#   'station': 'CA004013270',
#   'tmax': 28.0},
#  {'latitude': -23.869699478149414,
#   'longitude': 151.22140502929688,
#   'station': 'ASN00039326',
#   'tmax': 23.200000762939453},
#  {'latitude': 57.939998626708984,
#   'longitude': 13.069999694824219,
#   'station': 'SWE00138306',
#   'tmax': 17.0},
#  {'latitude': 43.10169982910156,
#   'longitude': -93.80139923095703,
#   'station': 'USC00130923',
#   'tmax': 20.0},
#  {'latitude': 29.78529930114746,
#   'longitude': -90.11579895019531,
#   'station': 'USC00165926',
#   'tmax': 34.400001525878906},
#  {'latitude': -4.192999839782715,
#   'longitude': -69.94300079345703,
#   'station': 'COM00080398',
#   'tmax': 31.799999237060547},
#  {'latitude': 48.632999420166016,
#   'longitude': 58.5,
#   'station': 'KZ000035532',
#   'tmax': 24.100000381469727},
#  {'latitude': 51.03329849243164,
#   'longitude': -115.0333023071289,
#   'station': 'CA003053600',
#   'tmax': 25.5},
#  {'latitude': 29.460800170898438,
#   'longitude': -101.02860260009766,
#   'station': 'USC00410225',
#   'tmax': 37.20000076293945},
#  {'latitude': 50.38330078125,
#   'longitude': -102.68329620361328,
#   'station': 'CA00401I010',
#   'tmax': 24.299999237060547},
#  {'latitude': 67.1500015258789,
#   'longitude': 32.349998474121094,
#   'station': 'RSM00022217',
#   'tmax': 15.100000381469727},
#  {'latitude': -34.94139862060547,
#   'longitude': 117.80220031738281,
#   'station': 'ASN00009741',
#   'tmax': 13.699999809265137},
#  {'latitude': 55.380001068115234,
#   'longitude': -131.4683074951172,
#   'station': 'USC00500657',
#   'tmax': 15.600000381469727},
#  {'latitude': 38.22439956665039,
#   'longitude': -109.2782974243164,
#   'station': 'USR0000BIGI',
#   'tmax': 26.700000762939453},
#  {'latitude': 45.29999923706055,
#   'longitude': -74.05000305175781,
#   'station': 'CA007014290',
#   'tmax': 23.5},
#  {'latitude': 65.59970092773438,
#   'longitude': 19.270000457763672,
#   'station': 'SWE00140562',
#   'tmax': 15.800000190734863},
#  {'latitude': 40.15999984741211,
#   'longitude': -111.20999908447266,
#   'station': 'USS0011J08S',
#   'tmax': 22.600000381469727},
#  {'latitude': 12.069999694824219,
#   'longitude': 0.3499999940395355,
#   'station': 'UV000005507',
#   'tmax': 31.200000762939453},
#  {'latitude': 61.1781005859375,
#   'longitude': -149.96640014648438,
#   'station': 'USW00026491',
#   'tmax': 15.600000381469727},
#  {'latitude': -16.288000106811523,
#   'longitude': 149.96499633789062,
#   'station': 'ASM00094299',
#   'tmax': 26.700000762939453},
#  {'latitude': 47.08330154418945,
#   'longitude': -70.7833023071289,
#   'station': 'CA007041JG6',
#   'tmax': 24.399999618530273},
#  {'latitude': 36.79499816894531,
#   'longitude': -108.69170379638672,
#   'station': 'USC00298284',
#   'tmax': 33.29999923706055},
#  {'latitude': -32.20280075073242,
#   'longitude': 127.52970123291016,
#   'station': 'ASN00011053',
#   'tmax': 14.0},
#  {'latitude': -2.549999952316284,
#   'longitude': 120.36699676513672,
#   'station': 'IDM00097126',
#   'tmax': 32.20000076293945},
#  {'latitude': 39.6953010559082,
#   'longitude': -106.97309875488281,
#   'station': 'USR0000CGYP',
#   'tmax': 24.399999618530273},
#  {'latitude': 32.1432991027832,
#   'longitude': -89.55249786376953,
#   'station': 'USC00227276',
#   'tmax': 37.20000076293945},
#  {'latitude': -28.877500534057617,
#   'longitude': 153.052001953125,
#   'station': 'ASN00058208',
#   'tmax': 23.5},
#  {'latitude': 47.792198181152344,
#   'longitude': -111.22029876708984,
#   'station': 'USC00241525',
#   'tmax': 31.700000762939453},
#  {'latitude': 36.13529968261719,
#   'longitude': -115.42720031738281,
#   'station': 'USR0000NRER',
#   'tmax': 35.0},
#  {'latitude': 34.60530090332031,
#   'longitude': -81.66310119628906,
#   'station': 'USC00388786',
#   'tmax': 25.600000381469727},
#  {'latitude': 26.2189998626709,
#   'longitude': 68.38999938964844,
#   'station': 'PKM00041749',
#   'tmax': 41.099998474121094},
#  {'latitude': 41.04439926147461,
#   'longitude': -74.29329681396484,
#   'station': 'USC00289187',
#   'tmax': 25.0},
#  {'latitude': 19.735599517822266,
#   'longitude': -156.0489044189453,
#   'station': 'USW00021510',
#   'tmax': 30.0},
#  {'latitude': 32.572200775146484,
#   'longitude': -116.97940063476562,
#   'station': 'USW00003178',
#   'tmax': 25.0},
#  {'latitude': 38.4536018371582,
#   'longitude': -82.61309814453125,
#   'station': 'USC00150254',
#   'tmax': 30.0},
#  {'latitude': 69.05889892578125,
#   'longitude': 18.540300369262695,
#   'station': 'NOE00109394',
#   'tmax': 12.600000381469727},
#  {'latitude': 36.59280014038086,
#   'longitude': -121.85559844970703,
#   'station': 'USC00045802',
#   'tmax': 21.100000381469727},
#  {'latitude': 35.06999969482422,
#   'longitude': -104.25749969482422,
#   'station': 'USC00296115',
#   'tmax': 31.700000762939453},
#  {'latitude': 16.433000564575195,
#   'longitude': 102.83300018310547,
#   'station': 'TH000048381',
#   'tmax': 30.399999618530273},
#  {'latitude': 34.47439956665039,
#   'longitude': -91.41719818115234,
#   'station': 'USC00036920',
#   'tmax': 37.79999923706055},
#  {'latitude': 55.53329849243164,
#   'longitude': -122.4832992553711,
#   'station': 'CA001186A71',
#   'tmax': 20.0},
#  {'latitude': 31.37809944152832,
#   'longitude': -82.12920379638672,
#   'station': 'USC00096838',
#   'tmax': 36.099998474121094},
#  {'latitude': 46.00809860229492,
#   'longitude': -114.84420013427734,
#   'station': 'USC00108246',
#   'tmax': 31.700000762939453},
#  {'latitude': 56.470001220703125,
#   'longitude': 53.72999954223633,
#   'station': 'RSM00028418',
#   'tmax': 18.200000762939453},
#  {'latitude': 15.333000183105469,
#   'longitude': -1.6829999685287476,
#   'station': 'MLM00061240',
#   'tmax': 33.5},
#  {'latitude': 42.48440170288086,
#   'longitude': -120.2822036743164,
#   'station': 'USC00358812',
#   'tmax': 32.20000076293945},
#  {'latitude': 18.32360076904297,
#   'longitude': -64.85420227050781,
#   'station': 'VQC00677600',
#   'tmax': 30.600000381469727},
#  {'latitude': 40.60919952392578,
#   'longitude': -96.87190246582031,
#   'station': 'USC00252020',
#   'tmax': 32.79999923706055},
#  {'latitude': 40.54999923706055,
#   'longitude': 65.68299865722656,
#   'station': 'UZM00038565',
#   'tmax': 32.400001525878906},
#  {'latitude': -33.46699905395508,
#   'longitude': 18.716999053955078,
#   'station': 'SF000414170',
#   'tmax': 21.299999237060547},
#  {'latitude': 56.900001525878906,
#   'longitude': 93.13300323486328,
#   'station': 'RSM00029471',
#   'tmax': 20.899999618530273},
#  {'latitude': -37.67499923706055,
#   'longitude': 144.84190368652344,
#   'station': 'ASN00086384',
#   'tmax': 12.600000381469727},
#  {'latitude': 14.467000007629395,
#   'longitude': 100.13300323486328,
#   'station': 'TH000048425',
#   'tmax': 29.299999237060547},
#  {'latitude': 32.36000061035156,
#   'longitude': -89.4207992553711,
#   'station': 'USC00223107',
#   'tmax': 34.400001525878906},
#  {'latitude': 32.71670150756836,
#   'longitude': -95.36669921875,
#   'station': 'USC00415956',
#   'tmax': 37.79999923706055},
#  {'latitude': 46.069698333740234,
#   'longitude': -114.55000305175781,
#   'station': 'USR0000IMOO',
#   'tmax': 38.900001525878906},
#  {'latitude': 46.18330001831055,
#   'longitude': -77.6500015258789,
#   'station': 'CA006107182',
#   'tmax': 19.0},
#  {'latitude': 46.48080062866211,
#   'longitude': -96.28690338134766,
#   'station': 'USC00217149',
#   'tmax': 26.700000762939453},
#  {'latitude': 0.06400000303983688,
#   'longitude': 111.4729995727539,
#   'station': 'IDM00096559',
#   'tmax': 33.20000076293945},
#  {'latitude': 54.09939956665039,
#   'longitude': 61.59939956665039,
#   'station': 'RSM00028748',
#   'tmax': 21.399999618530273},
#  {'latitude': 34.11579895019531,
#   'longitude': -113.34719848632812,
#   'station': 'USR0000ASMI',
#   'tmax': 35.0},
#  {'latitude': 54.5,
#   'longitude': 134.41969299316406,
#   'station': 'RSM00031285',
#   'tmax': 21.299999237060547},
#  {'latitude': 47.58330154418945,
#   'longitude': -58.96670150756836,
#   'station': 'CA008402450',
#   'tmax': 19.5},
#  {'latitude': 60.71670150756836,
#   'longitude': -135.03329467773438,
#   'station': 'CA002101400',
#   'tmax': 15.0},
#  {'latitude': 54.233299255371094,
#   'longitude': -115.0167007446289,
#   'station': 'CA003064657',
#   'tmax': 24.5},
#  {'latitude': 32.844200134277344,
#   'longitude': -81.12439727783203,
#   'station': 'USC00383906',
#   'tmax': 32.20000076293945},
#  {'latitude': -44.516998291015625,
#   'longitude': 169.89999389648438,
#   'station': 'NZ000937470',
#   'tmax': 4.800000190734863},
#  {'latitude': 43.16529846191406,
#   'longitude': -95.14669799804688,
#   'station': 'USC00137844',
#   'tmax': 28.899999618530273},
#  {'latitude': 42.739200592041016,
#   'longitude': -78.58779907226562,
#   'station': 'USC00308910',
#   'tmax': 21.700000762939453},
#  {'latitude': 43.42580032348633,
#   'longitude': -103.75890350341797,
#   'station': 'USR0000SRED',
#   'tmax': 36.099998474121094},
#  {'latitude': 30.204999923706055,
#   'longitude': -91.98750305175781,
#   'station': 'USW00013976',
#   'tmax': 33.29999923706055},
#  {'latitude': 44.77640151977539,
#   'longitude': -108.75920104980469,
#   'station': 'USC00487388',
#   'tmax': 33.900001525878906},
#  {'latitude': -17.67060089111328,
#   'longitude': 141.06719970703125,
#   'station': 'ASN00029041',
#   'tmax': 29.200000762939453},
#  {'latitude': 33.05830001831055,
#   'longitude': -89.57969665527344,
#   'station': 'USC00224776',
#   'tmax': 35.599998474121094},
#  {'latitude': 43.72999954223633,
#   'longitude': -87.97139739990234,
#   'station': 'USC00476678',
#   'tmax': 26.700000762939453},
#  {'latitude': 39.871700286865234,
#   'longitude': -121.61080169677734,
#   'station': 'USC00042402',
#   'tmax': 31.700000762939453},
#  {'latitude': 54.18170166015625,
#   'longitude': 12.081899642944336,
#   'station': 'GME00102212',
#   'tmax': 17.600000381469727},
#  {'latitude': 73.33000183105469,
#   'longitude': 70.02940368652344,
#   'station': 'RSM00020667',
#   'tmax': 6.699999809265137},
#  {'latitude': -16.451400756835938,
#   'longitude': 123.00859832763672,
#   'station': 'ASN00003057',
#   'tmax': 30.5},
#  {'latitude': 32.32500076293945,
#   'longitude': -109.49169921875,
#   'station': 'USC00020958',
#   'tmax': 34.400001525878906},
#  {'latitude': 38.88529968261719,
#   'longitude': -79.85279846191406,
#   'station': 'USW00013729',
#   'tmax': 21.700000762939453},
#  {'latitude': 35.01279830932617,
#   'longitude': -78.00440216064453,
#   'station': 'USC00319081',
#   'tmax': 30.0},
#  {'latitude': 37.75,
#   'longitude': -119.5896987915039,
#   'station': 'USC00049855',
#   'tmax': 30.600000381469727},
#  {'latitude': 56.29999923706055,
#   'longitude': -121.0167007446289,
#   'station': 'CA0011814FR',
#   'tmax': 20.0},
#  {'latitude': 32.650001525878906,
#   'longitude': 103.56700134277344,
#   'station': 'CHM00056182',
#   'tmax': 19.600000381469727},
#  {'latitude': 31.767200469970703,
#   'longitude': -84.79309844970703,
#   'station': 'USC00092450',
#   'tmax': 33.900001525878906},
#  {'latitude': 38.377201080322266,
#   'longitude': -97.60970306396484,
#   'station': 'USC00145152',
#   'tmax': 40.0},
#  {'latitude': 39.3036003112793,
#   'longitude': -121.11720275878906,
#   'station': 'USR0000CDOR',
#   'tmax': 35.0},
#  {'latitude': 36.54719924926758,
#   'longitude': -87.33529663085938,
#   'station': 'USC00401790',
#   'tmax': 29.399999618530273},
#  {'latitude': 35.729698181152344,
#   'longitude': -81.67279815673828,
#   'station': 'USC00315838',
#   'tmax': 32.20000076293945},
#  {'latitude': 33.83140182495117,
#   'longitude': -79.05580139160156,
#   'station': 'USC00381997',
#   'tmax': 30.600000381469727},
#  {'latitude': 43.274200439453125,
#   'longitude': -91.47109985351562,
#   'station': 'USC00138755',
#   'tmax': 27.799999237060547},
#  {'latitude': 40.50859832763672,
#   'longitude': -108.91059875488281,
#   'station': 'USR0000CDIN',
#   'tmax': 30.600000381469727},
#  {'latitude': 44.87110137939453,
#   'longitude': -104.1532974243164,
#   'station': 'USC00481905',
#   'tmax': 40.0},
#  {'latitude': 43.600799560546875,
#   'longitude': -114.31580352783203,
#   'station': 'USR0000IOHI',
#   'tmax': 28.899999618530273},
#  {'latitude': 42.5099983215332,
#   'longitude': -110.91000366210938,
#   'station': 'USS0010G08S',
#   'tmax': 23.600000381469727},
#  {'latitude': 40.535301208496094,
#   'longitude': -112.32170104980469,
#   'station': 'USC00428771',
#   'tmax': 34.400001525878906},
#  {'latitude': 58.06999969482422,
#   'longitude': 15.239999771118164,
#   'station': 'SWE00138338',
#   'tmax': 13.199999809265137},
#  {'latitude': 48.349998474121094,
#   'longitude': -54.16669845581055,
#   'station': 'CA008403008',
#   'tmax': 23.0},
#  {'latitude': 44.67190170288086,
#   'longitude': -117.99420166015625,
#   'station': 'USC00355258',
#   'tmax': 31.100000381469727},
#  {'latitude': 36.99530029296875,
#   'longitude': -111.49140167236328,
#   'station': 'USC00029114',
#   'tmax': 35.599998474121094},
#  ...]

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

# %% [markdown]
# ## Map for Year 2000

# %%
plt.figure(figsize=(16,12))

eq_map = Basemap(projection='cyl', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=0)
# eq_map.drawcoastlines()
# eq_map.drawcountries()
eq_map.fillcontinents(color = '#202020', lake_color='#3b3b3b', zorder=0.5)
eq_map.drawmapboundary(fill_color='#3b3b3b')
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))

lat = []
lon = []
val = []

for y in reduced_data['2000_2001']:
    lon.append(y['longitude'])
    lat.append(y['latitude'])
    val.append(y['tmax'])

x, y = eq_map(lon, lat)

cs = eq_map.scatter(x, y, c=val, marker="o", cmap=cm.bwr)
# add colorbar.
cbar = eq_map.colorbar(cs,location='bottom',pad="5%")
cbar.set_label('Max Temperature (in Celcius)')
plt.title('Year 2000')
plt.show()
# Out:
# /Users/mvachher/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1708: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /Users/mvachher/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:

# %% [markdown]
# ## Map for Year 2001

# %%
plt.figure(figsize=(16,12))

eq_map = Basemap(projection='cyl', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=0)
# eq_map.drawcoastlines()
# eq_map.drawcountries()
eq_map.fillcontinents(color = '#202020', lake_color='#3b3b3b', zorder=0.5)
eq_map.drawmapboundary(fill_color='#3b3b3b')
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))

lat = []
lon = []
val = []

for y in reduced_data['2001_2002']:
    lon.append(y['longitude'])
    lat.append(y['latitude'])
    val.append(y['tmax'])

x, y = eq_map(lon, lat)

cs = eq_map.scatter(x, y, c=val, marker="o", cmap=cm.coolwarm)
# add colorbar.
cbar = eq_map.colorbar(cs,location='bottom',pad="5%")
cbar.set_label('Max Temperature (in Celcius)')
plt.title('Year 2001')
plt.show()
# Out:
# /Users/mvachher/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1708: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /Users/mvachher/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:

# %% [markdown]
# # Part 2b

# %%
def make_weather_trainers(trainRatio,
                          estimator_gridbuilders,
                          metricName=None):
    """Construct a list of TrainValidationSplit estimators for weather data
       where `estimator_gridbuilders` is a list of (Estimator, ParamGridBuilder) tuples
       and 0 < `trainRatio` <= 1 determines the fraction of rows used for training.
       The RegressionEvaluator will use a non-default `metricName`, if specified.
    """
    feature_cols = ['latitude', 'longitude', 'elevation']
    column_names = dict(featuresCol="features",
                        labelCol="tmax",
                        predictionCol="tmax_pred")

    feature_assembler = VectorAssembler(
        inputCols=feature_cols,
        outputCol=column_names["featuresCol"])
    ev = (RegressionEvaluator()
          .setLabelCol(column_names["labelCol"])
          .setPredictionCol(column_names["predictionCol"])
    )
    if metricName:
        ev = ev.setMetricName(metricName)
    tvs_list = []
    for est, pgb in estimator_gridbuilders:
        est = est.setParams(**column_names)

        pl = Pipeline(stages=[feature_assembler, est])

        paramGrid = pgb.build()
        tvs_list.append(TrainValidationSplit(estimator=pl,
                                             estimatorParamMaps=paramGrid,
                                             evaluator=ev,
                                             trainRatio=trainRatio))
    return tvs_list

def get_best_weather_model(data):
    train, test = data.randomSplit([0.75, 0.25])
    train = train.cache()
    test = test.cache()

    # e.g., use print(LinearRegression().explainParams()) to see what can be tuned
    estimator_gridbuilders = [
        estimator_gridbuilder(
            LinearRegression(),
            dict(regParam=[0.3, 0.6],
                 elasticNetParam=[0, 0.5],
                 maxIter=[10, 20]
            )),

        estimator_gridbuilder(
            GBTRegressor(),
            dict(lossType=["squared"],
                 maxDepth=[5, 10],
                 maxIter=[2, 5],
                 stepSize=[0.1]
            )),

        estimator_gridbuilder(
            RandomForestRegressor(),
            dict(numTrees=[5, 10],
                 maxDepth=[5, 15],
                 featureSubsetStrategy=["auto"]
            ))
    ]
    
    metricName = 'r2'
    tvs_list = make_weather_trainers(.2, # fraction of data for training
                                     estimator_gridbuilders,
                                     metricName)
    ev = tvs_list[0].getEvaluator()
    scorescale = 1 if ev.isLargerBetter() else -1
    model_name_scores = []
    for tvs in tvs_list:
        model = tvs.fit(train)
        test_pred = model.transform(test)
        score = ev.evaluate(test_pred) * scorescale
        model_name_scores.append((model, get_estimator_name(tvs.getEstimator()), score))
    
    best_model, best_name, best_score = max(model_name_scores, key=lambda triplet: triplet[2])
    print("\n\nBest model is %s with validation data %s score %f" % (best_name, ev.getMetricName(), best_score*scorescale))
    return best_model

fortrain, holdout = data.randomSplit([0.75, 0.25])

model = get_best_weather_model(fortrain)
print("\n\n\nBest parameters on test data:\n", get_best_tvs_model_params(model))
# Out:
# Best model is GBTRegressor with validation data r2 score 0.349027
#
#
#
# Best parameters on test data:
#  ('r2', 0.33791125405080014, {Param(parent='GBTRegressor_4c978c52e6d89bf5aef6', name='lossType', doc='Loss function which GBT tries to minimize (case-insensitive). Supported options: squared, absolute'): 'squared', Param(parent='GBTRegressor_4c978c52e6d89bf5aef6', name='maxDepth', doc='Maximum depth of the tree. (>= 0) E.g., depth 0 means 1 leaf node; depth 1 means 1 internal node + 2 leaf nodes.'): 10, Param(parent='GBTRegressor_4c978c52e6d89bf5aef6', name='maxIter', doc='max number of iterations (>= 0).'): 5, Param(parent='GBTRegressor_4c978c52e6d89bf5aef6', name='stepSize', doc='Step size to be used for each iteration of optimization (>= 0).'): 0.1})

# %%
import elevation_grid as eg
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
import numpy as np

lat_range = range(-90, 90, 1)
lon_range = range(-180, 180, 1)

combo = []

for lat in lat_range:
    for lon in lon_range:
        elev = eg.get_elevation(lat, lon)
        combo.append((lat, lon, float(elev)))

dataset = spark.createDataFrame(combo,["latitude", "longitude", "elevation"])
pred = model.transform(dataset).collect()

collected_predictions = list(map(lambda row: row.asDict(), pred))

collected_predictions
# Out:
# [{'elevation': 0.0,
#   'features': DenseVector([-90.0, -180.0, 0.0]),
#   'latitude': -90,
#   'longitude': -180,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -179.0, 0.0]),
#   'latitude': -90,
#   'longitude': -179,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -178.0, 0.0]),
#   'latitude': -90,
#   'longitude': -178,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -177.0, 0.0]),
#   'latitude': -90,
#   'longitude': -177,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -176.0, 0.0]),
#   'latitude': -90,
#   'longitude': -176,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -175.0, 0.0]),
#   'latitude': -90,
#   'longitude': -175,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -174.0, 0.0]),
#   'latitude': -90,
#   'longitude': -174,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -173.0, 0.0]),
#   'latitude': -90,
#   'longitude': -173,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -172.0, 0.0]),
#   'latitude': -90,
#   'longitude': -172,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -171.0, 0.0]),
#   'latitude': -90,
#   'longitude': -171,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -170.0, 0.0]),
#   'latitude': -90,
#   'longitude': -170,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -169.0, 0.0]),
#   'latitude': -90,
#   'longitude': -169,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -168.0, 0.0]),
#   'latitude': -90,
#   'longitude': -168,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -167.0, 0.0]),
#   'latitude': -90,
#   'longitude': -167,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -166.0, 0.0]),
#   'latitude': -90,
#   'longitude': -166,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -165.0, 0.0]),
#   'latitude': -90,
#   'longitude': -165,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -164.0, 0.0]),
#   'latitude': -90,
#   'longitude': -164,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -163.0, 0.0]),
#   'latitude': -90,
#   'longitude': -163,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -162.0, 0.0]),
#   'latitude': -90,
#   'longitude': -162,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -161.0, 0.0]),
#   'latitude': -90,
#   'longitude': -161,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -160.0, 0.0]),
#   'latitude': -90,
#   'longitude': -160,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -159.0, 0.0]),
#   'latitude': -90,
#   'longitude': -159,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -158.0, 0.0]),
#   'latitude': -90,
#   'longitude': -158,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -157.0, 0.0]),
#   'latitude': -90,
#   'longitude': -157,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -156.0, 0.0]),
#   'latitude': -90,
#   'longitude': -156,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -155.0, 0.0]),
#   'latitude': -90,
#   'longitude': -155,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -154.0, 0.0]),
#   'latitude': -90,
#   'longitude': -154,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -153.0, 0.0]),
#   'latitude': -90,
#   'longitude': -153,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -152.0, 0.0]),
#   'latitude': -90,
#   'longitude': -152,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -151.0, 0.0]),
#   'latitude': -90,
#   'longitude': -151,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -150.0, 0.0]),
#   'latitude': -90,
#   'longitude': -150,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -149.0, 0.0]),
#   'latitude': -90,
#   'longitude': -149,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -148.0, 0.0]),
#   'latitude': -90,
#   'longitude': -148,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -147.0, 0.0]),
#   'latitude': -90,
#   'longitude': -147,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -146.0, 0.0]),
#   'latitude': -90,
#   'longitude': -146,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -145.0, 0.0]),
#   'latitude': -90,
#   'longitude': -145,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -144.0, 0.0]),
#   'latitude': -90,
#   'longitude': -144,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -143.0, 0.0]),
#   'latitude': -90,
#   'longitude': -143,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -142.0, 0.0]),
#   'latitude': -90,
#   'longitude': -142,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -141.0, 0.0]),
#   'latitude': -90,
#   'longitude': -141,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -140.0, 0.0]),
#   'latitude': -90,
#   'longitude': -140,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -139.0, 0.0]),
#   'latitude': -90,
#   'longitude': -139,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -138.0, 0.0]),
#   'latitude': -90,
#   'longitude': -138,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -137.0, 0.0]),
#   'latitude': -90,
#   'longitude': -137,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -136.0, 0.0]),
#   'latitude': -90,
#   'longitude': -136,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -135.0, 0.0]),
#   'latitude': -90,
#   'longitude': -135,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -134.0, 0.0]),
#   'latitude': -90,
#   'longitude': -134,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -133.0, 0.0]),
#   'latitude': -90,
#   'longitude': -133,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -132.0, 0.0]),
#   'latitude': -90,
#   'longitude': -132,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -131.0, 0.0]),
#   'latitude': -90,
#   'longitude': -131,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -130.0, 0.0]),
#   'latitude': -90,
#   'longitude': -130,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -129.0, 0.0]),
#   'latitude': -90,
#   'longitude': -129,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -128.0, 0.0]),
#   'latitude': -90,
#   'longitude': -128,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -127.0, 0.0]),
#   'latitude': -90,
#   'longitude': -127,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -126.0, 0.0]),
#   'latitude': -90,
#   'longitude': -126,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -125.0, 0.0]),
#   'latitude': -90,
#   'longitude': -125,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -124.0, 0.0]),
#   'latitude': -90,
#   'longitude': -124,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -123.0, 0.0]),
#   'latitude': -90,
#   'longitude': -123,
#   'tmax_pred': -12.091761736194762},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -122.0, 0.0]),
#   'latitude': -90,
#   'longitude': -122,
#   'tmax_pred': -13.486679426950088},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -121.0, 0.0]),
#   'latitude': -90,
#   'longitude': -121,
#   'tmax_pred': -13.486679426950088},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -120.0, 0.0]),
#   'latitude': -90,
#   'longitude': -120,
#   'tmax_pred': -13.844315514309},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -119.0, 0.0]),
#   'latitude': -90,
#   'longitude': -119,
#   'tmax_pred': -13.844315514309},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -118.0, 0.0]),
#   'latitude': -90,
#   'longitude': -118,
#   'tmax_pred': -14.96388578280396},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -117.0, 0.0]),
#   'latitude': -90,
#   'longitude': -117,
#   'tmax_pred': -14.96388578280396},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -116.0, 0.0]),
#   'latitude': -90,
#   'longitude': -116,
#   'tmax_pred': -14.96388578280396},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -115.0, 0.0]),
#   'latitude': -90,
#   'longitude': -115,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -114.0, 0.0]),
#   'latitude': -90,
#   'longitude': -114,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -113.0, 0.0]),
#   'latitude': -90,
#   'longitude': -113,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -112.0, 0.0]),
#   'latitude': -90,
#   'longitude': -112,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -111.0, 0.0]),
#   'latitude': -90,
#   'longitude': -111,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -110.0, 0.0]),
#   'latitude': -90,
#   'longitude': -110,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -109.0, 0.0]),
#   'latitude': -90,
#   'longitude': -109,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -108.0, 0.0]),
#   'latitude': -90,
#   'longitude': -108,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -107.0, 0.0]),
#   'latitude': -90,
#   'longitude': -107,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -106.0, 0.0]),
#   'latitude': -90,
#   'longitude': -106,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -105.0, 0.0]),
#   'latitude': -90,
#   'longitude': -105,
#   'tmax_pred': -13.194810516493504},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -104.0, 0.0]),
#   'latitude': -90,
#   'longitude': -104,
#   'tmax_pred': -13.085749005673849},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -103.0, 0.0]),
#   'latitude': -90,
#   'longitude': -103,
#   'tmax_pred': -13.085749005673849},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -102.0, 0.0]),
#   'latitude': -90,
#   'longitude': -102,
#   'tmax_pred': -12.860259596526317},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -101.0, 0.0]),
#   'latitude': -90,
#   'longitude': -101,
#   'tmax_pred': -12.860259596526317},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -100.0, 0.0]),
#   'latitude': -90,
#   'longitude': -100,
#   'tmax_pred': -12.860259596526317},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -99.0, 0.0]),
#   'latitude': -90,
#   'longitude': -99,
#   'tmax_pred': -12.505366537891604},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -98.0, 0.0]),
#   'latitude': -90,
#   'longitude': -98,
#   'tmax_pred': -12.505366537891604},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -97.0, 0.0]),
#   'latitude': -90,
#   'longitude': -97,
#   'tmax_pred': -12.505366537891604},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -96.0, 0.0]),
#   'latitude': -90,
#   'longitude': -96,
#   'tmax_pred': -12.505366537891604},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -95.0, 0.0]),
#   'latitude': -90,
#   'longitude': -95,
#   'tmax_pred': -12.505366537891604},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -94.0, 0.0]),
#   'latitude': -90,
#   'longitude': -94,
#   'tmax_pred': -12.436689640103983},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -93.0, 0.0]),
#   'latitude': -90,
#   'longitude': -93,
#   'tmax_pred': -12.436689640103983},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -92.0, 0.0]),
#   'latitude': -90,
#   'longitude': -92,
#   'tmax_pred': -12.436689640103983},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -91.0, 0.0]),
#   'latitude': -90,
#   'longitude': -91,
#   'tmax_pred': -12.802424340396305},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -90.0, 0.0]),
#   'latitude': -90,
#   'longitude': -90,
#   'tmax_pred': -12.802424340396305},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -89.0, 0.0]),
#   'latitude': -90,
#   'longitude': -89,
#   'tmax_pred': -12.802424340396305},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -88.0, 0.0]),
#   'latitude': -90,
#   'longitude': -88,
#   'tmax_pred': -12.802424340396305},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -87.0, 0.0]),
#   'latitude': -90,
#   'longitude': -87,
#   'tmax_pred': -12.802424340396305},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -86.0, 0.0]),
#   'latitude': -90,
#   'longitude': -86,
#   'tmax_pred': -12.455910905136939},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -85.0, 0.0]),
#   'latitude': -90,
#   'longitude': -85,
#   'tmax_pred': -12.455910905136939},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -84.0, 0.0]),
#   'latitude': -90,
#   'longitude': -84,
#   'tmax_pred': -12.455910905136939},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -83.0, 0.0]),
#   'latitude': -90,
#   'longitude': -83,
#   'tmax_pred': -12.636887925615863},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -82.0, 0.0]),
#   'latitude': -90,
#   'longitude': -82,
#   'tmax_pred': -12.636887925615863},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -81.0, 0.0]),
#   'latitude': -90,
#   'longitude': -81,
#   'tmax_pred': -12.321666009571755},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -80.0, 0.0]),
#   'latitude': -90,
#   'longitude': -80,
#   'tmax_pred': -12.321666009571755},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -79.0, 0.0]),
#   'latitude': -90,
#   'longitude': -79,
#   'tmax_pred': -12.321666009571755},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -78.0, 0.0]),
#   'latitude': -90,
#   'longitude': -78,
#   'tmax_pred': -12.321666009571755},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -77.0, 0.0]),
#   'latitude': -90,
#   'longitude': -77,
#   'tmax_pred': -12.321666009571755},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -76.0, 0.0]),
#   'latitude': -90,
#   'longitude': -76,
#   'tmax_pred': -12.321666009571755},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -75.0, 0.0]),
#   'latitude': -90,
#   'longitude': -75,
#   'tmax_pred': -12.321666009571755},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -74.0, 0.0]),
#   'latitude': -90,
#   'longitude': -74,
#   'tmax_pred': -12.321666009571755},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -73.0, 0.0]),
#   'latitude': -90,
#   'longitude': -73,
#   'tmax_pred': -12.321666009571755},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -72.0, 0.0]),
#   'latitude': -90,
#   'longitude': -72,
#   'tmax_pred': -13.420059163202946},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -71.0, 0.0]),
#   'latitude': -90,
#   'longitude': -71,
#   'tmax_pred': -14.599485591725246},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -70.0, 0.0]),
#   'latitude': -90,
#   'longitude': -70,
#   'tmax_pred': -14.599485591725246},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -69.0, 0.0]),
#   'latitude': -90,
#   'longitude': -69,
#   'tmax_pred': -14.599485591725246},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -68.0, 0.0]),
#   'latitude': -90,
#   'longitude': -68,
#   'tmax_pred': -14.599485591725246},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -67.0, 0.0]),
#   'latitude': -90,
#   'longitude': -67,
#   'tmax_pred': -14.599485591725246},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -66.0, 0.0]),
#   'latitude': -90,
#   'longitude': -66,
#   'tmax_pred': -14.599485591725246},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -65.0, 0.0]),
#   'latitude': -90,
#   'longitude': -65,
#   'tmax_pred': -14.599485591725246},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -64.0, 0.0]),
#   'latitude': -90,
#   'longitude': -64,
#   'tmax_pred': -14.599485591725246},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -63.0, 0.0]),
#   'latitude': -90,
#   'longitude': -63,
#   'tmax_pred': -14.599485591725246},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -62.0, 0.0]),
#   'latitude': -90,
#   'longitude': -62,
#   'tmax_pred': -14.599485591725246},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -61.0, 0.0]),
#   'latitude': -90,
#   'longitude': -61,
#   'tmax_pred': -14.2781824295021},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -60.0, 0.0]),
#   'latitude': -90,
#   'longitude': -60,
#   'tmax_pred': -14.2781824295021},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -59.0, 0.0]),
#   'latitude': -90,
#   'longitude': -59,
#   'tmax_pred': -14.2781824295021},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -58.0, 0.0]),
#   'latitude': -90,
#   'longitude': -58,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -57.0, 0.0]),
#   'latitude': -90,
#   'longitude': -57,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -56.0, 0.0]),
#   'latitude': -90,
#   'longitude': -56,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -55.0, 0.0]),
#   'latitude': -90,
#   'longitude': -55,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -54.0, 0.0]),
#   'latitude': -90,
#   'longitude': -54,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -53.0, 0.0]),
#   'latitude': -90,
#   'longitude': -53,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -52.0, 0.0]),
#   'latitude': -90,
#   'longitude': -52,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -51.0, 0.0]),
#   'latitude': -90,
#   'longitude': -51,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -50.0, 0.0]),
#   'latitude': -90,
#   'longitude': -50,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -49.0, 0.0]),
#   'latitude': -90,
#   'longitude': -49,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -48.0, 0.0]),
#   'latitude': -90,
#   'longitude': -48,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -47.0, 0.0]),
#   'latitude': -90,
#   'longitude': -47,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -46.0, 0.0]),
#   'latitude': -90,
#   'longitude': -46,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -45.0, 0.0]),
#   'latitude': -90,
#   'longitude': -45,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -44.0, 0.0]),
#   'latitude': -90,
#   'longitude': -44,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -43.0, 0.0]),
#   'latitude': -90,
#   'longitude': -43,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -42.0, 0.0]),
#   'latitude': -90,
#   'longitude': -42,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -41.0, 0.0]),
#   'latitude': -90,
#   'longitude': -41,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -40.0, 0.0]),
#   'latitude': -90,
#   'longitude': -40,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -39.0, 0.0]),
#   'latitude': -90,
#   'longitude': -39,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -38.0, 0.0]),
#   'latitude': -90,
#   'longitude': -38,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -37.0, 0.0]),
#   'latitude': -90,
#   'longitude': -37,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -36.0, 0.0]),
#   'latitude': -90,
#   'longitude': -36,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -35.0, 0.0]),
#   'latitude': -90,
#   'longitude': -35,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -34.0, 0.0]),
#   'latitude': -90,
#   'longitude': -34,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -33.0, 0.0]),
#   'latitude': -90,
#   'longitude': -33,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -32.0, 0.0]),
#   'latitude': -90,
#   'longitude': -32,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -31.0, 0.0]),
#   'latitude': -90,
#   'longitude': -31,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -30.0, 0.0]),
#   'latitude': -90,
#   'longitude': -30,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -29.0, 0.0]),
#   'latitude': -90,
#   'longitude': -29,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -28.0, 0.0]),
#   'latitude': -90,
#   'longitude': -28,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -27.0, 0.0]),
#   'latitude': -90,
#   'longitude': -27,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -26.0, 0.0]),
#   'latitude': -90,
#   'longitude': -26,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -25.0, 0.0]),
#   'latitude': -90,
#   'longitude': -25,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -24.0, 0.0]),
#   'latitude': -90,
#   'longitude': -24,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -23.0, 0.0]),
#   'latitude': -90,
#   'longitude': -23,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -22.0, 0.0]),
#   'latitude': -90,
#   'longitude': -22,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -21.0, 0.0]),
#   'latitude': -90,
#   'longitude': -21,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -20.0, 0.0]),
#   'latitude': -90,
#   'longitude': -20,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -19.0, 0.0]),
#   'latitude': -90,
#   'longitude': -19,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -18.0, 0.0]),
#   'latitude': -90,
#   'longitude': -18,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -17.0, 0.0]),
#   'latitude': -90,
#   'longitude': -17,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -16.0, 0.0]),
#   'latitude': -90,
#   'longitude': -16,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -15.0, 0.0]),
#   'latitude': -90,
#   'longitude': -15,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -14.0, 0.0]),
#   'latitude': -90,
#   'longitude': -14,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -13.0, 0.0]),
#   'latitude': -90,
#   'longitude': -13,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -12.0, 0.0]),
#   'latitude': -90,
#   'longitude': -12,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -11.0, 0.0]),
#   'latitude': -90,
#   'longitude': -11,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -10.0, 0.0]),
#   'latitude': -90,
#   'longitude': -10,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -9.0, 0.0]),
#   'latitude': -90,
#   'longitude': -9,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -8.0, 0.0]),
#   'latitude': -90,
#   'longitude': -8,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -7.0, 0.0]),
#   'latitude': -90,
#   'longitude': -7,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -6.0, 0.0]),
#   'latitude': -90,
#   'longitude': -6,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -5.0, 0.0]),
#   'latitude': -90,
#   'longitude': -5,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -4.0, 0.0]),
#   'latitude': -90,
#   'longitude': -4,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -3.0, 0.0]),
#   'latitude': -90,
#   'longitude': -3,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -2.0, 0.0]),
#   'latitude': -90,
#   'longitude': -2,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, -1.0, 0.0]),
#   'latitude': -90,
#   'longitude': -1,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 0.0, 0.0]),
#   'latitude': -90,
#   'longitude': 0,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 1.0, 0.0]),
#   'latitude': -90,
#   'longitude': 1,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 2.0, 0.0]),
#   'latitude': -90,
#   'longitude': 2,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 3.0, 0.0]),
#   'latitude': -90,
#   'longitude': 3,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 4.0, 0.0]),
#   'latitude': -90,
#   'longitude': 4,
#   'tmax_pred': -13.31704032599551},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 5.0, 0.0]),
#   'latitude': -90,
#   'longitude': 5,
#   'tmax_pred': -13.343983215354422},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 6.0, 0.0]),
#   'latitude': -90,
#   'longitude': 6,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 7.0, 0.0]),
#   'latitude': -90,
#   'longitude': 7,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 8.0, 0.0]),
#   'latitude': -90,
#   'longitude': 8,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 9.0, 0.0]),
#   'latitude': -90,
#   'longitude': 9,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 10.0, 0.0]),
#   'latitude': -90,
#   'longitude': 10,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 11.0, 0.0]),
#   'latitude': -90,
#   'longitude': 11,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 12.0, 0.0]),
#   'latitude': -90,
#   'longitude': 12,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 13.0, 0.0]),
#   'latitude': -90,
#   'longitude': 13,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 14.0, 0.0]),
#   'latitude': -90,
#   'longitude': 14,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 15.0, 0.0]),
#   'latitude': -90,
#   'longitude': 15,
#   'tmax_pred': -4.458182781480828},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 16.0, 0.0]),
#   'latitude': -90,
#   'longitude': 16,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 17.0, 0.0]),
#   'latitude': -90,
#   'longitude': 17,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 18.0, 0.0]),
#   'latitude': -90,
#   'longitude': 18,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 19.0, 0.0]),
#   'latitude': -90,
#   'longitude': 19,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 20.0, 0.0]),
#   'latitude': -90,
#   'longitude': 20,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 21.0, 0.0]),
#   'latitude': -90,
#   'longitude': 21,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 22.0, 0.0]),
#   'latitude': -90,
#   'longitude': 22,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 23.0, 0.0]),
#   'latitude': -90,
#   'longitude': 23,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 24.0, 0.0]),
#   'latitude': -90,
#   'longitude': 24,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 25.0, 0.0]),
#   'latitude': -90,
#   'longitude': 25,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 26.0, 0.0]),
#   'latitude': -90,
#   'longitude': 26,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 27.0, 0.0]),
#   'latitude': -90,
#   'longitude': 27,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 28.0, 0.0]),
#   'latitude': -90,
#   'longitude': 28,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 29.0, 0.0]),
#   'latitude': -90,
#   'longitude': 29,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 30.0, 0.0]),
#   'latitude': -90,
#   'longitude': 30,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 31.0, 0.0]),
#   'latitude': -90,
#   'longitude': 31,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 32.0, 0.0]),
#   'latitude': -90,
#   'longitude': 32,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 33.0, 0.0]),
#   'latitude': -90,
#   'longitude': 33,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 34.0, 0.0]),
#   'latitude': -90,
#   'longitude': 34,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 35.0, 0.0]),
#   'latitude': -90,
#   'longitude': 35,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 36.0, 0.0]),
#   'latitude': -90,
#   'longitude': 36,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 37.0, 0.0]),
#   'latitude': -90,
#   'longitude': 37,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 38.0, 0.0]),
#   'latitude': -90,
#   'longitude': 38,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 39.0, 0.0]),
#   'latitude': -90,
#   'longitude': 39,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 40.0, 0.0]),
#   'latitude': -90,
#   'longitude': 40,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 41.0, 0.0]),
#   'latitude': -90,
#   'longitude': 41,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 42.0, 0.0]),
#   'latitude': -90,
#   'longitude': 42,
#   'tmax_pred': -4.453768927287458},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 43.0, 0.0]),
#   'latitude': -90,
#   'longitude': 43,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 44.0, 0.0]),
#   'latitude': -90,
#   'longitude': 44,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 45.0, 0.0]),
#   'latitude': -90,
#   'longitude': 45,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 46.0, 0.0]),
#   'latitude': -90,
#   'longitude': 46,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 47.0, 0.0]),
#   'latitude': -90,
#   'longitude': 47,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 48.0, 0.0]),
#   'latitude': -90,
#   'longitude': 48,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 49.0, 0.0]),
#   'latitude': -90,
#   'longitude': 49,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 50.0, 0.0]),
#   'latitude': -90,
#   'longitude': 50,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 51.0, 0.0]),
#   'latitude': -90,
#   'longitude': 51,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 52.0, 0.0]),
#   'latitude': -90,
#   'longitude': 52,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 53.0, 0.0]),
#   'latitude': -90,
#   'longitude': 53,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 54.0, 0.0]),
#   'latitude': -90,
#   'longitude': 54,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 55.0, 0.0]),
#   'latitude': -90,
#   'longitude': 55,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 56.0, 0.0]),
#   'latitude': -90,
#   'longitude': 56,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 57.0, 0.0]),
#   'latitude': -90,
#   'longitude': 57,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 58.0, 0.0]),
#   'latitude': -90,
#   'longitude': 58,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 59.0, 0.0]),
#   'latitude': -90,
#   'longitude': 59,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 60.0, 0.0]),
#   'latitude': -90,
#   'longitude': 60,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 61.0, 0.0]),
#   'latitude': -90,
#   'longitude': 61,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 62.0, 0.0]),
#   'latitude': -90,
#   'longitude': 62,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 63.0, 0.0]),
#   'latitude': -90,
#   'longitude': 63,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 64.0, 0.0]),
#   'latitude': -90,
#   'longitude': 64,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 65.0, 0.0]),
#   'latitude': -90,
#   'longitude': 65,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 66.0, 0.0]),
#   'latitude': -90,
#   'longitude': 66,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 67.0, 0.0]),
#   'latitude': -90,
#   'longitude': 67,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 68.0, 0.0]),
#   'latitude': -90,
#   'longitude': 68,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 69.0, 0.0]),
#   'latitude': -90,
#   'longitude': 69,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 70.0, 0.0]),
#   'latitude': -90,
#   'longitude': 70,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 71.0, 0.0]),
#   'latitude': -90,
#   'longitude': 71,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 72.0, 0.0]),
#   'latitude': -90,
#   'longitude': 72,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 73.0, 0.0]),
#   'latitude': -90,
#   'longitude': 73,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 74.0, 0.0]),
#   'latitude': -90,
#   'longitude': 74,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 75.0, 0.0]),
#   'latitude': -90,
#   'longitude': 75,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 76.0, 0.0]),
#   'latitude': -90,
#   'longitude': 76,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 77.0, 0.0]),
#   'latitude': -90,
#   'longitude': 77,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 78.0, 0.0]),
#   'latitude': -90,
#   'longitude': 78,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 79.0, 0.0]),
#   'latitude': -90,
#   'longitude': 79,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 80.0, 0.0]),
#   'latitude': -90,
#   'longitude': 80,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 81.0, 0.0]),
#   'latitude': -90,
#   'longitude': 81,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 82.0, 0.0]),
#   'latitude': -90,
#   'longitude': 82,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 83.0, 0.0]),
#   'latitude': -90,
#   'longitude': 83,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 84.0, 0.0]),
#   'latitude': -90,
#   'longitude': 84,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 85.0, 0.0]),
#   'latitude': -90,
#   'longitude': 85,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 86.0, 0.0]),
#   'latitude': -90,
#   'longitude': 86,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 87.0, 0.0]),
#   'latitude': -90,
#   'longitude': 87,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 88.0, 0.0]),
#   'latitude': -90,
#   'longitude': 88,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 89.0, 0.0]),
#   'latitude': -90,
#   'longitude': 89,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 90.0, 0.0]),
#   'latitude': -90,
#   'longitude': 90,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 91.0, 0.0]),
#   'latitude': -90,
#   'longitude': 91,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 92.0, 0.0]),
#   'latitude': -90,
#   'longitude': 92,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 93.0, 0.0]),
#   'latitude': -90,
#   'longitude': 93,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 94.0, 0.0]),
#   'latitude': -90,
#   'longitude': 94,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 95.0, 0.0]),
#   'latitude': -90,
#   'longitude': 95,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 96.0, 0.0]),
#   'latitude': -90,
#   'longitude': 96,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 97.0, 0.0]),
#   'latitude': -90,
#   'longitude': 97,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 98.0, 0.0]),
#   'latitude': -90,
#   'longitude': 98,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 99.0, 0.0]),
#   'latitude': -90,
#   'longitude': 99,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 100.0, 0.0]),
#   'latitude': -90,
#   'longitude': 100,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 101.0, 0.0]),
#   'latitude': -90,
#   'longitude': 101,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 102.0, 0.0]),
#   'latitude': -90,
#   'longitude': 102,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 103.0, 0.0]),
#   'latitude': -90,
#   'longitude': 103,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 104.0, 0.0]),
#   'latitude': -90,
#   'longitude': 104,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 105.0, 0.0]),
#   'latitude': -90,
#   'longitude': 105,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 106.0, 0.0]),
#   'latitude': -90,
#   'longitude': 106,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 107.0, 0.0]),
#   'latitude': -90,
#   'longitude': 107,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 108.0, 0.0]),
#   'latitude': -90,
#   'longitude': 108,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 109.0, 0.0]),
#   'latitude': -90,
#   'longitude': 109,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 110.0, 0.0]),
#   'latitude': -90,
#   'longitude': 110,
#   'tmax_pred': 21.870521070277018},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 111.0, 0.0]),
#   'latitude': -90,
#   'longitude': 111,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 112.0, 0.0]),
#   'latitude': -90,
#   'longitude': 112,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 113.0, 0.0]),
#   'latitude': -90,
#   'longitude': 113,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 114.0, 0.0]),
#   'latitude': -90,
#   'longitude': 114,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 115.0, 0.0]),
#   'latitude': -90,
#   'longitude': 115,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 116.0, 0.0]),
#   'latitude': -90,
#   'longitude': 116,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 117.0, 0.0]),
#   'latitude': -90,
#   'longitude': 117,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 118.0, 0.0]),
#   'latitude': -90,
#   'longitude': 118,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 119.0, 0.0]),
#   'latitude': -90,
#   'longitude': 119,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 120.0, 0.0]),
#   'latitude': -90,
#   'longitude': 120,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 121.0, 0.0]),
#   'latitude': -90,
#   'longitude': 121,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 122.0, 0.0]),
#   'latitude': -90,
#   'longitude': 122,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 123.0, 0.0]),
#   'latitude': -90,
#   'longitude': 123,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 124.0, 0.0]),
#   'latitude': -90,
#   'longitude': 124,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 125.0, 0.0]),
#   'latitude': -90,
#   'longitude': 125,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 126.0, 0.0]),
#   'latitude': -90,
#   'longitude': 126,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 127.0, 0.0]),
#   'latitude': -90,
#   'longitude': 127,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 128.0, 0.0]),
#   'latitude': -90,
#   'longitude': 128,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 129.0, 0.0]),
#   'latitude': -90,
#   'longitude': 129,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 130.0, 0.0]),
#   'latitude': -90,
#   'longitude': 130,
#   'tmax_pred': 21.62013777133331},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 131.0, 0.0]),
#   'latitude': -90,
#   'longitude': 131,
#   'tmax_pred': 21.659784883033705},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 132.0, 0.0]),
#   'latitude': -90,
#   'longitude': 132,
#   'tmax_pred': 21.659784883033705},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 133.0, 0.0]),
#   'latitude': -90,
#   'longitude': 133,
#   'tmax_pred': 21.53036716494813},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 134.0, 0.0]),
#   'latitude': -90,
#   'longitude': 134,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 135.0, 0.0]),
#   'latitude': -90,
#   'longitude': 135,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 136.0, 0.0]),
#   'latitude': -90,
#   'longitude': 136,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 137.0, 0.0]),
#   'latitude': -90,
#   'longitude': 137,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 138.0, 0.0]),
#   'latitude': -90,
#   'longitude': 138,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 139.0, 0.0]),
#   'latitude': -90,
#   'longitude': 139,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 140.0, 0.0]),
#   'latitude': -90,
#   'longitude': 140,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 141.0, 0.0]),
#   'latitude': -90,
#   'longitude': 141,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 142.0, 0.0]),
#   'latitude': -90,
#   'longitude': 142,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 143.0, 0.0]),
#   'latitude': -90,
#   'longitude': 143,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 144.0, 0.0]),
#   'latitude': -90,
#   'longitude': 144,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 145.0, 0.0]),
#   'latitude': -90,
#   'longitude': 145,
#   'tmax_pred': 21.24373746858667},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 146.0, 0.0]),
#   'latitude': -90,
#   'longitude': 146,
#   'tmax_pred': 19.25670773139014},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 147.0, 0.0]),
#   'latitude': -90,
#   'longitude': 147,
#   'tmax_pred': 19.25670773139014},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 148.0, 0.0]),
#   'latitude': -90,
#   'longitude': 148,
#   'tmax_pred': 19.25670773139014},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 149.0, 0.0]),
#   'latitude': -90,
#   'longitude': 149,
#   'tmax_pred': 19.25670773139014},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 150.0, 0.0]),
#   'latitude': -90,
#   'longitude': 150,
#   'tmax_pred': 19.25670773139014},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 151.0, 0.0]),
#   'latitude': -90,
#   'longitude': 151,
#   'tmax_pred': 19.25670773139014},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 152.0, 0.0]),
#   'latitude': -90,
#   'longitude': 152,
#   'tmax_pred': 19.25670773139014},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 153.0, 0.0]),
#   'latitude': -90,
#   'longitude': 153,
#   'tmax_pred': 19.25670773139014},
#  {'elevation': 0.0,
#   'features': DenseVector([-90.0, 154.0, 0.0]),
#   'latitude': -90,
#   'longitude': 154,
#   'tmax_pred': 19.25670773139014},
#  {'elevation': 0.0,
# ...
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -13.0, 0.0]),
#   'latitude': -88,
#   'longitude': -13,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -12.0, 0.0]),
#   'latitude': -88,
#   'longitude': -12,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -11.0, 0.0]),
#   'latitude': -88,
#   'longitude': -11,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -10.0, 0.0]),
#   'latitude': -88,
#   'longitude': -10,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -9.0, 0.0]),
#   'latitude': -88,
#   'longitude': -9,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -8.0, 0.0]),
#   'latitude': -88,
#   'longitude': -8,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -7.0, 0.0]),
#   'latitude': -88,
#   'longitude': -7,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -6.0, 0.0]),
#   'latitude': -88,
#   'longitude': -6,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -5.0, 0.0]),
#   'latitude': -88,
#   'longitude': -5,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -4.0, 0.0]),
#   'latitude': -88,
#   'longitude': -4,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -3.0, 0.0]),
#   'latitude': -88,
#   'longitude': -3,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -2.0, 0.0]),
#   'latitude': -88,
#   'longitude': -2,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, -1.0, 0.0]),
#   'latitude': -88,
#   'longitude': -1,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 0.0, 0.0]),
#   'latitude': -88,
#   'longitude': 0,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 1.0, 0.0]),
#   'latitude': -88,
#   'longitude': 1,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 2.0, 0.0]),
#   'latitude': -88,
#   'longitude': 2,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 3.0, 0.0]),
#   'latitude': -88,
#   'longitude': 3,
#   'tmax_pred': -13.485433384488712},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 4.0, 0.0]),
#   'latitude': -88,
#   'longitude': 4,
#   'tmax_pred': -13.31704032599551},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 5.0, 0.0]),
#   'latitude': -88,
#   'longitude': 5,
#   'tmax_pred': -13.343983215354422},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 6.0, 0.0]),
#   'latitude': -88,
#   'longitude': 6,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 7.0, 0.0]),
#   'latitude': -88,
#   'longitude': 7,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 8.0, 0.0]),
#   'latitude': -88,
#   'longitude': 8,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 9.0, 0.0]),
#   'latitude': -88,
#   'longitude': 9,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 10.0, 0.0]),
#   'latitude': -88,
#   'longitude': 10,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 11.0, 0.0]),
#   'latitude': -88,
#   'longitude': 11,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 12.0, 0.0]),
#   'latitude': -88,
#   'longitude': 12,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 13.0, 0.0]),
#   'latitude': -88,
#   'longitude': 13,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 14.0, 0.0]),
#   'latitude': -88,
#   'longitude': 14,
#   'tmax_pred': -4.476096914574362},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 15.0, 0.0]),
#   'latitude': -88,
#   'longitude': 15,
#   'tmax_pred': -4.458182781480828},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 16.0, 0.0]),
#   'latitude': -88,
#   'longitude': 16,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 17.0, 0.0]),
#   'latitude': -88,
#   'longitude': 17,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 18.0, 0.0]),
#   'latitude': -88,
#   'longitude': 18,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 19.0, 0.0]),
#   'latitude': -88,
#   'longitude': 19,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 20.0, 0.0]),
#   'latitude': -88,
#   'longitude': 20,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 21.0, 0.0]),
#   'latitude': -88,
#   'longitude': 21,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 22.0, 0.0]),
#   'latitude': -88,
#   'longitude': 22,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 23.0, 0.0]),
#   'latitude': -88,
#   'longitude': 23,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 24.0, 0.0]),
#   'latitude': -88,
#   'longitude': 24,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 25.0, 0.0]),
#   'latitude': -88,
#   'longitude': 25,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 26.0, 0.0]),
#   'latitude': -88,
#   'longitude': 26,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 27.0, 0.0]),
#   'latitude': -88,
#   'longitude': 27,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 28.0, 0.0]),
#   'latitude': -88,
#   'longitude': 28,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 29.0, 0.0]),
#   'latitude': -88,
#   'longitude': 29,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 30.0, 0.0]),
#   'latitude': -88,
#   'longitude': 30,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 31.0, 0.0]),
#   'latitude': -88,
#   'longitude': 31,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 32.0, 0.0]),
#   'latitude': -88,
#   'longitude': 32,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 33.0, 0.0]),
#   'latitude': -88,
#   'longitude': 33,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 34.0, 0.0]),
#   'latitude': -88,
#   'longitude': 34,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 35.0, 0.0]),
#   'latitude': -88,
#   'longitude': 35,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 36.0, 0.0]),
#   'latitude': -88,
#   'longitude': 36,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 37.0, 0.0]),
#   'latitude': -88,
#   'longitude': 37,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 38.0, 0.0]),
#   'latitude': -88,
#   'longitude': 38,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 39.0, 0.0]),
#   'latitude': -88,
#   'longitude': 39,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 40.0, 0.0]),
#   'latitude': -88,
#   'longitude': 40,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 41.0, 0.0]),
#   'latitude': -88,
#   'longitude': 41,
#   'tmax_pred': -4.188792764856283},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 42.0, 0.0]),
#   'latitude': -88,
#   'longitude': 42,
#   'tmax_pred': -4.453768927287458},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 43.0, 0.0]),
#   'latitude': -88,
#   'longitude': 43,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 44.0, 0.0]),
#   'latitude': -88,
#   'longitude': 44,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 45.0, 0.0]),
#   'latitude': -88,
#   'longitude': 45,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 46.0, 0.0]),
#   'latitude': -88,
#   'longitude': 46,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 47.0, 0.0]),
#   'latitude': -88,
#   'longitude': 47,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 48.0, 0.0]),
#   'latitude': -88,
#   'longitude': 48,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 49.0, 0.0]),
#   'latitude': -88,
#   'longitude': 49,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 50.0, 0.0]),
#   'latitude': -88,
#   'longitude': 50,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 51.0, 0.0]),
#   'latitude': -88,
#   'longitude': 51,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 52.0, 0.0]),
#   'latitude': -88,
#   'longitude': 52,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 53.0, 0.0]),
#   'latitude': -88,
#   'longitude': 53,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 54.0, 0.0]),
#   'latitude': -88,
#   'longitude': 54,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 55.0, 0.0]),
#   'latitude': -88,
#   'longitude': 55,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 56.0, 0.0]),
#   'latitude': -88,
#   'longitude': 56,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 57.0, 0.0]),
#   'latitude': -88,
#   'longitude': 57,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 58.0, 0.0]),
#   'latitude': -88,
#   'longitude': 58,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 59.0, 0.0]),
#   'latitude': -88,
#   'longitude': 59,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 60.0, 0.0]),
#   'latitude': -88,
#   'longitude': 60,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 61.0, 0.0]),
#   'latitude': -88,
#   'longitude': 61,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 62.0, 0.0]),
#   'latitude': -88,
#   'longitude': 62,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 63.0, 0.0]),
#   'latitude': -88,
#   'longitude': 63,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 64.0, 0.0]),
#   'latitude': -88,
#   'longitude': 64,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 65.0, 0.0]),
#   'latitude': -88,
#   'longitude': 65,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 66.0, 0.0]),
#   'latitude': -88,
#   'longitude': 66,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 67.0, 0.0]),
#   'latitude': -88,
#   'longitude': 67,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 68.0, 0.0]),
#   'latitude': -88,
#   'longitude': 68,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 69.0, 0.0]),
#   'latitude': -88,
#   'longitude': 69,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 70.0, 0.0]),
#   'latitude': -88,
#   'longitude': 70,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 71.0, 0.0]),
#   'latitude': -88,
#   'longitude': 71,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 72.0, 0.0]),
#   'latitude': -88,
#   'longitude': 72,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 73.0, 0.0]),
#   'latitude': -88,
#   'longitude': 73,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 74.0, 0.0]),
#   'latitude': -88,
#   'longitude': 74,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 75.0, 0.0]),
#   'latitude': -88,
#   'longitude': 75,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 76.0, 0.0]),
#   'latitude': -88,
#   'longitude': 76,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 77.0, 0.0]),
#   'latitude': -88,
#   'longitude': 77,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 78.0, 0.0]),
#   'latitude': -88,
#   'longitude': 78,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 79.0, 0.0]),
#   'latitude': -88,
#   'longitude': 79,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 80.0, 0.0]),
#   'latitude': -88,
#   'longitude': 80,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 81.0, 0.0]),
#   'latitude': -88,
#   'longitude': 81,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 82.0, 0.0]),
#   'latitude': -88,
#   'longitude': 82,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 83.0, 0.0]),
#   'latitude': -88,
#   'longitude': 83,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 84.0, 0.0]),
#   'latitude': -88,
#   'longitude': 84,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 85.0, 0.0]),
#   'latitude': -88,
#   'longitude': 85,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 86.0, 0.0]),
#   'latitude': -88,
#   'longitude': 86,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 87.0, 0.0]),
#   'latitude': -88,
#   'longitude': 87,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 88.0, 0.0]),
#   'latitude': -88,
#   'longitude': 88,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 89.0, 0.0]),
#   'latitude': -88,
#   'longitude': 89,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 90.0, 0.0]),
#   'latitude': -88,
#   'longitude': 90,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 91.0, 0.0]),
#   'latitude': -88,
#   'longitude': 91,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 92.0, 0.0]),
#   'latitude': -88,
#   'longitude': 92,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 93.0, 0.0]),
#   'latitude': -88,
#   'longitude': 93,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 94.0, 0.0]),
#   'latitude': -88,
#   'longitude': 94,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 95.0, 0.0]),
#   'latitude': -88,
#   'longitude': 95,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 96.0, 0.0]),
#   'latitude': -88,
#   'longitude': 96,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 97.0, 0.0]),
#   'latitude': -88,
#   'longitude': 97,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 98.0, 0.0]),
#   'latitude': -88,
#   'longitude': 98,
#   'tmax_pred': -4.476450348197685},
#  {'elevation': 0.0,
#   'features': DenseVector([-88.0, 99.0, 0.0]),
#   'latitude': -88,
#   'longitude': 99,
#   'tmax_pred': -4.476450348197685},
#  ...]

# %%
plt.figure(figsize=(16,12))

eq_map = Basemap(projection='cyl', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=0)
# eq_map.drawcoastlines()
# eq_map.drawcountries()
eq_map.fillcontinents(color = '#202020', lake_color='#3b3b3b', zorder=0.5)
eq_map.drawmapboundary(fill_color='#3b3b3b')
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))

lon = []
lat = []
val = []

for y in collected_predictions:
    lon.append(y['longitude'])
    lat.append(y['latitude'])
    val.append(y['tmax_pred'])

x, y = eq_map(lon, lat)

cs = eq_map.scatter(x, y, c=val, marker="o", cmap=cm.coolwarm)
cbar = eq_map.colorbar(cs,location='bottom',pad="5%")
cbar.set_label('Max Temperature (in Celcius)')
plt.title('Predicted Heat Map')
plt.show()
# Out:
# /Users/mvachher/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1708: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /Users/mvachher/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:

# %%
pred = model.transform(holdout).collect()

collected_predictions = list(map(lambda row: row.asDict(), pred))

collected_predictions
# Out:
# [{'date': datetime.date(2000, 6, 18),
#   'elevation': 34.0,
#   'features': DenseVector([25.333, 55.517, 34.0]),
#   'latitude': 25.33300018310547,
#   'longitude': 55.516998291015625,
#   'station': 'AE000041196',
#   'tmax': 37.099998474121094,
#   'tmax_pred': 32.54940962105588},
#  {'date': datetime.date(2002, 4, 10),
#   'elevation': 34.0,
#   'features': DenseVector([25.333, 55.517, 34.0]),
#   'latitude': 25.33300018310547,
#   'longitude': 55.516998291015625,
#   'station': 'AE000041196',
#   'tmax': 35.900001525878906,
#   'tmax_pred': 32.54940962105588},
#  {'date': datetime.date(2003, 5, 8),
#   'elevation': 34.0,
#   'features': DenseVector([25.333, 55.517, 34.0]),
#   'latitude': 25.33300018310547,
#   'longitude': 55.516998291015625,
#   'station': 'AE000041196',
#   'tmax': 41.20000076293945,
#   'tmax_pred': 32.54940962105588},
#  {'date': datetime.date(2003, 9, 26),
#   'elevation': 34.0,
#   'features': DenseVector([25.333, 55.517, 34.0]),
#   'latitude': 25.33300018310547,
#   'longitude': 55.516998291015625,
#   'station': 'AE000041196',
#   'tmax': 41.099998474121094,
#   'tmax_pred': 32.54940962105588},
#  {'date': datetime.date(2006, 5, 18),
#   'elevation': 34.0,
#   'features': DenseVector([25.333, 55.517, 34.0]),
#   'latitude': 25.33300018310547,
#   'longitude': 55.516998291015625,
#   'station': 'AE000041196',
#   'tmax': 39.5,
#   'tmax_pred': 32.54940962105588},
#  {'date': datetime.date(2000, 7, 11),
#   'elevation': 10.399999618530273,
#   'features': DenseVector([25.255, 55.364, 10.4]),
#   'latitude': 25.2549991607666,
#   'longitude': 55.36399841308594,
#   'station': 'AEM00041194',
#   'tmax': 46.0,
#   'tmax_pred': 32.301436704746315},
#  {'date': datetime.date(2000, 9, 19),
#   'elevation': 10.399999618530273,
#   'features': DenseVector([25.255, 55.364, 10.4]),
#   'latitude': 25.2549991607666,
#   'longitude': 55.36399841308594,
#   'station': 'AEM00041194',
#   'tmax': 38.400001525878906,
#   'tmax_pred': 32.301436704746315},
#  {'date': datetime.date(2002, 10, 27),
#   'elevation': 10.399999618530273,
#   'features': DenseVector([25.255, 55.364, 10.4]),
#   'latitude': 25.2549991607666,
#   'longitude': 55.36399841308594,
#   'station': 'AEM00041194',
#   'tmax': 32.29999923706055,
#   'tmax_pred': 32.301436704746315},
#  {'date': datetime.date(2011, 7, 5),
#   'elevation': 10.399999618530273,
#   'features': DenseVector([25.255, 55.364, 10.4]),
#   'latitude': 25.2549991607666,
#   'longitude': 55.36399841308594,
#   'station': 'AEM00041194',
#   'tmax': 39.0,
#   'tmax_pred': 32.301436704746315},
#  {'date': datetime.date(2000, 4, 14),
#   'elevation': 26.799999237060547,
#   'features': DenseVector([24.433, 54.651, 26.8]),
#   'latitude': 24.433000564575195,
#   'longitude': 54.6510009765625,
#   'station': 'AEM00041217',
#   'tmax': 34.20000076293945,
#   'tmax_pred': 32.68194822702493},
#  {'date': datetime.date(2004, 11, 25),
#   'elevation': 26.799999237060547,
#   'features': DenseVector([24.433, 54.651, 26.8]),
#   'latitude': 24.433000564575195,
#   'longitude': 54.6510009765625,
#   'station': 'AEM00041217',
#   'tmax': 27.299999237060547,
#   'tmax_pred': 32.68194822702493},
#  {'date': datetime.date(2004, 12, 17),
#   'elevation': 264.8999938964844,
#   'features': DenseVector([24.262, 55.609, 264.9]),
#   'latitude': 24.261999130249023,
#   'longitude': 55.60900115966797,
#   'station': 'AEM00041218',
#   'tmax': 28.299999237060547,
#   'tmax_pred': 35.240437841319284},
#  {'date': datetime.date(2013, 12, 6),
#   'elevation': 264.8999938964844,
#   'features': DenseVector([24.262, 55.609, 264.9]),
#   'latitude': 24.261999130249023,
#   'longitude': 55.60900115966797,
#   'station': 'AEM00041218',
#   'tmax': 28.600000381469727,
#   'tmax_pred': 35.240437841319284},
#  {'date': datetime.date(2002, 7, 20),
#   'elevation': 1791.300048828125,
#   'features': DenseVector([34.566, 69.212, 1791.3]),
#   'latitude': 34.566001892089844,
#   'longitude': 69.21199798583984,
#   'station': 'AFM00040948',
#   'tmax': 33.20000076293945,
#   'tmax_pred': 22.041914185571592},
#  {'date': datetime.date(2003, 6, 6),
#   'elevation': 24.0,
#   'features': DenseVector([36.7167, 3.25, 24.0]),
#   'latitude': 36.71670150756836,
#   'longitude': 3.25,
#   'station': 'AG000060390',
#   'tmax': 29.5,
#   'tmax_pred': 23.63216238947677},
#  {'date': datetime.date(2000, 7, 21),
#   'elevation': 397.0,
#   'features': DenseVector([30.5667, 2.8667, 397.0]),
#   'latitude': 30.566699981689453,
#   'longitude': 2.8666999340057373,
#   'station': 'AG000060590',
#   'tmax': 46.20000076293945,
#   'tmax_pred': 26.869567881268722},
#  {'date': datetime.date(2001, 11, 27),
#   'elevation': 397.0,
#   'features': DenseVector([30.5667, 2.8667, 397.0]),
#   'latitude': 30.566699981689453,
#   'longitude': 2.8666999340057373,
#   'station': 'AG000060590',
#   'tmax': 21.0,
#   'tmax_pred': 26.869567881268722},
#  {'date': datetime.date(2003, 10, 2),
#   'elevation': 561.0,
#   'features': DenseVector([28.05, 9.6331, 561.0]),
#   'latitude': 28.049999237060547,
#   'longitude': 9.633099555969238,
#   'station': 'AG000060611',
#   'tmax': 37.400001525878906,
#   'tmax_pred': 29.38630428704844},
#  {'date': datetime.date(2004, 5, 10),
#   'elevation': 561.0,
#   'features': DenseVector([28.05, 9.6331, 561.0]),
#   'latitude': 28.049999237060547,
#   'longitude': 9.633099555969238,
#   'station': 'AG000060611',
#   'tmax': 34.5,
#   'tmax_pred': 29.38630428704844},
#  {'date': datetime.date(2006, 5, 15),
#   'elevation': 561.0,
#   'features': DenseVector([28.05, 9.6331, 561.0]),
#   'latitude': 28.049999237060547,
#   'longitude': 9.633099555969238,
#   'station': 'AG000060611',
#   'tmax': 37.099998474121094,
#   'tmax_pred': 29.38630428704844},
#  {'date': datetime.date(2003, 3, 25),
#   'elevation': 1362.0,
#   'features': DenseVector([22.8, 5.4331, 1362.0]),
#   'latitude': 22.799999237060547,
#   'longitude': 5.43310022354126,
#   'station': 'AG000060680',
#   'tmax': 24.299999237060547,
#   'tmax_pred': 26.9584232173608},
#  {'date': datetime.date(2003, 4, 20),
#   'elevation': 1362.0,
#   'features': DenseVector([22.8, 5.4331, 1362.0]),
#   'latitude': 22.799999237060547,
#   'longitude': 5.43310022354126,
#   'station': 'AG000060680',
#   'tmax': 32.5,
#   'tmax_pred': 26.9584232173608},
#  {'date': datetime.date(2003, 5, 3),
#   'elevation': 1362.0,
#   'features': DenseVector([22.8, 5.4331, 1362.0]),
#   'latitude': 22.799999237060547,
#   'longitude': 5.43310022354126,
#   'station': 'AG000060680',
#   'tmax': 33.5,
#   'tmax_pred': 26.9584232173608},
#  {'date': datetime.date(2005, 10, 27),
#   'elevation': 1362.0,
#   'features': DenseVector([22.8, 5.4331, 1362.0]),
#   'latitude': 22.799999237060547,
#   'longitude': 5.43310022354126,
#   'station': 'AG000060680',
#   'tmax': 28.0,
#   'tmax_pred': 26.9584232173608},
#  {'date': datetime.date(2005, 11, 26),
#   'elevation': 1362.0,
#   'features': DenseVector([22.8, 5.4331, 1362.0]),
#   'latitude': 22.799999237060547,
#   'longitude': 5.43310022354126,
#   'station': 'AG000060680',
#   'tmax': 24.0,
#   'tmax_pred': 26.9584232173608},
#  {'date': datetime.date(2005, 12, 21),
#   'elevation': 1362.0,
#   'features': DenseVector([22.8, 5.4331, 1362.0]),
#   'latitude': 22.799999237060547,
#   'longitude': 5.43310022354126,
#   'station': 'AG000060680',
#   'tmax': 20.0,
#   'tmax_pred': 26.9584232173608},
#  {'date': datetime.date(2012, 1, 16),
#   'elevation': 1362.0,
#   'features': DenseVector([22.8, 5.4331, 1362.0]),
#   'latitude': 22.799999237060547,
#   'longitude': 5.43310022354126,
#   'station': 'AG000060680',
#   'tmax': 20.200000762939453,
#   'tmax_pred': 26.9584232173608},
#  {'date': datetime.date(2012, 12, 17),
#   'elevation': 1362.0,
#   'features': DenseVector([22.8, 5.4331, 1362.0]),
#   'latitude': 22.799999237060547,
#   'longitude': 5.43310022354126,
#   'station': 'AG000060680',
#   'tmax': 22.200000762939453,
#   'tmax_pred': 26.9584232173608},
#  {'date': datetime.date(2003, 6, 2),
#   'elevation': 222.0,
#   'features': DenseVector([36.72, 4.05, 222.0]),
#   'latitude': 36.720001220703125,
#   'longitude': 4.050000190734863,
#   'station': 'AGE00147708',
#   'tmax': 27.0,
#   'tmax_pred': 23.886860029384714},
#  {'date': datetime.date(2012, 11, 29),
#   'elevation': 222.0,
#   'features': DenseVector([36.72, 4.05, 222.0]),
#   'latitude': 36.720001220703125,
#   'longitude': 4.050000190734863,
#   'station': 'AGE00147708',
#   'tmax': 14.399999618530273,
#   'tmax_pred': 23.886860029384714},
#  {'date': datetime.date(2013, 12, 10),
#   'elevation': 222.0,
#   'features': DenseVector([36.72, 4.05, 222.0]),
#   'latitude': 36.720001220703125,
#   'longitude': 4.050000190734863,
#   'station': 'AGE00147708',
#   'tmax': 16.799999237060547,
#   'tmax_pred': 23.886860029384714},
#  {'date': datetime.date(2001, 12, 17),
#   'elevation': 83.0,
#   'features': DenseVector([35.1, -1.85, 83.0]),
#   'latitude': 35.099998474121094,
#   'longitude': -1.850000023841858,
#   'station': 'AGE00147716',
#   'tmax': 16.0,
#   'tmax_pred': 23.63440718631166},
#  {'date': datetime.date(2002, 6, 10),
#   'elevation': 83.0,
#   'features': DenseVector([35.1, -1.85, 83.0]),
#   'latitude': 35.099998474121094,
#   'longitude': -1.850000023841858,
#   'station': 'AGE00147716',
#   'tmax': 25.700000762939453,
#   'tmax_pred': 23.63440718631166},
#  {'date': datetime.date(2002, 11, 20),
#   'elevation': 83.0,
#   'features': DenseVector([35.1, -1.85, 83.0]),
#   'latitude': 35.099998474121094,
#   'longitude': -1.850000023841858,
#   'station': 'AGE00147716',
#   'tmax': 18.5,
#   'tmax_pred': 23.63440718631166},
#  {'date': datetime.date(2003, 3, 16),
#   'elevation': 83.0,
#   'features': DenseVector([35.1, -1.85, 83.0]),
#   'latitude': 35.099998474121094,
#   'longitude': -1.850000023841858,
#   'station': 'AGE00147716',
#   'tmax': 18.600000381469727,
#   'tmax_pred': 23.63440718631166},
#  {'date': datetime.date(2012, 1, 31),
#   'elevation': 83.0,
#   'features': DenseVector([35.1, -1.85, 83.0]),
#   'latitude': 35.099998474121094,
#   'longitude': -1.850000023841858,
#   'station': 'AGE00147716',
#   'tmax': 14.600000381469727,
#   'tmax_pred': 23.63440718631166},
#  {'date': datetime.date(2000, 3, 23),
#   'elevation': 125.0,
#   'features': DenseVector([34.85, 5.72, 125.0]),
#   'latitude': 34.849998474121094,
#   'longitude': 5.71999979019165,
#   'station': 'AGE00147718',
#   'tmax': 26.0,
#   'tmax_pred': 27.16922267123425},
#  {'date': datetime.date(2000, 7, 21),
#   'elevation': 125.0,
#   'features': DenseVector([34.85, 5.72, 125.0]),
#   'latitude': 34.849998474121094,
#   'longitude': 5.71999979019165,
#   'station': 'AGE00147718',
#   'tmax': 40.29999923706055,
#   'tmax_pred': 27.16922267123425},
#  {'date': datetime.date(2002, 5, 7),
#   'elevation': 125.0,
#   'features': DenseVector([34.85, 5.72, 125.0]),
#   'latitude': 34.849998474121094,
#   'longitude': 5.71999979019165,
#   'station': 'AGE00147718',
#   'tmax': 29.0,
#   'tmax_pred': 27.16922267123425},
#  {'date': datetime.date(2005, 8, 22),
#   'elevation': 11.0,
#   'features': DenseVector([36.795, 5.874, 11.0]),
#   'latitude': 36.79499816894531,
#   'longitude': 5.874000072479248,
#   'station': 'AGM00060351',
#   'tmax': 27.5,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2005, 9, 13),
#   'elevation': 11.0,
#   'features': DenseVector([36.795, 5.874, 11.0]),
#   'latitude': 36.79499816894531,
#   'longitude': 5.874000072479248,
#   'station': 'AGM00060351',
#   'tmax': 28.200000762939453,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2011, 5, 14),
#   'elevation': 11.0,
#   'features': DenseVector([36.795, 5.874, 11.0]),
#   'latitude': 36.79499816894531,
#   'longitude': 5.874000072479248,
#   'station': 'AGM00060351',
#   'tmax': 29.299999237060547,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2002, 3, 28),
#   'elevation': 6.0,
#   'features': DenseVector([36.817, 5.883, 6.0]),
#   'latitude': 36.81700134277344,
#   'longitude': 5.882999897003174,
#   'station': 'AGM00060353',
#   'tmax': 18.899999618530273,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2002, 12, 8),
#   'elevation': 6.0,
#   'features': DenseVector([36.817, 5.883, 6.0]),
#   'latitude': 36.81700134277344,
#   'longitude': 5.882999897003174,
#   'station': 'AGM00060353',
#   'tmax': 16.0,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2003, 5, 4),
#   'elevation': 6.0,
#   'features': DenseVector([36.817, 5.883, 6.0]),
#   'latitude': 36.81700134277344,
#   'longitude': 5.882999897003174,
#   'station': 'AGM00060353',
#   'tmax': 21.700000762939453,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2003, 6, 8),
#   'elevation': 6.0,
#   'features': DenseVector([36.817, 5.883, 6.0]),
#   'latitude': 36.81700134277344,
#   'longitude': 5.882999897003174,
#   'station': 'AGM00060353',
#   'tmax': 27.200000762939453,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2002, 4, 19),
#   'elevation': 7.0,
#   'features': DenseVector([36.933, 6.95, 7.0]),
#   'latitude': 36.93299865722656,
#   'longitude': 6.949999809265137,
#   'station': 'AGM00060355',
#   'tmax': 18.0,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2002, 6, 10),
#   'elevation': 7.0,
#   'features': DenseVector([36.933, 6.95, 7.0]),
#   'latitude': 36.93299865722656,
#   'longitude': 6.949999809265137,
#   'station': 'AGM00060355',
#   'tmax': 25.5,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2003, 2, 22),
#   'elevation': 7.0,
#   'features': DenseVector([36.933, 6.95, 7.0]),
#   'latitude': 36.93299865722656,
#   'longitude': 6.949999809265137,
#   'station': 'AGM00060355',
#   'tmax': 17.299999237060547,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2003, 9, 27),
#   'elevation': 7.0,
#   'features': DenseVector([36.933, 6.95, 7.0]),
#   'latitude': 36.93299865722656,
#   'longitude': 6.949999809265137,
#   'station': 'AGM00060355',
#   'tmax': 24.799999237060547,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2005, 11, 30),
#   'elevation': 7.0,
#   'features': DenseVector([36.933, 6.95, 7.0]),
#   'latitude': 36.93299865722656,
#   'longitude': 6.949999809265137,
#   'station': 'AGM00060355',
#   'tmax': 13.0,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2015, 12, 28),
#   'elevation': 7.0,
#   'features': DenseVector([36.933, 6.95, 7.0]),
#   'latitude': 36.93299865722656,
#   'longitude': 6.949999809265137,
#   'station': 'AGM00060355',
#   'tmax': 20.299999237060547,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2000, 9, 11),
#   'elevation': 4.900000095367432,
#   'features': DenseVector([36.822, 7.809, 4.9]),
#   'latitude': 36.821998596191406,
#   'longitude': 7.809000015258789,
#   'station': 'AGM00060360',
#   'tmax': 28.5,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2000, 11, 24),
#   'elevation': 4.900000095367432,
#   'features': DenseVector([36.822, 7.809, 4.9]),
#   'latitude': 36.821998596191406,
#   'longitude': 7.809000015258789,
#   'station': 'AGM00060360',
#   'tmax': 16.799999237060547,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2001, 10, 8),
#   'elevation': 4.900000095367432,
#   'features': DenseVector([36.822, 7.809, 4.9]),
#   'latitude': 36.821998596191406,
#   'longitude': 7.809000015258789,
#   'station': 'AGM00060360',
#   'tmax': 29.0,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2002, 11, 14),
#   'elevation': 4.900000095367432,
#   'features': DenseVector([36.822, 7.809, 4.9]),
#   'latitude': 36.821998596191406,
#   'longitude': 7.809000015258789,
#   'station': 'AGM00060360',
#   'tmax': 27.799999237060547,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2002, 12, 24),
#   'elevation': 4.900000095367432,
#   'features': DenseVector([36.822, 7.809, 4.9]),
#   'latitude': 36.821998596191406,
#   'longitude': 7.809000015258789,
#   'station': 'AGM00060360',
#   'tmax': 21.0,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2003, 2, 10),
#   'elevation': 4.900000095367432,
#   'features': DenseVector([36.822, 7.809, 4.9]),
#   'latitude': 36.821998596191406,
#   'longitude': 7.809000015258789,
#   'station': 'AGM00060360',
#   'tmax': 11.300000190734863,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2001, 10, 14),
#   'elevation': 13.0,
#   'features': DenseVector([36.9, 8.45, 13.0]),
#   'latitude': 36.900001525878906,
#   'longitude': 8.449999809265137,
#   'station': 'AGM00060367',
#   'tmax': 26.799999237060547,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2003, 10, 9),
#   'elevation': 12.0,
#   'features': DenseVector([36.767, 3.1, 12.0]),
#   'latitude': 36.766998291015625,
#   'longitude': 3.0999999046325684,
#   'station': 'AGM00060369',
#   'tmax': 23.399999618530273,
#   'tmax_pred': 23.55268599177846},
#  {'date': datetime.date(2003, 9, 27),
#   'elevation': 6.099999904632568,
#   'features': DenseVector([36.712, 5.07, 6.1]),
#   'latitude': 36.71200180053711,
#   'longitude': 5.070000171661377,
#   'station': 'AGM00060402',
#   'tmax': 26.0,
#   'tmax_pred': 23.51639494993177},
#  {'date': datetime.date(2002, 4, 1),
#   'elevation': 228.0,
#   'features': DenseVector([36.467, 7.467, 228.0]),
#   'latitude': 36.46699905395508,
#   'longitude': 7.4670000076293945,
#   'station': 'AGM00060403',
#   'tmax': 24.600000381469727,
#   'tmax_pred': 25.721512519680154},
#  {'date': datetime.date(2002, 11, 22),
#   'elevation': 228.0,
#   'features': DenseVector([36.467, 7.467, 228.0]),
#   'latitude': 36.46699905395508,
#   'longitude': 7.4670000076293945,
#   'station': 'AGM00060403',
#   'tmax': 22.600000381469727,
#   'tmax_pred': 25.721512519680154},
#  {'date': datetime.date(2005, 11, 7),
#   'elevation': 228.0,
#   'features': DenseVector([36.467, 7.467, 228.0]),
#   'latitude': 36.46699905395508,
#   'longitude': 7.4670000076293945,
#   'station': 'AGM00060403',
#   'tmax': 24.0,
#   'tmax_pred': 25.721512519680154},
#  {'date': datetime.date(2007, 12, 9),
#   'elevation': 228.0,
#   'features': DenseVector([36.467, 7.467, 228.0]),
#   'latitude': 36.46699905395508,
#   'longitude': 7.4670000076293945,
#   'station': 'AGM00060403',
#   'tmax': 23.399999618530273,
#   'tmax_pred': 25.721512519680154},
#  {'date': datetime.date(2011, 6, 7),
#   'elevation': 228.0,
#   'features': DenseVector([36.467, 7.467, 228.0]),
#   'latitude': 36.46699905395508,
#   'longitude': 7.4670000076293945,
#   'station': 'AGM00060403',
#   'tmax': 26.200000762939453,
#   'tmax_pred': 25.721512519680154},
#  {'date': datetime.date(2003, 4, 4),
#   'elevation': 111.0,
#   'features': DenseVector([36.5, 7.717, 111.0]),
#   'latitude': 36.5,
#   'longitude': 7.7170000076293945,
#   'station': 'AGM00060405',
#   'tmax': 13.0,
#   'tmax_pred': 25.603692555941738},
#  {'date': datetime.date(2002, 6, 3),
#   'elevation': 690.4000244140625,
#   'features': DenseVector([36.276, 6.62, 690.4]),
#   'latitude': 36.2760009765625,
#   'longitude': 6.619999885559082,
#   'station': 'AGM00060419',
#   'tmax': 35.29999923706055,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2003, 10, 8),
#   'elevation': 690.4000244140625,
#   'features': DenseVector([36.276, 6.62, 690.4]),
#   'latitude': 36.2760009765625,
#   'longitude': 6.619999885559082,
#   'station': 'AGM00060419',
#   'tmax': 20.600000381469727,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2005, 11, 6),
#   'elevation': 690.4000244140625,
#   'features': DenseVector([36.276, 6.62, 690.4]),
#   'latitude': 36.2760009765625,
#   'longitude': 6.619999885559082,
#   'station': 'AGM00060419',
#   'tmax': 19.0,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2005, 8, 23),
#   'elevation': 891.0,
#   'features': DenseVector([35.867, 7.117, 891.0]),
#   'latitude': 35.867000579833984,
#   'longitude': 7.117000102996826,
#   'station': 'AGM00060421',
#   'tmax': 27.700000762939453,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2005, 10, 20),
#   'elevation': 891.0,
#   'features': DenseVector([35.867, 7.117, 891.0]),
#   'latitude': 35.867000579833984,
#   'longitude': 7.117000102996826,
#   'station': 'AGM00060421',
#   'tmax': 25.200000762939453,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2005, 11, 19),
#   'elevation': 891.0,
#   'features': DenseVector([35.867, 7.117, 891.0]),
#   'latitude': 35.867000579833984,
#   'longitude': 7.117000102996826,
#   'station': 'AGM00060421',
#   'tmax': 16.600000381469727,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2011, 12, 28),
#   'elevation': 891.0,
#   'features': DenseVector([35.867, 7.117, 891.0]),
#   'latitude': 35.867000579833984,
#   'longitude': 7.117000102996826,
#   'station': 'AGM00060421',
#   'tmax': 9.399999618530273,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2002, 11, 20),
#   'elevation': 680.0,
#   'features': DenseVector([36.283, 7.967, 680.0]),
#   'latitude': 36.28300094604492,
#   'longitude': 7.9670000076293945,
#   'station': 'AGM00060423',
#   'tmax': 16.200000762939453,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2004, 3, 19),
#   'elevation': 680.0,
#   'features': DenseVector([36.283, 7.967, 680.0]),
#   'latitude': 36.28300094604492,
#   'longitude': 7.9670000076293945,
#   'station': 'AGM00060423',
#   'tmax': 18.5,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2004, 3, 29),
#   'elevation': 680.0,
#   'features': DenseVector([36.283, 7.967, 680.0]),
#   'latitude': 36.28300094604492,
#   'longitude': 7.9670000076293945,
#   'station': 'AGM00060423',
#   'tmax': 17.700000762939453,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2013, 12, 20),
#   'elevation': 680.0,
#   'features': DenseVector([36.283, 7.967, 680.0]),
#   'latitude': 36.28300094604492,
#   'longitude': 7.9670000076293945,
#   'station': 'AGM00060423',
#   'tmax': 13.600000381469727,
#   'tmax_pred': 22.066636711410975},
#  {'date': datetime.date(2000, 3, 16),
#   'elevation': 141.10000610351562,
#   'features': DenseVector([36.213, 1.332, 141.1]),
#   'latitude': 36.2130012512207,
#   'longitude': 1.3320000171661377,
#   'station': 'AGM00060425',
#   'tmax': 19.5,
#   'tmax_pred': 25.597450840244882},
#  {'date': datetime.date(2000, 10, 25),
#   'elevation': 141.10000610351562,
#   'features': DenseVector([36.213, 1.332, 141.1]),
#   'latitude': 36.2130012512207,
#   'longitude': 1.3320000171661377,
#   'station': 'AGM00060425',
#   'tmax': 23.0,
#   'tmax_pred': 25.597450840244882},
#  {'date': datetime.date(2001, 1, 14),
#   'elevation': 141.10000610351562,
#   'features': DenseVector([36.213, 1.332, 141.1]),
#   'latitude': 36.2130012512207,
#   'longitude': 1.3320000171661377,
#   'station': 'AGM00060425',
#   'tmax': 14.100000381469727,
#   'tmax_pred': 25.597450840244882},
#  {'date': datetime.date(2002, 4, 22),
#   'elevation': 141.10000610351562,
#   'features': DenseVector([36.213, 1.332, 141.1]),
#   'latitude': 36.2130012512207,
#   'longitude': 1.3320000171661377,
#   'station': 'AGM00060425',
#   'tmax': 21.799999237060547,
#   'tmax_pred': 25.597450840244882},
#  {'date': datetime.date(2006, 7, 3),
#   'elevation': 141.10000610351562,
#   'features': DenseVector([36.213, 1.332, 141.1]),
#   'latitude': 36.2130012512207,
#   'longitude': 1.3320000171661377,
#   'station': 'AGM00060425',
#   'tmax': 39.70000076293945,
#   'tmax_pred': 25.597450840244882},
#  {'date': datetime.date(2003, 6, 17),
#   'elevation': 1036.0,
#   'features': DenseVector([36.283, 2.733, 1036.0]),
#   'latitude': 36.28300094604492,
#   'longitude': 2.7330000400543213,
#   'station': 'AGM00060437',
#   'tmax': 27.0,
#   'tmax_pred': 22.068291804344682},
#  {'date': datetime.date(2011, 5, 12),
#   'elevation': 1036.0,
#   'features': DenseVector([36.283, 2.733, 1036.0]),
#   'latitude': 36.28300094604492,
#   'longitude': 2.7330000400543213,
#   'station': 'AGM00060437',
#   'tmax': 24.600000381469727,
#   'tmax_pred': 22.068291804344682},
#  {'date': datetime.date(2000, 10, 15),
#   'elevation': 930.0,
#   'features': DenseVector([36.067, 4.767, 930.0]),
#   'latitude': 36.06700134277344,
#   'longitude': 4.767000198364258,
#   'station': 'AGM00060444',
#   'tmax': 15.5,
#   'tmax_pred': 22.15183758366726},
#  {'date': datetime.date(2001, 1, 27),
#   'elevation': 930.0,
#   'features': DenseVector([36.067, 4.767, 930.0]),
#   'latitude': 36.06700134277344,
#   'longitude': 4.767000198364258,
#   'station': 'AGM00060444',
#   'tmax': 10.199999809265137,
#   'tmax_pred': 22.15183758366726},
#  {'date': datetime.date(2002, 6, 21),
#   'elevation': 930.0,
#   'features': DenseVector([36.067, 4.767, 930.0]),
#   'latitude': 36.06700134277344,
#   'longitude': 4.767000198364258,
#   'station': 'AGM00060444',
#   'tmax': 36.400001525878906,
#   'tmax_pred': 22.15183758366726},
#  {'date': datetime.date(2002, 11, 13),
#   'elevation': 930.0,
#   'features': DenseVector([36.067, 4.767, 930.0]),
#   'latitude': 36.06700134277344,
#   'longitude': 4.767000198364258,
#   'station': 'AGM00060444',
#   'tmax': 20.0,
#   'tmax_pred': 22.15183758366726},
#  {'date': datetime.date(2003, 5, 20),
#   'elevation': 930.0,
#   'features': DenseVector([36.067, 4.767, 930.0]),
#   'latitude': 36.06700134277344,
#   'longitude': 4.767000198364258,
#   'station': 'AGM00060444',
#   'tmax': 27.899999618530273,
#   'tmax_pred': 22.15183758366726},
#  {'date': datetime.date(2000, 12, 9),
#   'elevation': 1050.0,
#   'features': DenseVector([36.178, 5.324, 1050.0]),
#   'latitude': 36.178001403808594,
#   'longitude': 5.323999881744385,
#   'station': 'AGM00060445',
#   'tmax': 15.699999809265137,
#   'tmax_pred': 22.157635538911926},
#  {'date': datetime.date(2002, 5, 12),
#   'elevation': 1050.0,
#   'features': DenseVector([36.178, 5.324, 1050.0]),
#   'latitude': 36.178001403808594,
#   'longitude': 5.323999881744385,
#   'station': 'AGM00060445',
#   'tmax': 18.399999618530273,
#   'tmax_pred': 22.157635538911926},
#  {'date': datetime.date(2003, 11, 20),
#   'elevation': 1050.0,
#   'features': DenseVector([36.178, 5.324, 1050.0]),
#   'latitude': 36.178001403808594,
#   'longitude': 5.323999881744385,
#   'station': 'AGM00060445',
#   'tmax': 14.0,
#   'tmax_pred': 22.157635538911926},
#  {'date': datetime.date(2011, 5, 27),
#   'elevation': 1050.0,
#   'features': DenseVector([36.178, 5.324, 1050.0]),
#   'latitude': 36.178001403808594,
#   'longitude': 5.323999881744385,
#   'station': 'AGM00060445',
#   'tmax': 27.0,
#   'tmax_pred': 22.157635538911926},
#  {'date': datetime.date(2012, 12, 27),
#   'elevation': 1050.0,
#   'features': DenseVector([36.178, 5.324, 1050.0]),
#   'latitude': 36.178001403808594,
#   'longitude': 5.323999881744385,
#   'station': 'AGM00060445',
#   'tmax': 11.699999809265137,
#   'tmax_pred': 22.157635538911926},
#  {'date': datetime.date(2001, 12, 13),
#   'elevation': 4.0,
#   'features': DenseVector([35.817, -0.267, 4.0]),
#   'latitude': 35.81700134277344,
#   'longitude': -0.2669999897480011,
#   'station': 'AGM00060452',
#   'tmax': 16.200000762939453,
#   'tmax_pred': 22.781621214908952},
#  {'date': datetime.date(2003, 3, 16),
#   'elevation': 4.0,
#   'features': DenseVector([35.817, -0.267, 4.0]),
#   'latitude': 35.81700134277344,
#   'longitude': -0.2669999897480011,
#   'station': 'AGM00060452',
#   'tmax': 16.799999237060547,
#   'tmax_pred': 22.781621214908952},
#  {'date': datetime.date(2003, 4, 22),
#   'elevation': 4.0,
#   'features': DenseVector([35.817, -0.267, 4.0]),
#   'latitude': 35.81700134277344,
#   'longitude': -0.2669999897480011,
#   'station': 'AGM00060452',
#   'tmax': 18.0,
#   'tmax_pred': 22.781621214908952},
#  {'date': datetime.date(2003, 6, 24),
#   'elevation': 4.0,
#   'features': DenseVector([35.817, -0.267, 4.0]),
#   'latitude': 35.81700134277344,
#   'longitude': -0.2669999897480011,
#   'station': 'AGM00060452',
#   'tmax': 32.599998474121094,
#   'tmax_pred': 22.781621214908952},
#  {'date': datetime.date(2012, 1, 24),
#   'elevation': 4.0,
#   'features': DenseVector([35.817, -0.267, 4.0]),
#   'latitude': 35.81700134277344,
#   'longitude': -0.2669999897480011,
#   'station': 'AGM00060452',
#   'tmax': 16.600000381469727,
#   'tmax_pred': 22.781621214908952},
#  {'date': datetime.date(2012, 2, 4),
#   'elevation': 4.0,
#   'features': DenseVector([35.817, -0.267, 4.0]),
#   'latitude': 35.81700134277344,
#   'longitude': -0.2669999897480011,
#   'station': 'AGM00060452',
#   'tmax': 9.699999809265137,
#   'tmax_pred': 22.781621214908952},
#  {'date': datetime.date(2003, 3, 1),
#   'elevation': 138.0,
#   'features': DenseVector([35.883, 0.117, 138.0]),
#   'latitude': 35.882999420166016,
#   'longitude': 0.11699999868869781,
#   'station': 'AGM00060457',
#   'tmax': 21.600000381469727,
#   'tmax_pred': 25.597450840244882},
#  {'date': datetime.date(2006, 6, 29),
#   'elevation': 138.0,
#   'features': DenseVector([35.883, 0.117, 138.0]),
#   'latitude': 35.882999420166016,
#   'longitude': 0.11699999868869781,
#   'station': 'AGM00060457',
#   'tmax': 27.0,
#   'tmax_pred': 25.597450840244882},
#  {'date': datetime.date(2012, 1, 6),
#   'elevation': 138.0,
#   'features': DenseVector([35.883, 0.117, 138.0]),
#   'latitude': 35.882999420166016,
#   'longitude': 0.11699999868869781,
#   'station': 'AGM00060457',
#   'tmax': 18.399999618530273,
#   'tmax_pred': 25.597450840244882},
#  {'date': datetime.date(2013, 11, 14),
#   'elevation': 138.0,
#   'features': DenseVector([35.883, 0.117, 138.0]),
#   'latitude': 35.882999420166016,
#   'longitude': 0.11699999868869781,
#   'station': 'AGM00060457',
#   'tmax': 19.600000381469727,
#   'tmax_pred': 25.597450840244882},
#  {'date': datetime.date(2015, 12, 22),
#   'elevation': 138.0,
#   'features': DenseVector([35.883, 0.117, 138.0]),
#   'latitude': 35.882999420166016,
#   'longitude': 0.11699999868869781,
#   'station': 'AGM00060457',
#   'tmax': 20.399999618530273,
#   'tmax_pred': 25.597450840244882},
#  {'date': datetime.date(2007, 12, 3),
#   'elevation': 22.0,
#   'features': DenseVector([35.7, -0.65, 22.0]),
#   'latitude': 35.70000076293945,
#   'longitude': -0.6499999761581421,
#   'station': 'AGM00060461',
#   'tmax': 18.799999237060547,
#   'tmax_pred': 23.141377314417934},
#  {'date': datetime.date(2000, 4, 9),
#   'elevation': 442.0,
#   'features': DenseVector([35.667, 4.5, 442.0]),
#   'latitude': 35.66699981689453,
#   'longitude': 4.5,
#   'station': 'AGM00060467',
#   'tmax': 25.799999237060547,
#   'tmax_pred': 26.336588998061778},
#  {'date': datetime.date(2000, 6, 13),
#   'elevation': 1052.0,
#   'features': DenseVector([35.55, 6.183, 1052.0]),
#   'latitude': 35.54999923706055,
#   'longitude': 6.183000087738037,
#   'station': 'AGM00060468',
#   'tmax': 24.0,
#   'tmax_pred': 22.739528773926157},
#  {'date': datetime.date(2000, 8, 15),
#   'elevation': 1052.0,
#   'features': DenseVector([35.55, 6.183, 1052.0]),
#   'latitude': 35.54999923706055,
#   'longitude': 6.183000087738037,
#   'station': 'AGM00060468',
#   'tmax': 31.600000381469727,
#   'tmax_pred': 22.739528773926157},
#  {'date': datetime.date(2001, 5, 4),
#   'elevation': 1052.0,
#   'features': DenseVector([35.55, 6.183, 1052.0]),
#   'latitude': 35.54999923706055,
#   'longitude': 6.183000087738037,
#   'station': 'AGM00060468',
#   'tmax': 17.0,
#   'tmax_pred': 22.739528773926157},
#  {'date': datetime.date(2002, 7, 12),
#   'elevation': 1052.0,
#   'features': DenseVector([35.55, 6.183, 1052.0]),
#   'latitude': 35.54999923706055,
#   'longitude': 6.183000087738037,
#   'station': 'AGM00060468',
#   'tmax': 38.599998474121094,
#   'tmax_pred': 22.739528773926157},
#  {'date': datetime.date(2000, 7, 2),
#   'elevation': 811.0999755859375,
#   'features': DenseVector([35.432, 8.121, 811.1]),
#   'latitude': 35.43199920654297,
#   'longitude': 8.121000289916992,
#   'station': 'AGM00060475',
#   'tmax': 38.0,
#   'tmax_pred': 22.488770987786772},
#  {'date': datetime.date(2001, 5, 3),
#   'elevation': 811.0999755859375,
#   'features': DenseVector([35.432, 8.121, 811.1]),
#   'latitude': 35.43199920654297,
#   'longitude': 8.121000289916992,
#   'station': 'AGM00060475',
#   'tmax': 24.0,
#   'tmax_pred': 22.488770987786772},
#  {'date': datetime.date(2002, 6, 24),
#   'elevation': 811.0999755859375,
#   'features': DenseVector([35.432, 8.121, 811.1]),
#   'latitude': 35.43199920654297,
#   'longitude': 8.121000289916992,
#   'station': 'AGM00060475',
#   'tmax': 33.900001525878906,
#   'tmax_pred': 22.488770987786772},
#  {'date': datetime.date(2003, 5, 9),
#   'elevation': 811.0999755859375,
#   'features': DenseVector([35.432, 8.121, 811.1]),
#   'latitude': 35.43199920654297,
#   'longitude': 8.121000289916992,
#   'station': 'AGM00060475',
#   'tmax': 29.200000762939453,
#   'tmax_pred': 22.488770987786772},
#  {'date': datetime.date(2003, 5, 11),
#   'elevation': 811.0999755859375,
#   'features': DenseVector([35.432, 8.121, 811.1]),
#   'latitude': 35.43199920654297,
#   'longitude': 8.121000289916992,
#   'station': 'AGM00060475',
#   'tmax': 24.0,
#   'tmax_pred': 22.488770987786772},
#  {'date': datetime.date(2013, 12, 31),
#   'elevation': 811.0999755859375,
#   'features': DenseVector([35.432, 8.121, 811.1]),
#   'latitude': 35.43199920654297,
#   'longitude': 8.121000289916992,
#   'station': 'AGM00060475',
#   'tmax': 9.399999618530273,
#   'tmax_pred': 22.488770987786772},
#  {'date': datetime.date(2002, 3, 11),
#   'elevation': 987.0,
#   'features': DenseVector([35.467, 7.083, 987.0]),
#   'latitude': 35.46699905395508,
#   'longitude': 7.083000183105469,
#   'station': 'AGM00060476',
#   'tmax': 17.700000762939453,
#   'tmax_pred': 22.739528773926157},
#  {'date': datetime.date(2002, 5, 17),
#   'elevation': 987.0,
#   'features': DenseVector([35.467, 7.083, 987.0]),
#   'latitude': 35.46699905395508,
#   'longitude': 7.083000183105469,
#   'station': 'AGM00060476',
#   'tmax': 32.5,
#   'tmax_pred': 22.739528773926157},
#  {'date': datetime.date(2002, 4, 27),
#   'elevation': 89.9000015258789,
#   'features': DenseVector([35.624, -0.621, 89.9]),
#   'latitude': 35.624000549316406,
#   'longitude': -0.6209999918937683,
#   'station': 'AGM00060490',
#   'tmax': 31.600000381469727,
#   'tmax_pred': 25.97740869668642},
#  {'date': datetime.date(2013, 12, 18),
#   'elevation': 89.9000015258789,
#   'features': DenseVector([35.624, -0.621, 89.9]),
#   'latitude': 35.624000549316406,
#   'longitude': -0.6209999918937683,
#   'station': 'AGM00060490',
#   'tmax': 17.0,
#   'tmax_pred': 25.97740869668642},
#  {'date': datetime.date(2003, 5, 17),
#   'elevation': 513.9000244140625,
#   'features': DenseVector([35.208, 0.147, 513.9]),
#   'latitude': 35.20800018310547,
#   'longitude': 0.1469999998807907,
#   'station': 'AGM00060507',
#   'tmax': 25.700000762939453,
#   'tmax_pred': 26.28046265893714},
#  {'date': datetime.date(2011, 6, 21),
#   'elevation': 513.9000244140625,
#   'features': DenseVector([35.208, 0.147, 513.9]),
#   'latitude': 35.20800018310547,
#   'longitude': 0.1469999998807907,
#   'station': 'AGM00060507',
#   'tmax': 35.400001525878906,
#   'tmax_pred': 26.28046265893714},
#  {'date': datetime.date(2012, 1, 9),
#   'elevation': 513.9000244140625,
#   'features': DenseVector([35.208, 0.147, 513.9]),
#   'latitude': 35.20800018310547,
#   'longitude': 0.1469999998807907,
#   'station': 'AGM00060507',
#   'tmax': 15.399999618530273,
#   'tmax_pred': 26.28046265893714},
#  {'date': datetime.date(2000, 9, 23),
#   'elevation': 989.0999755859375,
#   'features': DenseVector([35.341, 1.463, 989.1]),
#   'latitude': 35.340999603271484,
#   'longitude': 1.4630000591278076,
#   'station': 'AGM00060511',
#   'tmax': 28.299999237060547,
#   'tmax_pred': 22.254695181908485},
#  {'date': datetime.date(2000, 10, 27),
#   'elevation': 989.0999755859375,
#   'features': DenseVector([35.341, 1.463, 989.1]),
#   'latitude': 35.340999603271484,
#   'longitude': 1.4630000591278076,
#   'station': 'AGM00060511',
#   'tmax': 16.700000762939453,
#   'tmax_pred': 22.254695181908485},
#  {'date': datetime.date(2002, 12, 19),
#   'elevation': 989.0999755859375,
#   'features': DenseVector([35.341, 1.463, 989.1]),
#   'latitude': 35.340999603271484,
#   'longitude': 1.4630000591278076,
#   'station': 'AGM00060511',
#   'tmax': 14.399999618530273,
#   'tmax_pred': 22.254695181908485},
#  {'date': datetime.date(2012, 2, 22),
#   'elevation': 801.0,
#   'features': DenseVector([35.167, 2.317, 801.0]),
#   'latitude': 35.16699981689453,
#   'longitude': 2.316999912261963,
#   'station': 'AGM00060514',
#   'tmax': 8.5,
#   'tmax_pred': 22.0039373957691},
#  {'date': datetime.date(2000, 3, 31),
#   'elevation': 459.0,
#   'features': DenseVector([35.333, 4.206, 459.0]),
#   'latitude': 35.33300018310547,
#   'longitude': 4.205999851226807,
#   'station': 'AGM00060515',
#   'tmax': 26.0,
#   'tmax_pred': 26.336588998061778},
#  {'date': datetime.date(2001, 3, 9),
#   'elevation': 459.0,
#   'features': DenseVector([35.333, 4.206, 459.0]),
#   'latitude': 35.33300018310547,
#   'longitude': 4.205999851226807,
#   'station': 'AGM00060515',
#   'tmax': 21.5,
#   'tmax_pred': 26.336588998061778},
#  {'date': datetime.date(2002, 3, 28),
#   'elevation': 459.0,
#   'features': DenseVector([35.333, 4.206, 459.0]),
#   'latitude': 35.33300018310547,
#   'longitude': 4.205999851226807,
#   'station': 'AGM00060515',
#   'tmax': 21.0,
#   'tmax_pred': 26.336588998061778},
#  {'date': datetime.date(2002, 7, 4),
#   'elevation': 459.0,
#   'features': DenseVector([35.333, 4.206, 459.0]),
#   'latitude': 35.33300018310547,
#   'longitude': 4.205999851226807,
#   'station': 'AGM00060515',
#   'tmax': 40.599998474121094,
#   'tmax_pred': 26.336588998061778},
#  {'date': datetime.date(2001, 3, 27),
#   'elevation': 70.0,
#   'features': DenseVector([35.3, -1.35, 70.0]),
#   'latitude': 35.29999923706055,
#   'longitude': -1.350000023841858,
#   'station': 'AGM00060518',
#   'tmax': 19.5,
#   'tmax_pred': 23.63440718631166},
#  {'date': datetime.date(2002, 4, 9),
#   'elevation': 70.0,
#   'features': DenseVector([35.3, -1.35, 70.0]),
#   'latitude': 35.29999923706055,
#   'longitude': -1.350000023841858,
#   'station': 'AGM00060518',
#   'tmax': 19.600000381469727,
#   'tmax_pred': 23.63440718631166},
#  {'date': datetime.date(2012, 12, 10),
#   'elevation': 70.0,
#   'features': DenseVector([35.3, -1.35, 70.0]),
#   'latitude': 35.29999923706055,
#   'longitude': -1.350000023841858,
#   'station': 'AGM00060518',
#   'tmax': 18.399999618530273,
#   'tmax_pred': 23.63440718631166},
#  {'date': datetime.date(2002, 6, 20),
#   'elevation': 476.0,
#   'features': DenseVector([35.2, -0.617, 476.0]),
#   'latitude': 35.20000076293945,
#   'longitude': -0.6169999837875366,
#   'station': 'AGM00060520',
#   'tmax': 33.900001525878906,
#   'tmax_pred': 26.28046265893714},
#  {'date': datetime.date(2012, 2, 7),
#   'elevation': 476.0,
#   'features': DenseVector([35.2, -0.617, 476.0]),
#   'latitude': 35.20000076293945,
#   'longitude': -0.6169999837875366,
#   'station': 'AGM00060520',
#   'tmax': 12.800000190734863,
#   'tmax_pred': 26.28046265893714},
#  {'date': datetime.date(2003, 2, 9),
#   'elevation': 426.0,
#   'features': DenseVector([34.82, -1.77, 426.0]),
#   'latitude': 34.81999969482422,
#   'longitude': -1.7699999809265137,
#   'station': 'AGM00060522',
#   'tmax': 10.5,
#   'tmax_pred': 26.28046265893714},
#  {'date': datetime.date(2011, 5, 27),
#   'elevation': 426.0,
#   'features': DenseVector([34.82, -1.77, 426.0]),
#   'latitude': 34.81999969482422,
#   'longitude': -1.7699999809265137,
#   'station': 'AGM00060522',
#   'tmax': 29.100000381469727,
#   'tmax_pred': 26.28046265893714},
#  {'date': datetime.date(2004, 4, 13),
#   'elevation': 248.10000610351562,
#   'features': DenseVector([35.017, -1.45, 248.1]),
#   'latitude': 35.016998291015625,
#   'longitude': -1.4500000476837158,
#   'station': 'AGM00060531',
#   'tmax': 20.700000762939453,
#   'tmax_pred': 25.741329675104335},
#  {'date': datetime.date(2005, 10, 18),
#   'elevation': 248.10000610351562,
#   'features': DenseVector([35.017, -1.45, 248.1]),
#   'latitude': 35.016998291015625,
#   'longitude': -1.4500000476837158,
#   'station': 'AGM00060531',
#   'tmax': 24.799999237060547,
#   'tmax_pred': 25.741329675104335},
#  {'date': datetime.date(2006, 6, 11),
#   'elevation': 248.10000610351562,
#   'features': DenseVector([35.017, -1.45, 248.1]),
#   'latitude': 35.016998291015625,
#   'longitude': -1.4500000476837158,
#   'station': 'AGM00060531',
#   'tmax': 26.5,
#   'tmax_pred': 25.741329675104335},
#  {'date': datetime.date(2002, 10, 12),
#   'elevation': 1144.0,
#   'features': DenseVector([34.683, 3.25, 1144.0]),
#   'latitude': 34.68299865722656,
#   'longitude': 3.25,
#   'station': 'AGM00060535',
#   'tmax': 14.5,
#   'tmax_pred': 23.17287426646139},
#  {'date': datetime.date(2013, 12, 28),
#   'elevation': 1144.0,
#   'features': DenseVector([34.683, 3.25, 1144.0]),
#   'latitude': 34.68299865722656,
#   'longitude': 3.25,
#   'station': 'AGM00060535',
#   'tmax': 12.0,
#   'tmax_pred': 23.17287426646139},
#  {'date': datetime.date(2003, 10, 12),
#   'elevation': 752.0,
#   'features': DenseVector([34.867, 0.15, 752.0]),
#   'latitude': 34.867000579833984,
#   'longitude': 0.15000000596046448,
#   'station': 'AGM00060536',
#   'tmax': 31.5,
#   'tmax_pred': 22.0039373957691},
#  {'date': datetime.date(2012, 2, 16),
#   'elevation': 752.0,
#   'features': DenseVector([34.867, 0.15, 752.0]),
#   'latitude': 34.867000579833984,
#   'longitude': 0.15000000596046448,
#   'station': 'AGM00060536',
#   'tmax': 11.600000381469727,
#   'tmax_pred': 22.0039373957691},
#  {'date': datetime.date(2003, 3, 24),
#   'elevation': 1001.0,
#   'features': DenseVector([34.15, 0.067, 1001.0]),
#   'latitude': 34.150001525878906,
#   'longitude': 0.06700000166893005,
#   'station': 'AGM00060540',
#   'tmax': 17.700000762939453,
#   'tmax_pred': 23.728931547061794},
#  {'date': datetime.date(2015, 11, 28),
#   'elevation': 1001.0,
#   'features': DenseVector([34.15, 0.067, 1001.0]),
#   'latitude': 34.150001525878906,
#   'longitude': 0.06700000166893005,
#   'station': 'AGM00060540',
#   'tmax': 14.699999809265137,
#   'tmax_pred': 23.728931547061794},
#  {'date': datetime.date(2000, 10, 29),
#   'elevation': 1175.0,
#   'features': DenseVector([33.536, -0.242, 1175.0]),
#   'latitude': 33.5359992980957,
#   'longitude': -0.24199999868869781,
#   'station': 'AGM00060549',
#   'tmax': 19.700000762939453,
#   'tmax_pred': 24.52181230487353},
#  {'date': datetime.date(2002, 9, 30),
#   'elevation': 1175.0,
#   'features': DenseVector([33.536, -0.242, 1175.0]),
#   'latitude': 33.5359992980957,
#   'longitude': -0.24199999868869781,
#   'station': 'AGM00060549',
#   'tmax': 25.399999618530273,
#   'tmax_pred': 24.52181230487353},
#  {'date': datetime.date(2004, 12, 22),
#   'elevation': 1175.0,
#   'features': DenseVector([33.536, -0.242, 1175.0]),
#   'latitude': 33.5359992980957,
#   'longitude': -0.24199999868869781,
#   'station': 'AGM00060549',
#   'tmax': 13.300000190734863,
#   'tmax_pred': 24.52181230487353},
#  {'date': datetime.date(2015, 11, 28),
#   'elevation': 1175.0,
#   'features': DenseVector([33.536, -0.242, 1175.0]),
#   'latitude': 33.5359992980957,
#   'longitude': -0.24199999868869781,
#   'station': 'AGM00060549',
#   'tmax': 17.700000762939453,
#   'tmax_pred': 24.52181230487353},
#  {'date': datetime.date(2002, 5, 21),
#   'elevation': 1347.0,
#   'features': DenseVector([33.667, 1.0, 1347.0]),
#   'latitude': 33.66699981689453,
#   'longitude': 1.0,
#   'station': 'AGM00060550',
#   'tmax': 31.799999237060547,
#   'tmax_pred': 23.386917012644574},
#  {'date': datetime.date(2003, 12, 9),
#   'elevation': 1347.0,
#   'features': DenseVector([33.667, 1.0, 1347.0]),
#   'latitude': 33.66699981689453,
#   'longitude': 1.0,
#   'station': 'AGM00060550',
#   'tmax': 8.399999618530273,
#   'tmax_pred': 23.386917012644574},
#  {'date': datetime.date(2012, 12, 24),
#   'elevation': 1347.0,
#   'features': DenseVector([33.667, 1.0, 1347.0]),
#   'latitude': 33.66699981689453,
#   'longitude': 1.0,
#   'station': 'AGM00060550',
#   'tmax': 19.399999618530273,
#   'tmax_pred': 23.386917012644574},
#  {'date': datetime.date(2001, 11, 23),
#   'elevation': 85.0,
#   'features': DenseVector([33.068, 6.089, 85.0]),
#   'latitude': 33.06800079345703,
#   'longitude': 6.089000225067139,
#   'station': 'AGM00060555',
#   'tmax': 22.100000381469727,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2002, 11, 12),
#   'elevation': 85.0,
#   'features': DenseVector([33.068, 6.089, 85.0]),
#   'latitude': 33.06800079345703,
#   'longitude': 6.089000225067139,
#   'station': 'AGM00060555',
#   'tmax': 28.299999237060547,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2003, 12, 8),
#   'elevation': 85.0,
#   'features': DenseVector([33.068, 6.089, 85.0]),
#   'latitude': 33.06800079345703,
#   'longitude': 6.089000225067139,
#   'station': 'AGM00060555',
#   'tmax': 22.299999237060547,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2003, 12, 18),
#   'elevation': 85.0,
#   'features': DenseVector([33.068, 6.089, 85.0]),
#   'latitude': 33.06800079345703,
#   'longitude': 6.089000225067139,
#   'station': 'AGM00060555',
#   'tmax': 15.199999809265137,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2000, 4, 15),
#   'elevation': 61.900001525878906,
#   'features': DenseVector([33.511, 6.777, 61.9]),
#   'latitude': 33.51100158691406,
#   'longitude': 6.7769999504089355,
#   'station': 'AGM00060559',
#   'tmax': 29.600000381469727,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2000, 9, 23),
#   'elevation': 61.900001525878906,
#   'features': DenseVector([33.511, 6.777, 61.9]),
#   'latitude': 33.51100158691406,
#   'longitude': 6.7769999504089355,
#   'station': 'AGM00060559',
#   'tmax': 35.29999923706055,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2002, 6, 5),
#   'elevation': 61.900001525878906,
#   'features': DenseVector([33.511, 6.777, 61.9]),
#   'latitude': 33.51100158691406,
#   'longitude': 6.7769999504089355,
#   'station': 'AGM00060559',
#   'tmax': 43.29999923706055,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2003, 6, 23),
#   'elevation': 61.900001525878906,
#   'features': DenseVector([33.511, 6.777, 61.9]),
#   'latitude': 33.51100158691406,
#   'longitude': 6.7769999504089355,
#   'station': 'AGM00060559',
#   'tmax': 37.79999923706055,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2003, 12, 18),
#   'elevation': 61.900001525878906,
#   'features': DenseVector([33.511, 6.777, 61.9]),
#   'latitude': 33.51100158691406,
#   'longitude': 6.7769999504089355,
#   'station': 'AGM00060559',
#   'tmax': 14.100000381469727,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2005, 9, 2),
#   'elevation': 61.900001525878906,
#   'features': DenseVector([33.511, 6.777, 61.9]),
#   'latitude': 33.51100158691406,
#   'longitude': 6.7769999504089355,
#   'station': 'AGM00060559',
#   'tmax': 36.20000076293945,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2007, 11, 20),
#   'elevation': 61.900001525878906,
#   'features': DenseVector([33.511, 6.777, 61.9]),
#   'latitude': 33.51100158691406,
#   'longitude': 6.7769999504089355,
#   'station': 'AGM00060559',
#   'tmax': 22.200000762939453,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2012, 2, 26),
#   'elevation': 61.900001525878906,
#   'features': DenseVector([33.511, 6.777, 61.9]),
#   'latitude': 33.51100158691406,
#   'longitude': 6.7769999504089355,
#   'station': 'AGM00060559',
#   'tmax': 21.5,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2012, 12, 31),
#   'elevation': 61.900001525878906,
#   'features': DenseVector([33.511, 6.777, 61.9]),
#   'latitude': 33.51100158691406,
#   'longitude': 6.7769999504089355,
#   'station': 'AGM00060559',
#   'tmax': 18.100000381469727,
#   'tmax_pred': 24.684573913391468},
#  {'date': datetime.date(2003, 5, 8),
#   'elevation': 1059.0,
#   'features': DenseVector([32.767, -0.6, 1059.0]),
#   'latitude': 32.766998291015625,
#   'longitude': -0.6000000238418579,
#   'station': 'AGM00060560',
#   'tmax': 24.700000762939453,
#   'tmax_pred': 25.39114366717018},
#  {'date': datetime.date(2011, 11, 22),
#   'elevation': 1059.0,
#   'features': DenseVector([32.767, -0.6, 1059.0]),
#   'latitude': 32.766998291015625,
#   'longitude': -0.6000000238418579,
#   'station': 'AGM00060560',
#   'tmax': 15.399999618530273,
#   'tmax_pred': 25.39114366717018},
#  {'date': datetime.date(2003, 6, 22),
#   'elevation': 764.0,
#   'features': DenseVector([32.933, 3.283, 764.0]),
#   'latitude': 32.93299865722656,
#   'longitude': 3.2829999923706055,
#   'station': 'AGM00060563',
#   'tmax': 34.20000076293945,
#   'tmax_pred': 24.994203357979707},
#  {'date': datetime.date(2003, 12, 20),
#   'elevation': 764.0,
#   'features': DenseVector([32.933, 3.283, 764.0]),
#   'latitude': 32.93299865722656,
#   'longitude': 3.2829999923706055,
#   'station': 'AGM00060563',
#   'tmax': 15.0,
#   'tmax_pred': 24.994203357979707},
#  {'date': datetime.date(2007, 12, 14),
#   'elevation': 764.0,
#   'features': DenseVector([32.933, 3.283, 764.0]),
#   'latitude': 32.93299865722656,
#   'longitude': 3.2829999923706055,
#   'station': 'AGM00060563',
#   'tmax': 11.600000381469727,
#   'tmax_pred': 24.994203357979707},
#  {'date': datetime.date(2000, 3, 26),
#   'elevation': 460.8999938964844,
#   'features': DenseVector([32.384, 3.794, 460.9]),
#   'latitude': 32.38399887084961,
#   'longitude': 3.7939999103546143,
#   'station': 'AGM00060566',
#   'tmax': 24.0,
#   'tmax_pred': 26.23247764446386},
#  {'date': datetime.date(2003, 3, 10),
#   'elevation': 460.8999938964844,
#   'features': DenseVector([32.384, 3.794, 460.9]),
#   'latitude': 32.38399887084961,
#   'longitude': 3.7939999103546143,
#   'station': 'AGM00060566',
#   'tmax': 22.0,
#   'tmax_pred': 26.23247764446386},
#  {'date': datetime.date(2003, 5, 25),
#   'elevation': 460.8999938964844,
#   'features': DenseVector([32.384, 3.794, 460.9]),
#   'latitude': 32.38399887084961,
#   'longitude': 3.7939999103546143,
#   'station': 'AGM00060566',
#   'tmax': 33.099998474121094,
#   'tmax_pred': 26.23247764446386},
#  {'date': datetime.date(2012, 11, 18),
#   'elevation': 460.8999938964844,
#   'features': DenseVector([32.384, 3.794, 460.9]),
#   'latitude': 32.38399887084961,
# ...
#   'features': DenseVector([-30.7847, 121.4533, 365.3]),
#   'latitude': -30.784700393676758,
#   'longitude': 121.45330047607422,
#   'station': 'ASN00012038',
#   'tmax': 20.899999618530273,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2005, 11, 3),
#   'elevation': 365.29998779296875,
#   'features': DenseVector([-30.7847, 121.4533, 365.3]),
#   'latitude': -30.784700393676758,
#   'longitude': 121.45330047607422,
#   'station': 'ASN00012038',
#   'tmax': 30.200000762939453,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2011, 11, 22),
#   'elevation': 365.29998779296875,
#   'features': DenseVector([-30.7847, 121.4533, 365.3]),
#   'latitude': -30.784700393676758,
#   'longitude': 121.45330047607422,
#   'station': 'ASN00012038',
#   'tmax': 28.100000381469727,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2003, 6, 14),
#   'elevation': 220.0,
#   'features': DenseVector([-33.5547, 120.6997, 220.0]),
#   'latitude': -33.5546989440918,
#   'longitude': 120.69969940185547,
#   'station': 'ASN00012044',
#   'tmax': 13.300000190734863,
#   'tmax_pred': 22.190392883206002},
#  {'date': datetime.date(2005, 9, 14),
#   'elevation': 220.0,
#   'features': DenseVector([-33.5547, 120.6997, 220.0]),
#   'latitude': -33.5546989440918,
#   'longitude': 120.69969940185547,
#   'station': 'ASN00012044',
#   'tmax': 16.399999618530273,
#   'tmax_pred': 22.190392883206002},
#  {'date': datetime.date(2011, 11, 19),
#   'elevation': 220.0,
#   'features': DenseVector([-33.5547, 120.6997, 220.0]),
#   'latitude': -33.5546989440918,
#   'longitude': 120.69969940185547,
#   'station': 'ASN00012044',
#   'tmax': 20.5,
#   'tmax_pred': 22.190392883206002},
#  {'date': datetime.date(2001, 4, 7),
#   'elevation': 376.0,
#   'features': DenseVector([-28.8836, 121.3303, 376.0]),
#   'latitude': -28.88360023498535,
#   'longitude': 121.3302993774414,
#   'station': 'ASN00012046',
#   'tmax': 23.5,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2002, 6, 9),
#   'elevation': 376.0,
#   'features': DenseVector([-28.8836, 121.3303, 376.0]),
#   'latitude': -28.88360023498535,
#   'longitude': 121.3302993774414,
#   'station': 'ASN00012046',
#   'tmax': 20.0,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2003, 2, 25),
#   'elevation': 376.0,
#   'features': DenseVector([-28.8836, 121.3303, 376.0]),
#   'latitude': -28.88360023498535,
#   'longitude': 121.3302993774414,
#   'station': 'ASN00012046',
#   'tmax': 34.20000076293945,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2005, 9, 5),
#   'elevation': 376.0,
#   'features': DenseVector([-28.8836, 121.3303, 376.0]),
#   'latitude': -28.88360023498535,
#   'longitude': 121.3302993774414,
#   'station': 'ASN00012046',
#   'tmax': 30.700000762939453,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2005, 9, 30),
#   'elevation': 376.0,
#   'features': DenseVector([-28.8836, 121.3303, 376.0]),
#   'latitude': -28.88360023498535,
#   'longitude': 121.3302993774414,
#   'station': 'ASN00012046',
#   'tmax': 26.100000381469727,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2005, 12, 2),
#   'elevation': 376.0,
#   'features': DenseVector([-28.8836, 121.3303, 376.0]),
#   'latitude': -28.88360023498535,
#   'longitude': 121.3302993774414,
#   'station': 'ASN00012046',
#   'tmax': 38.29999923706055,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2000, 8, 19),
#   'elevation': 277.0,
#   'features': DenseVector([-32.1981, 121.7794, 277.0]),
#   'latitude': -32.19810104370117,
#   'longitude': 121.77940368652344,
#   'station': 'ASN00012065',
#   'tmax': 20.5,
#   'tmax_pred': 28.278591955159207},
#  {'date': datetime.date(2001, 2, 24),
#   'elevation': 277.0,
#   'features': DenseVector([-32.1981, 121.7794, 277.0]),
#   'latitude': -32.19810104370117,
#   'longitude': 121.77940368652344,
#   'station': 'ASN00012065',
#   'tmax': 24.200000762939453,
#   'tmax_pred': 28.278591955159207},
#  {'date': datetime.date(2001, 3, 17),
#   'elevation': 277.0,
#   'features': DenseVector([-32.1981, 121.7794, 277.0]),
#   'latitude': -32.19810104370117,
#   'longitude': 121.77940368652344,
#   'station': 'ASN00012065',
#   'tmax': 27.700000762939453,
#   'tmax_pred': 28.278591955159207},
#  {'date': datetime.date(2002, 11, 6),
#   'elevation': 277.0,
#   'features': DenseVector([-32.1981, 121.7794, 277.0]),
#   'latitude': -32.19810104370117,
#   'longitude': 121.77940368652344,
#   'station': 'ASN00012065',
#   'tmax': 33.900001525878906,
#   'tmax_pred': 28.278591955159207},
#  {'date': datetime.date(2001, 4, 12),
#   'elevation': 249.0,
#   'features': DenseVector([-32.9869, 121.6239, 249.0]),
#   'latitude': -32.986900329589844,
#   'longitude': 121.6239013671875,
#   'station': 'ASN00012071',
#   'tmax': 28.0,
#   'tmax_pred': 22.162511558930067},
#  {'date': datetime.date(2002, 4, 12),
#   'elevation': 249.0,
#   'features': DenseVector([-32.9869, 121.6239, 249.0]),
#   'latitude': -32.986900329589844,
#   'longitude': 121.6239013671875,
#   'station': 'ASN00012071',
#   'tmax': 24.0,
#   'tmax_pred': 22.162511558930067},
#  {'date': datetime.date(2003, 4, 8),
#   'elevation': 249.0,
#   'features': DenseVector([-32.9869, 121.6239, 249.0]),
#   'latitude': -32.986900329589844,
#   'longitude': 121.6239013671875,
#   'station': 'ASN00012071',
#   'tmax': 19.0,
#   'tmax_pred': 22.162511558930067},
#  {'date': datetime.date(2007, 12, 3),
#   'elevation': 249.0,
#   'features': DenseVector([-32.9869, 121.6239, 249.0]),
#   'latitude': -32.986900329589844,
#   'longitude': 121.6239013671875,
#   'station': 'ASN00012071',
#   'tmax': 23.600000381469727,
#   'tmax_pred': 22.162511558930067},
#  {'date': datetime.date(2011, 12, 18),
#   'elevation': 249.0,
#   'features': DenseVector([-32.9869, 121.6239, 249.0]),
#   'latitude': -32.986900329589844,
#   'longitude': 121.6239013671875,
#   'station': 'ASN00012071',
#   'tmax': 36.20000076293945,
#   'tmax_pred': 22.162511558930067},
#  {'date': datetime.date(2002, 12, 11),
#   'elevation': 355.0,
#   'features': DenseVector([-31.2319, 119.3281, 355.0]),
#   'latitude': -31.23189926147461,
#   'longitude': 119.3281021118164,
#   'station': 'ASN00012074',
#   'tmax': 36.20000076293945,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2003, 7, 16),
#   'elevation': 487.0,
#   'features': DenseVector([-27.2842, 120.0931, 487.0]),
#   'latitude': -27.28420066833496,
#   'longitude': 120.09310150146484,
#   'station': 'ASN00012090',
#   'tmax': 15.0,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2005, 8, 14),
#   'elevation': 487.0,
#   'features': DenseVector([-27.2842, 120.0931, 487.0]),
#   'latitude': -27.28420066833496,
#   'longitude': 120.09310150146484,
#   'station': 'ASN00012090',
#   'tmax': 16.600000381469727,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2003, 3, 29),
#   'elevation': 438.5,
#   'features': DenseVector([-28.4967, 119.7436, 438.5]),
#   'latitude': -28.496700286865234,
#   'longitude': 119.74359893798828,
#   'station': 'ASN00012239',
#   'tmax': 22.200000762939453,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2004, 11, 22),
#   'elevation': 438.5,
#   'features': DenseVector([-28.4967, 119.7436, 438.5]),
#   'latitude': -28.496700286865234,
#   'longitude': 119.74359893798828,
#   'station': 'ASN00012239',
#   'tmax': 34.5,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2004, 12, 29),
#   'elevation': 438.5,
#   'features': DenseVector([-28.4967, 119.7436, 438.5]),
#   'latitude': -28.496700286865234,
#   'longitude': 119.74359893798828,
#   'station': 'ASN00012239',
#   'tmax': 39.0,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2012, 12, 8),
#   'elevation': 438.5,
#   'features': DenseVector([-28.4967, 119.7436, 438.5]),
#   'latitude': -28.496700286865234,
#   'longitude': 119.74359893798828,
#   'station': 'ASN00012239',
#   'tmax': 33.599998474121094,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2015, 12, 3),
#   'elevation': 438.5,
#   'features': DenseVector([-28.4967, 119.7436, 438.5]),
#   'latitude': -28.496700286865234,
#   'longitude': 119.74359893798828,
#   'station': 'ASN00012239',
#   'tmax': 38.0,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2013, 12, 26),
#   'elevation': 370.0,
#   'features': DenseVector([-28.8789, 121.3186, 370.0]),
#   'latitude': -28.8789005279541,
#   'longitude': 121.318603515625,
#   'station': 'ASN00012241',
#   'tmax': 44.900001525878906,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2000, 3, 15),
#   'elevation': 464.29998779296875,
#   'features': DenseVector([-28.6133, 122.4236, 464.3]),
#   'latitude': -28.613300323486328,
#   'longitude': 122.42359924316406,
#   'station': 'ASN00012305',
#   'tmax': 29.399999618530273,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2000, 4, 2),
#   'elevation': 464.29998779296875,
#   'features': DenseVector([-28.6133, 122.4236, 464.3]),
#   'latitude': -28.613300323486328,
#   'longitude': 122.42359924316406,
#   'station': 'ASN00012305',
#   'tmax': 29.0,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2003, 10, 28),
#   'elevation': 464.29998779296875,
#   'features': DenseVector([-28.6133, 122.4236, 464.3]),
#   'latitude': -28.613300323486328,
#   'longitude': 122.42359924316406,
#   'station': 'ASN00012305',
#   'tmax': 24.899999618530273,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2006, 5, 17),
#   'elevation': 464.29998779296875,
#   'features': DenseVector([-28.6133, 122.4236, 464.3]),
#   'latitude': -28.613300323486328,
#   'longitude': 122.42359924316406,
#   'station': 'ASN00012305',
#   'tmax': 27.200000762939453,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2007, 12, 18),
#   'elevation': 464.29998779296875,
#   'features': DenseVector([-28.6133, 122.4236, 464.3]),
#   'latitude': -28.613300323486328,
#   'longitude': 122.42359924316406,
#   'station': 'ASN00012305',
#   'tmax': 30.0,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2001, 2, 6),
#   'elevation': 497.0,
#   'features': DenseVector([-27.8386, 120.7031, 497.0]),
#   'latitude': -27.838600158691406,
#   'longitude': 120.7031021118164,
#   'station': 'ASN00012314',
#   'tmax': 39.900001525878906,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2001, 11, 22),
#   'elevation': 497.0,
#   'features': DenseVector([-27.8386, 120.7031, 497.0]),
#   'latitude': -27.838600158691406,
#   'longitude': 120.7031021118164,
#   'station': 'ASN00012314',
#   'tmax': 28.600000381469727,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2002, 6, 17),
#   'elevation': 497.0,
#   'features': DenseVector([-27.8386, 120.7031, 497.0]),
#   'latitude': -27.838600158691406,
#   'longitude': 120.7031021118164,
#   'station': 'ASN00012314',
#   'tmax': 19.700000762939453,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2005, 8, 21),
#   'elevation': 497.0,
#   'features': DenseVector([-27.8386, 120.7031, 497.0]),
#   'latitude': -27.838600158691406,
#   'longitude': 120.7031021118164,
#   'station': 'ASN00012314',
#   'tmax': 19.899999618530273,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2011, 6, 8),
#   'elevation': 497.0,
#   'features': DenseVector([-27.8386, 120.7031, 497.0]),
#   'latitude': -27.838600158691406,
#   'longitude': 120.7031021118164,
#   'station': 'ASN00012314',
#   'tmax': 15.600000381469727,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2000, 7, 31),
#   'elevation': 347.3999938964844,
#   'features': DenseVector([-31.2353, 119.3564, 347.4]),
#   'latitude': -31.235300064086914,
#   'longitude': 119.35639953613281,
#   'station': 'ASN00012320',
#   'tmax': 19.399999618530273,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2000, 9, 12),
#   'elevation': 347.3999938964844,
#   'features': DenseVector([-31.2353, 119.3564, 347.4]),
#   'latitude': -31.235300064086914,
#   'longitude': 119.35639953613281,
#   'station': 'ASN00012320',
#   'tmax': 29.399999618530273,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2002, 12, 13),
#   'elevation': 347.3999938964844,
#   'features': DenseVector([-31.2353, 119.3564, 347.4]),
#   'latitude': -31.235300064086914,
#   'longitude': 119.35639953613281,
#   'station': 'ASN00012320',
#   'tmax': 35.0,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2004, 11, 20),
#   'elevation': 347.3999938964844,
#   'features': DenseVector([-31.2353, 119.3564, 347.4]),
#   'latitude': -31.235300064086914,
#   'longitude': 119.35639953613281,
#   'station': 'ASN00012320',
#   'tmax': 29.899999618530273,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2005, 11, 8),
#   'elevation': 347.3999938964844,
#   'features': DenseVector([-31.2353, 119.3564, 347.4]),
#   'latitude': -31.235300064086914,
#   'longitude': 119.35639953613281,
#   'station': 'ASN00012320',
#   'tmax': 22.799999237060547,
#   'tmax_pred': 28.618721128917834},
#  {'date': datetime.date(2003, 2, 17),
#   'elevation': 420.0,
#   'features': DenseVector([-20.1417, 127.9867, 420.0]),
#   'latitude': -20.141700744628906,
#   'longitude': 127.98670196533203,
#   'station': 'ASN00013007',
#   'tmax': 37.29999923706055,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2003, 4, 20),
#   'elevation': 420.0,
#   'features': DenseVector([-20.1417, 127.9867, 420.0]),
#   'latitude': -20.141700744628906,
#   'longitude': 127.98670196533203,
#   'station': 'ASN00013007',
#   'tmax': 34.20000076293945,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2005, 9, 24),
#   'elevation': 420.0,
#   'features': DenseVector([-20.1417, 127.9867, 420.0]),
#   'latitude': -20.141700744628906,
#   'longitude': 127.98670196533203,
#   'station': 'ASN00013007',
#   'tmax': 37.79999923706055,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2007, 12, 18),
#   'elevation': 420.0,
#   'features': DenseVector([-20.1417, 127.9867, 420.0]),
#   'latitude': -20.141700744628906,
#   'longitude': 127.98670196533203,
#   'station': 'ASN00013007',
#   'tmax': 39.099998474121094,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2011, 6, 28),
#   'elevation': 420.0,
#   'features': DenseVector([-20.1417, 127.9867, 420.0]),
#   'latitude': -20.141700744628906,
#   'longitude': 127.98670196533203,
#   'station': 'ASN00013007',
#   'tmax': 26.0,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2012, 11, 26),
#   'elevation': 420.0,
#   'features': DenseVector([-20.1417, 127.9867, 420.0]),
#   'latitude': -20.141700744628906,
#   'longitude': 127.98670196533203,
#   'station': 'ASN00013007',
#   'tmax': 34.5,
#   'tmax_pred': 30.61468169397209},
#  {'date': datetime.date(2000, 3, 28),
#   'elevation': 459.0,
#   'features': DenseVector([-26.1317, 126.5839, 459.0]),
#   'latitude': -26.13170051574707,
#   'longitude': 126.58390045166016,
#   'station': 'ASN00013011',
#   'tmax': 29.0,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2002, 12, 30),
#   'elevation': 459.0,
#   'features': DenseVector([-26.1317, 126.5839, 459.0]),
#   'latitude': -26.13170051574707,
#   'longitude': 126.58390045166016,
#   'station': 'ASN00013011',
#   'tmax': 32.0,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2001, 2, 16),
#   'elevation': 521.0,
#   'features': DenseVector([-26.5914, 120.225, 521.0]),
#   'latitude': -26.591400146484375,
#   'longitude': 120.2249984741211,
#   'station': 'ASN00013012',
#   'tmax': 22.0,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2001, 12, 4),
#   'elevation': 521.0,
#   'features': DenseVector([-26.5914, 120.225, 521.0]),
#   'latitude': -26.591400146484375,
#   'longitude': 120.2249984741211,
#   'station': 'ASN00013012',
#   'tmax': 34.5,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2003, 4, 8),
#   'elevation': 521.0,
#   'features': DenseVector([-26.5914, 120.225, 521.0]),
#   'latitude': -26.591400146484375,
#   'longitude': 120.2249984741211,
#   'station': 'ASN00013012',
#   'tmax': 20.399999618530273,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2003, 10, 22),
#   'elevation': 521.0,
#   'features': DenseVector([-26.5914, 120.225, 521.0]),
#   'latitude': -26.591400146484375,
#   'longitude': 120.2249984741211,
#   'station': 'ASN00013012',
#   'tmax': 38.5,
#   'tmax_pred': 30.325324621295696},
#  {'date': datetime.date(2007, 12, 21),
#   'elevation': 521.0,
#   'features': DenseVector([-26.5914, 120.225, 521.0]),
#   'latitude': -26.591400146484375,
#   'longitude': 120.2249984741211,
#   'station': 'ASN00013012',
#   'tmax': 33.0,
#   'tmax_pred': 30.325324621295696},
#  ...]

# %%
plt.figure(figsize=(16,12))

eq_map = Basemap(projection='cyl', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=0)
# eq_map.drawcoastlines()
# eq_map.drawcountries()
eq_map.fillcontinents(color = '#202020', lake_color='#3b3b3b', zorder=0.5)
eq_map.drawmapboundary(fill_color='#3b3b3b')
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))

lon = []
lat = []
val = []

for y in collected_predictions:
    lon.append(y['longitude'])
    lat.append(y['latitude'])
    val.append(abs(y['tmax_pred'] - y['tmax']))

x, y = eq_map(lon, lat)

cs = eq_map.scatter(x, y, c=val, marker="o", cmap=cm.Reds)
cbar = eq_map.colorbar(cs,location='bottom',pad="5%")
cbar.set_label('Absolute Temperature Difference (in Celcius)')
plt.title('Regression Error Map')
plt.show()
# Out:
# /Users/mvachher/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1708: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /Users/mvachher/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:

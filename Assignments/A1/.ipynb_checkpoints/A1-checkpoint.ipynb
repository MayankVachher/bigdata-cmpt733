# %% [markdown]
# # Assignment 1: Web Scraping

# %% [markdown]
# ## Objective

# %% [markdown]
# Data scientists often need to crawl data from websites and turn the crawled data (HTML pages) to structured data (tables). Thus, web scraping is an essential skill that every data scientist should master. In this assignment, you will learn the followings:
#
#
# * How to use [requests](http://www.python-requests.org/en/master/) to download HTML pages from a website?
# * How to select content on a webpage with [lxml](http://lxml.de/)?
#
# You can either use Spark DataFrame or [pandas.DataFrame](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html) to do the assignment. In comparison, pandas.DataFrame has richer APIs, but is not good at distributed computing.

# %% [markdown]
# ## Preliminary

# %% [markdown]
# If this is your first time to write a web scraper, you need to learn some basic knowledge of HTML, DOM, and XPath. I found that this is a good resource: [https://data-lessons.github.io/library-webscraping/](https://data-lessons.github.io/library-webscraping/). Please take a look at
#
# * [Selecting content on a web page with XPath
# ](https://data-lessons.github.io/library-webscraping/xpath/)
# * [Web scraping using Python: requests and lxml](https://data-lessons.github.io/library-webscraping/04-lxml/).
#
# Please let me know if you find a better resource. I'll share it with the other students.

# %% [markdown]
# ## Overview

# %% [markdown]
# Imagine you are a data scientist working at SFU. One day, you want to analyze CS faculty data and answer two interesting questions:
#
# 1. Who are the CS faculty members?
# 2. What are their research interests?
#
# To do so, the first thing is to figure out what data to collect.

# %% [markdown]
# ## Task 1: SFU CS Faculty Members

# %% [markdown]
# You find that there is a web page in the CS school website, which lists all the faculty members as well as their basic information.
#
# In Task 1, your job is to write a web scraper to extract the faculty information from this page: [https://www.sfu.ca/computing/people/faculty.html](https://www.sfu.ca/computing/people/faculty.html).

# %% [markdown]
# ### (a) Crawling Web Page

# %% [markdown]
# A web page is essentially a file stored in a remote machine (called web server). You can use [requests](http://www.python-requests.org/en/master/) to open such a file and read data from it. Please complete the following code to download the HTML page and save it as a text file (like [this](./faculty.txt)).

# %%
import requests


# 1. Download the webpage
# 2. Save it as a text file (named faculty.txt)

webpage_adrs = "https://www.sfu.ca/computing/people/faculty.html"
fac_page = 'faculty_page.txt'

# %%
def grab_and_save(webpage_adrs, file_tosave):
    response_obj = requests.get(webpage_adrs)
    html_text = response_obj.text
    with open(file_tosave, 'w', encoding='utf-8') as f:
        f.write(html_text)

grab_and_save(webpage_adrs, fac_page)

# %% [markdown]
# ### (b) Extracting Structured Data

# %% [markdown]
# An HTML page follows the Document Object Model (DOM). It models an HTML page as a tree structure wherein each node is an object representing a part of the page. The nodes can be searched and extracted programmatically using XPath. Please complete the following code to transform the above HTML page to a CSV file (like [this](./faculty_table.csv)).

# %%
import lxml.html
import pandas as pd

# 1. Open faculty.txt
with open(fac_page, 'r', encoding='utf-8') as f:
    fac_content = f.read()

# 2. Parse the HTML page as a tree structure
tree = lxml.html.document_fromstring(fac_content)
fac_texts = tree.xpath("//div[contains(@class, 'faculty-list')]//div[@class='text']")

# 3. Extract related content from the tree using XPath
def cleanup_faculty_profile(elem_obj):
    # Example:
    # name     - Greg Baker
    # rank     - SENIOR LECTURER
    # area     - Instruction
    # profile  - http://www.sfu.ca/computing/people/faculty/gregbaker.html
    # homepage - http://www.cs.sfu.ca/~ggbaker/
    
    acad = dict()
    h4_objs = elem_obj.xpath("h4")
    name, rank = h4_objs[0].text_content().split(',')[:2]
    acad['name'] = name.strip()
    acad['rank'] = rank.split()[0].strip()
    
    area_obj = elem_obj.xpath(".//*[contains(text(), 'Area')]/..")
    acad['area'] = area_obj[0].text_content().split(':')[1].strip()
    
    profile_obj = elem_obj.xpath(".//*[contains(text(), 'Profile')]/..")
    sublinks = profile_obj[0].xpath("a")
    acad['profile'] = requests.compat.urljoin('http://www.sfu.ca/',sublinks[0].attrib['href'])
    if len(sublinks) == 1:
        acad['homepage'] = ""
    else:
        acad['homepage'] = sublinks[1].attrib['href']
    return pd.DataFrame([acad])

df = cleanup_faculty_profile(fac_texts[0])
for fac_obj in fac_texts[1:]:
    df = pd.concat([df,cleanup_faculty_profile(fac_obj)], ignore_index=True)

print(df)

fac_table_filename = "faculty_table_mv.csv"

# 4. Save the extracted content as an csv file (named faculty_table.csv)
df.to_csv(fac_table_filename, index=False, columns=["name","rank","area","profile","homepage"])
# Out:
#                                                  area  \
# 0                                         Instruction
# 1   Probabilistic methods; Randomized algorithms; ...
# 2   Constraint Satisfaction, Complexity of Computa...
# 3                                         Instruction
# 4                               Computational Biology
# 5                                         Instruction
# 6          Formal Aspects of Knowledge Representation
# 7                                         Instruction
# 8                                         Instruction
# 9                           Databases and Data Mining
# 10                                        Instruction
# 11  Computer Vision, Deep Learning, Computer Graph...
# 12  Software Technology, Distributed Communication...
# 13       Computer Networks, Multimedia Communications
# 14                                        Instruction
# 15                                        Instruction
# 16         Computational Biology and Machine Learning
# 17           Networking and multimedia communications
# 18  Constraint satisfaction, Algorithms for deduct...
# 19                          Databases and Data Mining
# 20    Computational Linguistics and Logic Programming
# 21  Systems architecture, hardware-software intera...
# 22  Automated debugging, debugging tools, concurre...
# 23       Computer Vision, Computer Graphics, Robotics
# 24  Logical aspects of AI, Knowledge Representatio...
# 25  Parallel & Distributed Computing, Irregular Bi...
# 26                             Databases, Data Mining
# 27  Bioinformatics, Evolutionary Computation, Comp...
# 28  Computer Animation, Computer Graphics, Humanoi...
# 29                                        Instruction
# 30        Computational Geometry, Pattern Recognition
# 31  Software Engineering Languages; Electronic Pub...
# 32                    Robotics and Autonomous Systems
# 33                         Human-Computer Interaction
# 34                                       Neuroscience
# 35                                    Computer Vision
# 36                         Computational Color Vision
# 37              Network Communications and Algorithms
# 38  Medical Image Analysis (Computational/Artifici...
# 39                                  Computer Graphics
# 40                        Computational Combinatorics
# 41  Pseudorandomness and Derandomization, Complexi...
# 42  Combinatorial Optimization and Approximation A...
# 43                        Computer Vision, Multimedia
# 44                            Human Robot Interaction
# 45                  Computer Vision, Machine Learning
# 46     Instruction, Computational Applied Mathematics
# 47                             Network Communications
# 48                                        Instruction
# 49  Computational Linguistics; Machine Learning; P...
# 50       Computational Geometry and Computer Graphics
# 51  Machine Learning, Computational Logic, Computa...
# 52                    Robotics and Autonomous Systems
# 53                      Database Systems and Big Data
# 54  Mandarin Chinese Instruction for the Dual Degr...
# 55             Computer Graphics; Geometric Modelling
#
#                            homepage                     name  \
# 0    http://www.cs.sfu.ca/~ggbaker/               Greg Baker
# 1      http://www.cs.sfu.ca/~petra/         Petra Berenbrink
# 2   http://www.cs.sfu.ca/~abulatov/           Andrei Bulatov
# 3                                                 BOBBY CHAN
# 4         http://www.sfu.ca/~leonid     LEONID CHINDELEVITCH
# 5                                            Diana Cukierman
# 6        http://www.cs.sfu.ca/~jim/       James P. Delgrande
# 7                                             Toby Donaldson
# 8                                                 John Edgar
# 9      http://www.cs.sfu.ca/~ester/             Martin Ester
# 10   http://www.cs.sfu.ca/~bfraser/             Brian Fraser
# 11  http://www.cs.sfu.ca/~furukawa/        Yasutaka Furukawa
# 12  http://www.cs.sfu.ca/~glaesser/              Uwe Glässer
# 13  http://www.cs.sfu.ca/~mhefeeda/          Mohamed Hefeeda
# 14  http://www.cs.sfu.ca/~hskhangu/  Harinder Singh Khangura
# 15  http://www.cs.sfu.ca/~alavergn/            Anne Lavergne
# 16     http://www.cs.sfu.ca/~maxwl/        Maxwell Libbrecht
# 17     http://www.cs.sfu.ca/~jcliu/      Jiangchuan (JC) Liu
# 18  http://www.cs.sfu.ca/~mitchell/           David Mitchell
# 19      http://www.cs.sfu.ca/~jpei/                 Jian Pei
# 20  http://www.cs.sfu.ca/~popowich/            Fred Popowich
# 21  http://www.cs.sfu.ca/~ashriram/       Arrvindh Shriraman
# 22   http://www.cs.sfu.ca/~wsumner/    William (Nick) Sumner
# 23   http://www.cs.sfu.ca/~pingtan/                 Ping Tan
# 24       http://www.cs.sfu.ca/~ter/        Eugenia Ternovska
# 25     http://www.cs.sfu.ca/~keval/               Keval Vora
# 26     http://www.cs.sfu.ca/~wangk/                  Ke Wang
# 27     http://www.cs.sfu.ca/~wiese/             Kay C. Wiese
# 28     http://www.cs.sfu.ca/~kkyin/             KangKang Yin
# 29     http://www.cs.sfu.ca/~bbart/                Brad Bart
# 30     http://www.cs.sfu.ca/~binay/       Binay Bhattacharya
# 31   http://www.cs.sfu.ca/~cameron/        Robert D. Cameron
# 32                                                   Mo Chen
# 33            http://hci.cs.sfu.ca/           Parmit Chilana
# 34                                          Ryan C.N. D'Arcy
# 35      http://www.cs.sfu.ca/~mark/             Mark S. Drew
# 36      http://www.cs.sfu.ca/~funt/               Brian Funt
# 37       http://www.cs.sfu.ca/~qgu/              Qianping Gu
# 38  http://www.cs.sfu.ca/~hamarneh/         Ghassan Hamarneh
# 39                                              Eugene Fiume
# 40     http://www.cs.sfu.ca/~pavol/               Pavol Hell
# 41  http://www.cs.sfu.ca/~kabanets/       Valentine Kabanets
# 42    http://www.cs.sfu.ca/~ramesh/      Ramesh Krishnamurti
# 43        http://www.cs.sfu.ca/~li/               Ze-Nian Li
# 44         https://www.rosielab.ca/             Angelica Lim
# 45      http://www.cs.sfu.ca/~mori/                Greg Mori
# 46   http://www.cs.sfu.ca/~stevenp/            Steven Pearce
# 47    http://www.cs.sfu.ca/~peters/         Joseph G. Peters
# 48    http://www.cs.sfu.ca/~jregan/             Janice Regan
# 49     http://www.cs.sfu.ca/~anoop/             Anoop Sarkar
# 50   http://www.cs.sfu.ca/~shermer/        Thomas C. Shermer
# 51  http://www.cs.sfu.ca/~oschulte/           Oliver Schulte
# 52   http://www.cs.sfu.ca/~vaughan/          Richard Vaughan
# 53   https://www.cs.sfu.ca/~jnwang/             Jiannan Wang
# 54                                               Cynthia Xie
# 55      http://www.cs.sfu.ca/~haoz/      Richard (Hao) Zhang
#
#                                               profile       rank
# 0   http://www.sfu.ca/computing/people/faculty/gre...     SENIOR
# 1   http://www.sfu.ca/computing/people/faculty/pet...  PROFESSOR
# 2   http://www.sfu.ca/computing/people/faculty/and...  Professor
# 3   http://www.sfu.ca/computing/people/faculty/bob...    LIMITED
# 4   http://www.sfu.ca/computing/people/faculty/leo...  ASSISTANT
# 5   http://www.sfu.ca/computing/people/faculty/dia...     Senior
# 6   http://www.sfu.ca/computing/people/faculty/jam...  Professor
# 7   http://www.sfu.ca/computing/people/faculty/tob...     Senior
# 8   http://www.sfu.ca/computing/people/faculty/joh...     Senior
# 9   http://www.sfu.ca/computing/people/faculty/mar...  Professor
# 10  http://www.sfu.ca/computing/people/faculty/bri...     Senior
# 11  http://www.sfu.ca/computing/people/faculty/yas...  Assistant
# 12  http://www.sfu.ca/computing/people/faculty/uwe...  Professor
# 13  http://www.sfu.ca/computing/people/faculty/moh...  Professor
# 14  http://www.sfu.ca/computing/people/faculty/har...     Senior
# 15  http://www.sfu.ca/computing/people/faculty/ann...     Senior
# 16  http://www.sfu.ca/computing/people/faculty/max...  Assistant
# 17  http://www.sfu.ca/computing/people/faculty/jia...  Professor
# 18  http://www.sfu.ca/computing/people/faculty/dav...  Associate
# 19  http://www.sfu.ca/computing/people/faculty/jia...  Professor
# 20  http://www.sfu.ca/computing/people/faculty/fre...  Professor
# 21  http://www.sfu.ca/computing/people/faculty/Arr...  Associate
# 22  http://www.sfu.ca/computing/people/faculty/Nic...  Assistant
# 23  http://www.sfu.ca/computing/people/faculty/pin...  Associate
# 24  http://www.sfu.ca/computing/people/faculty/Eug...  Associate
# 25  http://www.sfu.ca/computing/people/faculty/kev...  Assistant
# 26  http://www.sfu.ca/computing/people/faculty/kew...  Professor
# 27  http://www.sfu.ca/computing/people/faculty/kay...  Associate
# 28  http://www.sfu.ca/computing/people/faculty/kan...  Associate
# 29  http://www.sfu.ca/computing/people/faculty/bra...     SENIOR
# 30  http://www.sfu.ca/computing/people/faculty/bin...  Professor
# 31  http://www.sfu.ca/computing/people/faculty/rob...  Professor
# 32  http://www.sfu.ca/computing/people/faculty/moc...  Assistant
# 33  http://www.sfu.ca/computing/people/faculty/par...  Assistant
# 34  http://www.sfu.ca/computing/people/faculty/rya...  Professor
# 35  http://www.sfu.ca/computing/people/faculty/mar...  Professor
# 36  http://www.sfu.ca/computing/people/faculty/bri...  Professor
# 37  http://www.sfu.ca/computing/people/faculty/Qia...  Professor
# 38  http://www.sfu.ca/computing/people/faculty/gha...  Professor
# 39  http://www.sfu.ca/computing/people/faculty/eug...  Professor
# 40  http://www.sfu.ca/computing/people/faculty/pav...  Professor
# 41  http://www.sfu.ca/computing/people/faculty/val...  Associate
# 42  http://www.sfu.ca/computing/people/faculty/Ram...  Professor
# 43  http://www.sfu.ca/computing/people/faculty/ze-...  Professor
# 44  http://www.sfu.ca/computing/people/faculty/ang...  Assistant
# 45  http://www.sfu.ca/computing/people/faculty/gre...  Professor
# 46  http://www.sfu.ca/computing/people/faculty/ste...   Lecturer
# 47  http://www.sfu.ca/computing/people/faculty/Jos...  Professor
# 48  http://www.sfu.ca/computing/people/faculty/jan...     Senior
# 49  http://www.sfu.ca/computing/people/faculty/ano...  Professor
# 50  http://www.sfu.ca/computing/people/faculty/tho...  Professor
# 51  http://www.sfu.ca/computing/people/faculty/oli...  Professor
# 52  http://www.sfu.ca/computing/people/faculty/ric...  Associate
# 53  http://www.sfu.ca/computing/people/faculty/jia...  Assistant
# 54  http://www.sfu.ca/computing/people/faculty/cyn...     Senior
# 55  http://www.sfu.ca/computing/people/faculty/ric...  Professor

# %% [markdown]
# ## Task 2: Research Interests

# %% [markdown]
# Suppose you want to know the research interests of each faculty. However, the above crawled web page does not contain such information.

# %% [markdown]
# ### (a) Crawling Web Page

# %% [markdown]
# You notice that such information can be found on the profile page of each faculty. For example, you can find the research interests of Dr. Jiannan Wang from [http://www.sfu.ca/computing/people/faculty/jiannanwang.html](http://www.sfu.ca/computing/people/faculty/jiannanwang.html).
#
#
# Please complete the following code to download the profile pages and save them as text files. There are 56 faculties, so you need to download 56 web pages in total.

# %%
import requests
import os
import shutil
import string

fac_profiles_dir = "faculty_profiles"

if os.path.exists(fac_profiles_dir):
    shutil.rmtree(fac_profiles_dir)
    
os.makedirs(fac_profiles_dir)

df = pd.read_csv(fac_table_filename)

def fac_name_resolver(fac_url):
    fac_url_split = fac_url.split('.html')[0]
    name_resolved = fac_url_split.split('/')[-1]
    return name_resolved.lower()

# 1. Download the profile pages of 56 faculties
# 2. Save each page as a text file
for index, row in df.iterrows():
    fac_filename = fac_name_resolver(row['profile'])+".txt"
    grab_and_save(row['profile'], os.path.join(fac_profiles_dir, fac_filename))

# %% [markdown]
# ### (b) Extracting Structured Data

# %% [markdown]
# Please complete the following code to extract the research interests of each faculty, and generate a file like [this](./faculty_more_table.csv).

# %%
import lxml.html 
import unicodedata

# 1. Open each text file and parse it as a tree structure 
# 2. Extract the research interests from each tree using XPath
# 3. Add the extracted content to faculty_table.csv
# 4. Generate a new CSV file, named faculty_more_table.csv

def get_research_interests(fac_profile):
    with open(fac_profile, 'r', encoding='utf-8') as f:
        fac_content = f.read()
    tree = lxml.html.document_fromstring(fac_content)
    research_interests = tree.xpath("//h2[contains(text(), 'Research ')]/../ul/li")
    ri_list = []
    for interest in research_interests:
        preproc = interest.text_content().strip()
        preproc = unicodedata.normalize('NFKD', preproc)
        rm_extra_spaces = ' '.join(preproc.split())
        ri_list.append(rm_extra_spaces)
    ri = ', '.join(ri_list)
    return '[' + ri + ']'


df = pd.read_csv(fac_table_filename)
df["research_interests"] = ""

for index, row in df.iterrows():
    fac_filename = fac_name_resolver(row['profile'])+".txt"
    fac_profile = os.path.join(fac_profiles_dir, fac_filename)
    df.loc[index,'research_interests'] = get_research_interests(fac_profile)

df["homepage"].fillna("", inplace=True)

print(df)

fac_more_table_filename = "faculty_more_table_mv.csv"

df.to_csv(fac_more_table_filename, index=False, columns=["name","rank","area", \
                                                         "profile","homepage","research_interests"])
# Out:
#                        name       rank  \
# 0                Greg Baker     SENIOR
# 1          Petra Berenbrink  PROFESSOR
# 2            Andrei Bulatov  Professor
# 3                BOBBY CHAN    LIMITED
# 4      LEONID CHINDELEVITCH  ASSISTANT
# 5           Diana Cukierman     Senior
# 6        James P. Delgrande  Professor
# 7            Toby Donaldson     Senior
# 8                John Edgar     Senior
# 9              Martin Ester  Professor
# 10             Brian Fraser     Senior
# 11        Yasutaka Furukawa  Assistant
# 12              Uwe Gl?sser  Professor
# 13          Mohamed Hefeeda  Professor
# 14  Harinder Singh Khangura     Senior
# 15            Anne Lavergne     Senior
# 16        Maxwell Libbrecht  Assistant
# 17      Jiangchuan (JC) Liu  Professor
# 18           David Mitchell  Associate
# 19                 Jian Pei  Professor
# 20            Fred Popowich  Professor
# 21       Arrvindh Shriraman  Associate
# 22    William (Nick) Sumner  Assistant
# 23                 Ping Tan  Associate
# 24        Eugenia Ternovska  Associate
# 25               Keval Vora  Assistant
# 26                  Ke Wang  Professor
# 27             Kay C. Wiese  Associate
# 28             KangKang Yin  Associate
# 29                Brad Bart     SENIOR
# 30       Binay Bhattacharya  Professor
# 31        Robert D. Cameron  Professor
# 32                  Mo Chen  Assistant
# 33           Parmit Chilana  Assistant
# 34         Ryan C.N. D'Arcy  Professor
# 35             Mark S. Drew  Professor
# 36               Brian Funt  Professor
# 37              Qianping Gu  Professor
# 38         Ghassan Hamarneh  Professor
# 39             Eugene Fiume  Professor
# 40               Pavol Hell  Professor
# 41       Valentine Kabanets  Associate
# 42      Ramesh Krishnamurti  Professor
# 43               Ze-Nian Li  Professor
# 44             Angelica Lim  Assistant
# 45                Greg Mori  Professor
# 46            Steven Pearce   Lecturer
# 47         Joseph G. Peters  Professor
# 48             Janice Regan     Senior
# 49             Anoop Sarkar  Professor
# 50        Thomas C. Shermer  Professor
# 51           Oliver Schulte  Professor
# 52          Richard Vaughan  Associate
# 53             Jiannan Wang  Assistant
# 54              Cynthia Xie     Senior
# 55      Richard (Hao) Zhang  Professor
#
#                                                  area  \
# 0                                         Instruction
# 1   Probabilistic methods; Randomized algorithms; ...
# 2   Constraint Satisfaction, Complexity of Computa...
# 3                                         Instruction
# 4                               Computational Biology
# 5                                         Instruction
# 6          Formal Aspects of Knowledge Representation
# 7                                         Instruction
# 8                                         Instruction
# 9                           Databases and Data Mining
# 10                                        Instruction
# 11  Computer Vision, Deep Learning, Computer Graph...
# 12  Software Technology, Distributed Communication...
# 13       Computer Networks, Multimedia Communications
# 14                                        Instruction
# 15                                        Instruction
# 16         Computational Biology and Machine Learning
# 17           Networking and multimedia communications
# 18  Constraint satisfaction, Algorithms for deduct...
# 19                          Databases and Data Mining
# 20    Computational Linguistics and Logic Programming
# 21  Systems architecture, hardware-software intera...
# 22  Automated debugging, debugging tools, concurre...
# 23       Computer Vision, Computer Graphics, Robotics
# 24  Logical aspects of AI, Knowledge Representatio...
# 25  Parallel & Distributed Computing, Irregular Bi...
# 26                             Databases, Data Mining
# 27  Bioinformatics, Evolutionary Computation, Comp...
# 28  Computer Animation, Computer Graphics, Humanoi...
# 29                                        Instruction
# 30        Computational Geometry, Pattern Recognition
# 31  Software Engineering Languages; Electronic Pub...
# 32                    Robotics and Autonomous Systems
# 33                         Human-Computer Interaction
# 34                                       Neuroscience
# 35                                    Computer Vision
# 36                         Computational Color Vision
# 37              Network Communications and Algorithms
# 38  Medical Image Analysis (Computational/Artifici...
# 39                                  Computer Graphics
# 40                        Computational Combinatorics
# 41  Pseudorandomness and Derandomization, Complexi...
# 42  Combinatorial Optimization and Approximation A...
# 43                        Computer Vision, Multimedia
# 44                            Human Robot Interaction
# 45                  Computer Vision, Machine Learning
# 46     Instruction, Computational Applied Mathematics
# 47                             Network Communications
# 48                                        Instruction
# 49  Computational Linguistics; Machine Learning; P...
# 50       Computational Geometry and Computer Graphics
# 51  Machine Learning, Computational Logic, Computa...
# 52                    Robotics and Autonomous Systems
# 53                      Database Systems and Big Data
# 54  Mandarin Chinese Instruction for the Dual Degr...
# 55             Computer Graphics; Geometric Modelling
#
#                                               profile  \
# 0   http://www.sfu.ca/computing/people/faculty/gre...
# 1   http://www.sfu.ca/computing/people/faculty/pet...
# 2   http://www.sfu.ca/computing/people/faculty/and...
# 3   http://www.sfu.ca/computing/people/faculty/bob...
# 4   http://www.sfu.ca/computing/people/faculty/leo...
# 5   http://www.sfu.ca/computing/people/faculty/dia...
# 6   http://www.sfu.ca/computing/people/faculty/jam...
# 7   http://www.sfu.ca/computing/people/faculty/tob...
# 8   http://www.sfu.ca/computing/people/faculty/joh...
# 9   http://www.sfu.ca/computing/people/faculty/mar...
# 10  http://www.sfu.ca/computing/people/faculty/bri...
# 11  http://www.sfu.ca/computing/people/faculty/yas...
# 12  http://www.sfu.ca/computing/people/faculty/uwe...
# 13  http://www.sfu.ca/computing/people/faculty/moh...
# 14  http://www.sfu.ca/computing/people/faculty/har...
# 15  http://www.sfu.ca/computing/people/faculty/ann...
# 16  http://www.sfu.ca/computing/people/faculty/max...
# 17  http://www.sfu.ca/computing/people/faculty/jia...
# 18  http://www.sfu.ca/computing/people/faculty/dav...
# 19  http://www.sfu.ca/computing/people/faculty/jia...
# 20  http://www.sfu.ca/computing/people/faculty/fre...
# 21  http://www.sfu.ca/computing/people/faculty/Arr...
# 22  http://www.sfu.ca/computing/people/faculty/Nic...
# 23  http://www.sfu.ca/computing/people/faculty/pin...
# 24  http://www.sfu.ca/computing/people/faculty/Eug...
# 25  http://www.sfu.ca/computing/people/faculty/kev...
# 26  http://www.sfu.ca/computing/people/faculty/kew...
# 27  http://www.sfu.ca/computing/people/faculty/kay...
# 28  http://www.sfu.ca/computing/people/faculty/kan...
# 29  http://www.sfu.ca/computing/people/faculty/bra...
# 30  http://www.sfu.ca/computing/people/faculty/bin...
# 31  http://www.sfu.ca/computing/people/faculty/rob...
# 32  http://www.sfu.ca/computing/people/faculty/moc...
# 33  http://www.sfu.ca/computing/people/faculty/par...
# 34  http://www.sfu.ca/computing/people/faculty/rya...
# 35  http://www.sfu.ca/computing/people/faculty/mar...
# 36  http://www.sfu.ca/computing/people/faculty/bri...
# 37  http://www.sfu.ca/computing/people/faculty/Qia...
# 38  http://www.sfu.ca/computing/people/faculty/gha...
# 39  http://www.sfu.ca/computing/people/faculty/eug...
# 40  http://www.sfu.ca/computing/people/faculty/pav...
# 41  http://www.sfu.ca/computing/people/faculty/val...
# 42  http://www.sfu.ca/computing/people/faculty/Ram...
# 43  http://www.sfu.ca/computing/people/faculty/ze-...
# 44  http://www.sfu.ca/computing/people/faculty/ang...
# 45  http://www.sfu.ca/computing/people/faculty/gre...
# 46  http://www.sfu.ca/computing/people/faculty/ste...
# 47  http://www.sfu.ca/computing/people/faculty/Jos...
# 48  http://www.sfu.ca/computing/people/faculty/jan...
# 49  http://www.sfu.ca/computing/people/faculty/ano...
# 50  http://www.sfu.ca/computing/people/faculty/tho...
# 51  http://www.sfu.ca/computing/people/faculty/oli...
# 52  http://www.sfu.ca/computing/people/faculty/ric...
# 53  http://www.sfu.ca/computing/people/faculty/jia...
# 54  http://www.sfu.ca/computing/people/faculty/cyn...
# 55  http://www.sfu.ca/computing/people/faculty/ric...
#
#                            homepage research_interests
# 0    http://www.cs.sfu.ca/~ggbaker/                 []
# 1      http://www.cs.sfu.ca/~petra/                 []
# 2   http://www.cs.sfu.ca/~abulatov/                 []
# 3                                                   []
# 4         http://www.sfu.ca/~leonid                 []
# 5                                                   []
# 6        http://www.cs.sfu.ca/~jim/                 []
# 7                                                   []
# 8                                                   []
# 9      http://www.cs.sfu.ca/~ester/                 []
# 10   http://www.cs.sfu.ca/~bfraser/                 []
# 11  http://www.cs.sfu.ca/~furukawa/                 []
# 12  http://www.cs.sfu.ca/~glaesser/                 []
# 13  http://www.cs.sfu.ca/~mhefeeda/                 []
# 14  http://www.cs.sfu.ca/~hskhangu/                 []
# 15  http://www.cs.sfu.ca/~alavergn/                 []
# 16     http://www.cs.sfu.ca/~maxwl/                 []
# 17     http://www.cs.sfu.ca/~jcliu/                 []
# 18  http://www.cs.sfu.ca/~mitchell/                 []
# 19      http://www.cs.sfu.ca/~jpei/                 []
# 20  http://www.cs.sfu.ca/~popowich/                 []
# 21  http://www.cs.sfu.ca/~ashriram/                 []
# 22   http://www.cs.sfu.ca/~wsumner/                 []
# 23   http://www.cs.sfu.ca/~pingtan/                 []
# 24       http://www.cs.sfu.ca/~ter/                 []
# 25     http://www.cs.sfu.ca/~keval/                 []
# 26     http://www.cs.sfu.ca/~wangk/                 []
# 27     http://www.cs.sfu.ca/~wiese/                 []
# 28     http://www.cs.sfu.ca/~kkyin/                 []
# 29     http://www.cs.sfu.ca/~bbart/                 []
# 30     http://www.cs.sfu.ca/~binay/                 []
# 31   http://www.cs.sfu.ca/~cameron/                 []
# 32                                                  []
# 33            http://hci.cs.sfu.ca/                 []
# 34                                                  []
# 35      http://www.cs.sfu.ca/~mark/                 []
# 36      http://www.cs.sfu.ca/~funt/                 []
# 37       http://www.cs.sfu.ca/~qgu/                 []
# 38  http://www.cs.sfu.ca/~hamarneh/                 []
# 39                                                  []
# 40     http://www.cs.sfu.ca/~pavol/                 []
# 41  http://www.cs.sfu.ca/~kabanets/                 []
# 42    http://www.cs.sfu.ca/~ramesh/                 []
# 43        http://www.cs.sfu.ca/~li/                 []
# 44         https://www.rosielab.ca/                 []
# 45      http://www.cs.sfu.ca/~mori/                 []
# 46   http://www.cs.sfu.ca/~stevenp/                 []
# 47    http://www.cs.sfu.ca/~peters/                 []
# 48    http://www.cs.sfu.ca/~jregan/                 []
# 49     http://www.cs.sfu.ca/~anoop/                 []
# 50   http://www.cs.sfu.ca/~shermer/                 []
# 51  http://www.cs.sfu.ca/~oschulte/                 []
# 52   http://www.cs.sfu.ca/~vaughan/                 []
# 53   https://www.cs.sfu.ca/~jnwang/                 []
# 54                                                  []
# 55      http://www.cs.sfu.ca/~haoz/                 []

# %% [markdown]
# ## Submission

# %% [markdown]
# Complete the code in this notebook, and submit it to the CourSys activity [Assignment 1](https://courses.cs.sfu.ca/2018sp-cmpt-733-g1/+a1/).
